# %%
from keras.models import Model
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate

import pandas as pd
import tqdm
import h5py
from Bio import SeqIO

import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# import keras functions
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Input, Flatten, LSTM, Dropout, Bidirectional
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import EarlyStopping

# performance matrices
from sklearn.metrics import confusion_matrix, matthews_corrcoef, accuracy_score

# plots
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape, Lambda, LeakyReLU
from keras.layers import Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint
import numpy as np
from Bio import SeqIO
from numpy import array
from numpy import argmax
from sklearn.model_selection import train_test_split
from keras.layers.embeddings import Embedding
from keras import backend as K
from keras.backend import expand_dims
import matplotlib.pyplot as plt
from keras.regularizers import l1, l2

# %%
def plot_save(history, filename):
    # learning curves of model accuracy
    plt.plot(history.history['accuracy'], label='train_acc')
    plt.plot(history.history['val_accuracy'], label='val_acc')
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['auc_roc'], label='Train AUC')
    plt.plot(history.history['val_auc_roc'], label='Val AUC')
    plt.legend()
    plt.savefig(filename)
    plt.show()
    
def plot(history):
    # learning curves of model accuracy
    plt.plot(history.history['accuracy'], label='train_acc')
    plt.plot(history.history['val_accuracy'], label='val_acc')
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['auc_roc'], label='Train AUC')
    plt.plot(history.history['val_auc_roc'], label='Val AUC')
    plt.legend()
    plt.show()

# %%
def prot_t5_model():
    # prot_t5
    M1_input = Input(shape=(1024,))
    M1_dense_1 = Dense(256)(M1_input)
    drop_out = Dropout(0.4)(M1_dense_1)
   
    M1_dense_2 = Dense(64, activation='relu')(drop_out)
    drop_out = Dropout(0.4)(M1_dense_2)
    #M1_dense_2 = Dense(128, activation='relu')(drop_out)
    #leaky_relu = LeakyReLU(alpha=0.3)(M1_dense_2)
    #drop_out = Dropout(0.7)(leaky_relu)
    M1_dense_3 = Dense(1, activation = 'sigmoid')(drop_out)
    model = Model(inputs=M1_input, outputs=M1_dense_3)
    return model

# %%
def read_h5(path):
    hf = h5py.File(path, 'r')
    mat = np.array(hf["embedding"])
    hf.close()
    return mat

# %%
test_positive_ST_embedding_pos = read_h5("../embeddings/test_positive_ST_embedding.h5")
test_negative_ST_embedding_pos = read_h5("../embeddings/test_negative_ST_embedding.h5")

# %%
test_positive_ST_labels = np.ones(test_positive_ST_embedding_pos.shape[0])
test_negative_ST_labels = np.zeros(test_negative_ST_embedding_pos.shape[0])

test_ST_labels = np.concatenate((test_positive_ST_labels, test_negative_ST_labels), axis = 0)
X_test_full_ST_embedding = np.vstack((test_positive_ST_embedding_pos, test_negative_ST_embedding_pos))

# %%
train_positive_ST_embedding_pos = read_h5("../embeddings/train_positive_ST_embedding.h5")
train_negative_ST_embedding_pos = read_h5("../embeddings/train_negative_ST_embedding.h5")

# %%
train_positive_ST_labels = np.ones(train_positive_ST_embedding_pos.shape[0])
train_negative_ST_labels = np.zeros(train_negative_ST_embedding_pos.shape[0])

train_ST_labels = np.concatenate((train_positive_ST_labels, train_negative_ST_labels), axis = 0)
X_train_full_ST_embedding = np.vstack((train_positive_ST_embedding_pos, train_negative_ST_embedding_pos))

# %%
X_train_full_ST_embedding.shape, train_ST_labels.shape,  X_test_full_ST_embedding.shape, test_ST_labels.shape
# Out:
# ((1779, 1024), (1779,), (446, 1024), (446,))

# %%
def get_input_for_embedding(fasta_file):
    # This is returning just integers to feed to embedding layer
    
    encodings = []
    
    # define universe of possible input values
    alphabet = 'ARNDCQEGHILKMFPSTWYV-'
    
    # define a mapping of chars to integers
    char_to_int = dict((c, i) for i, c in enumerate(alphabet))
    int_to_char = dict((i, c) for i, c in enumerate(alphabet))
    
    #print(char_to_int)
    
    for seq_record in SeqIO.parse(fasta_file, "fasta"):
        data = seq_record.seq
        try:
            integer_encoded = [char_to_int[char] for char in data]
        except:
            continue
        encodings.append(integer_encoded)
    encodings = np.array(encodings)
    print(encodings.shape)
    return encodings


# convert sequences to integer encoding, for embedding
test_positive_ST_CNN = get_input_for_embedding('../dataset/test_Pos_ST.fasta')
test_negative_ST_CNN = get_input_for_embedding('../dataset/test_Neg_ST.fasta')

train_positive_ST_CNN = get_input_for_embedding('../dataset/train_Pos_ST.fasta')
train_negative_ST_CNN = get_input_for_embedding('../dataset/train_Neg_ST.fasta')
# Out:
# (222, 33)
# (224, 33)
# (890, 33)
# (889, 33)

# %%
X_train_CNN = np.vstack((train_positive_ST_CNN, train_negative_ST_CNN))
X_test_CNN = np.vstack((test_positive_ST_CNN, test_negative_ST_CNN))
X_train_CNN.shape, X_test_CNN.shape, train_ST_labels.shape, test_ST_labels.shape
# Out:
# ((1779, 33), (446, 33), (1779,), (446,))

# %%
X_train_CNN, train_ST_labels
# Out:
# (array([[ 2, 18, 16, ..., 15, 14, 15],
#         [15,  7, 12, ...,  1, 16,  5],
#         [ 5, 14,  5, ..., 15, 16, 18],
#         ...,
#         [ 0, 14, 10, ..., 19, 15,  7],
#         [ 8,  0, 15, ...,  1, 10, 10],
#         [ 3,  0, 10, ...,  3, 18, 11]]),
#  array([1., 1., 1., ..., 0., 0., 0.]))

# %%
from tensorflow.keras import backend as K

def CNN_model():
    model = Sequential()
    model.add(Embedding(128, 21, input_length=33))
    model.add(Lambda(lambda x: tf.expand_dims(x, 3)))
    model.add(Conv2D(32, kernel_size=(17, 3), activation = 'relu', kernel_initializer='he_normal', padding = 'VALID'))
    model.add(Dropout(0.2))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(16, activation='relu', kernel_initializer='he_normal'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='sigmoid'))
    return model


#import tensorflow as tf
from tensorflow.keras.layers import MultiHeadAttention, LayerNormalization, Layer, GlobalAveragePooling1D, Input, GlobalAveragePooling2D
#from tensorflow.keras.layers import Dense, Embedding
#from tensorflow.keras.models import Sequential


class TransformerBlock(Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=rate)
        self.ffn = Sequential(
            [Dense(ff_dim, activation="relu"), Dense(embed_dim)] #Dense(4 * ff_dim, activation="relu")
        )
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)
        
    def get_config(self):
        config = super().get_config()
        return config

    def call(self, inputs, training):
        attn_output, attention_scores = self.att(inputs, inputs, inputs, return_attention_scores=True, training=training)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output), attention_scores


class TokenAndPositionEmbedding(Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb = Embedding(input_dim=vocab_size, output_dim=embed_dim, mask_zero=True)
        self.pos_emb = Embedding(input_dim=maxlen, output_dim=embed_dim, mask_zero=True)
        
    def get_config(self):
        config = super().get_config()
        return config

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions
    
# transformer based embedding model
def transformer_model():
    vocab_size = 21
    embed_dim = 32 #config["embedding_dim"]
    ff_dim = 32 #config["feed_forward_dim"]
    max_len = 33 #config["maximum_path_length"]
    dropout = 0.2 #config["dropout"]
    n_heads = 2

    inputs = Input(shape=(max_len,))
    embedding_layer = TokenAndPositionEmbedding(max_len, vocab_size, embed_dim)
    x = embedding_layer(inputs)
    transformer_block = TransformerBlock(embed_dim, n_heads, ff_dim)
    x, weights = transformer_block(x)
    x = GlobalAveragePooling1D()(x) #GlobalAveragePooling1D
    x = Dropout(dropout)(x)
    x = Dense(ff_dim, activation="relu")(x)
    x = Dropout(dropout)(x)
    outputs = Dense(1, activation="sigmoid")(x)
    return Model(inputs=inputs, outputs=[outputs])

# %%
# Pretraining with Phosphorylation dataset

# S
pre_test_positive_S_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/test_pos_S.fasta')
pre_test_negative_S_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/test_neg_S.fasta')

pre_train_positive_S_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/train_pos_S.fasta')
pre_train_negative_S_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/train_neg_S.fasta')

# T
pre_test_positive_T_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/test_pos_T.fasta')
pre_test_negative_T_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/test_neg_T.fasta')

pre_train_positive_T_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/train_pos_T.fasta')
pre_train_negative_T_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/train_neg_T.fasta')


pre_test_pos_ST_CNN = np.vstack((pre_test_positive_S_CNN, pre_test_positive_T_CNN))
pre_test_neg_ST_CNN = np.vstack((pre_test_negative_S_CNN, pre_test_negative_T_CNN))

pre_train_pos_ST_CNN = np.vstack((pre_train_positive_S_CNN, pre_train_positive_T_CNN))
pre_train_neg_ST_CNN = np.vstack((pre_train_negative_S_CNN, pre_train_negative_T_CNN))
# Out:
# (3367, 33)
# (3366, 33)
# (13465, 33)
# (13464, 33)
# (856, 33)
# (858, 33)
# (3420, 33)
# (3419, 33)

# %%
pre_test_pos_ST_CNN.shape, pre_test_neg_ST_CNN.shape, pre_train_pos_ST_CNN.shape, pre_train_neg_ST_CNN.shape
# Out:
# ((4223, 33), (4224, 33), (16885, 33), (16883, 33))

# %%
pre_test_ST = np.vstack((pre_test_pos_ST_CNN, pre_test_neg_ST_CNN))

pre_test_positive_ST_labels = np.ones(pre_test_pos_ST_CNN.shape[0])
pre_test_negative_ST_labels = np.zeros(pre_test_neg_ST_CNN.shape[0])

pre_test_ST_labels = np.concatenate((pre_test_positive_ST_labels, pre_test_negative_ST_labels), axis = 0)
pre_test_ST.shape, pre_test_ST_labels.shape
# Out:
# ((8447, 33), (8447,))

# %%
pre_train_ST = np.vstack((pre_train_pos_ST_CNN, pre_train_neg_ST_CNN))

pre_train_positive_ST_labels = np.ones(pre_train_pos_ST_CNN.shape[0])
pre_train_negative_ST_labels = np.zeros(pre_train_neg_ST_CNN.shape[0])

pre_train_ST_labels = np.concatenate((pre_train_positive_ST_labels, pre_train_negative_ST_labels), axis = 0)
pre_train_ST.shape, pre_train_ST_labels.shape
# Out:
# ((33768, 33), (33768,))

# %%
pre_train_ST, pre_train_ST_labels
# Out:
# (array([[10,  1,  8, ..., 14, 10, 16],
#         [ 0, 10,  5, ..., 10, 16,  7],
#         [ 5,  6,  6, ...,  3, 14, 10],
#         ...,
#         [16, 12, 18, ...,  2, 15, 11],
#         [ 8, 16,  7, ...,  7,  6,  1],
#         [10,  7,  0, ...,  1,  0,  0]]),
#  array([1., 1., 1., ..., 0., 0., 0.]))

# %%
X_train_CNN, train_ST_labels
# Out:
# (array([[ 2, 18, 16, ..., 15, 14, 15],
#         [15,  7, 12, ...,  1, 16,  5],
#         [ 5, 14,  5, ..., 15, 16, 18],
#         ...,
#         [ 0, 14, 10, ..., 19, 15,  7],
#         [ 8,  0, 15, ...,  1, 10, 10],
#         [ 3,  0, 10, ...,  3, 18, 11]]),
#  array([1., 1., 1., ..., 0., 0., 0.]))

# %%
# Pretraining models

iteration = 1
n_epo_cnn = 30
n_epo = 10

metrics = ['accuracy', tf.keras.metrics.AUC(name='auc_roc')]

model_A = CNN_model()
model_A.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)

model_A.summary()

print("PRE Training CNN model...")

#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=7,mode='auto')

history_A = model_A.fit(pre_train_ST, pre_train_ST_labels, batch_size=1024, epochs=n_epo_cnn, verbose=1, callbacks=[],
    validation_data=(pre_test_ST, pre_test_ST_labels))

# Save model
#model_A.save('../models/cv_new/model_A_'+str(iteration)+'.h5')
model_A.save_weights('../models/pre_model_A.h5')

y_pred = model_A.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

#save plot
plot(history_A)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))


########### Model B

'''print("Training Embedding model...")

model_B = prot_t5_model()
model_B.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=3,mode='auto')

metric = 'val_accuracy'

history_B = model_B.fit(X_train_full_ST_embedding, train_ST_labels, batch_size=256, epochs=n_epo, verbose=1, callbacks=[], 
                        validation_data=(X_test_full_ST_embedding, test_ST_labels))

model_B.save_weights('../models/model_B.h5')

y_pred = model_B.predict(X_test_full_ST_embedding).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

plot(history_B)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))'''

############# Training Transformer


model_C = transformer_model()
model_C.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)

model_C.summary()

print("PRE Training Transformer model...")

history_C = model_C.fit(pre_train_ST, pre_train_ST_labels, batch_size=256, epochs=n_epo_cnn, verbose=1, callbacks=[],
    validation_data=(pre_test_ST, pre_test_ST_labels))

# Save model
model_C.save_weights('../models/pre_model_C.h5')

y_pred = model_C.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

#save plot
plot(history_C)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
# Model: "sequential_66"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_86 (Embedding)    (None, 33, 21)            2688
#
#  lambda_46 (Lambda)          (None, 33, 21, 1)         0
#
#  conv2d_46 (Conv2D)          (None, 17, 19, 32)        1664
#
#  dropout_174 (Dropout)       (None, 17, 19, 32)        0
#
#  max_pooling2d_46 (MaxPoolin  (None, 8, 9, 32)         0
#  g2D)
#
#  flatten_46 (Flatten)        (None, 2304)              0
#
#  dense_175 (Dense)           (None, 16)                36880
#
#  dropout_175 (Dropout)       (None, 16)                0
#
#  dense_176 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 41,249
# Trainable params: 41,249
# Non-trainable params: 0
# _________________________________________________________________
# PRE Training CNN model...
# Epoch 1/30
# 33/33 [==============================] - 9s 263ms/step - loss: 0.6451 - accuracy: 0.6332 - auc_roc: 0.6912 - val_loss: 0.5868 - val_accuracy: 0.6987 - val_auc_roc: 0.7648
# Epoch 2/30
# 33/33 [==============================] - 17s 517ms/step - loss: 0.5645 - accuracy: 0.7158 - auc_roc: 0.7798 - val_loss: 0.5500 - val_accuracy: 0.7242 - val_auc_roc: 0.7958
# Epoch 3/30
# 33/33 [==============================] - 14s 414ms/step - loss: 0.5397 - accuracy: 0.7368 - auc_roc: 0.8035 - val_loss: 0.5408 - val_accuracy: 0.7309 - val_auc_roc: 0.8052
# Epoch 4/30
# 33/33 [==============================] - 15s 443ms/step - loss: 0.5324 - accuracy: 0.7392 - auc_roc: 0.8100 - val_loss: 0.5363 - val_accuracy: 0.7343 - val_auc_roc: 0.8086
# Epoch 5/30
# 33/33 [==============================] - 13s 401ms/step - loss: 0.5273 - accuracy: 0.7431 - auc_roc: 0.8148 - val_loss: 0.5365 - val_accuracy: 0.7319 - val_auc_roc: 0.8114
# Epoch 6/30
# 33/33 [==============================] - 12s 371ms/step - loss: 0.5254 - accuracy: 0.7445 - auc_roc: 0.8163 - val_loss: 0.5305 - val_accuracy: 0.7403 - val_auc_roc: 0.8140
# Epoch 7/30
# 33/33 [==============================] - 12s 362ms/step - loss: 0.5200 - accuracy: 0.7486 - auc_roc: 0.8209 - val_loss: 0.5293 - val_accuracy: 0.7419 - val_auc_roc: 0.8161
# Epoch 8/30
# 33/33 [==============================] - 12s 362ms/step - loss: 0.5175 - accuracy: 0.7506 - auc_roc: 0.8230 - val_loss: 0.5242 - val_accuracy: 0.7450 - val_auc_roc: 0.8182
# Epoch 9/30
# 33/33 [==============================] - 12s 363ms/step - loss: 0.5137 - accuracy: 0.7533 - auc_roc: 0.8261 - val_loss: 0.5218 - val_accuracy: 0.7464 - val_auc_roc: 0.8201
# Epoch 10/30
# 33/33 [==============================] - 12s 368ms/step - loss: 0.5113 - accuracy: 0.7554 - auc_roc: 0.8279 - val_loss: 0.5197 - val_accuracy: 0.7462 - val_auc_roc: 0.8219
30
# 132/132 [==============================] - 10s 77ms/step - loss: 0.5129 - accuracy: 0.7516 - auc_roc: 0.8267 - val_loss: 0.5156 - val_accuracy: 0.7448 - val_auc_roc: 0.8234
# Epoch 19/30
# 132/132 [==============================] - 11s 83ms/step - loss: 0.5158 - accuracy: 0.7520 - auc_roc: 0.8244 - val_loss: 0.5148 - val_accuracy: 0.7468 - val_auc_roc: 0.8234
# Epoch 20/30
# 132/132 [==============================] - 11s 84ms/step - loss: 0.5092 - accuracy: 0.7557 - auc_roc: 0.8294 - val_loss: 0.5150 - val_accuracy: 0.7478 - val_auc_roc: 0.8246
# Epoch 21/30
# 132/132 [==============================] - 10s 77ms/step - loss: 0.5113 - accuracy: 0.7539 - auc_roc: 0.8279 - val_loss: 0.5159 - val_accuracy: 0.7459 - val_auc_roc: 0.8241
# Epoch 22/30
# 132/132 [==============================] - 10s 78ms/step - loss: 0.5097 - accuracy: 0.7527 - auc_roc: 0.8288 - val_loss: 0.5133 - val_accuracy: 0.7456 - val_auc_roc: 0.8250
# Epoch 23/30
# 132/132 [==============================] - 10s 78ms/step - loss: 0.5092 - accuracy: 0.7562 - auc_roc: 0.8291 - val_loss: 0.5131 - val_accuracy: 0.7472 - val_auc_roc: 0.8248
# Epoch 24/30
# 132/132 [==============================] - 10s 78ms/step - loss: 0.5106 - accuracy: 0.7553 - auc_roc: 0.8283 - val_loss: 0.5141 - val_accuracy: 0.7477 - val_auc_roc: 0.8247
# Epoch 25/30
# 132/132 [==============================] - 10s 77ms/step - loss: 0.5123 - accuracy: 0.7538 - auc_roc: 0.8271 - val_loss: 0.5125 - val_accuracy: 0.7471 - val_auc_roc: 0.8254
# Epoch 26/30
# 132/132 [==============================] - 10s 79ms/step - loss: 0.5078 - accuracy: 0.7566 - auc_roc: 0.8306 - val_loss: 0.5145 - val_accuracy: 0.7431 - val_auc_roc: 0.8253
# Epoch 27/30
# 132/132 [==============================] - 10s 79ms/step - loss: 0.5071 - accuracy: 0.7557 - auc_roc: 0.8309 - val_loss: 0.5136 - val_accuracy: 0.7454 - val_auc_roc: 0.8242
# Epoch 28/30
# 132/132 [==============================] - 10s 78ms/step - loss: 0.5085 - accuracy: 0.7560 - auc_roc: 0.8304 - val_loss: 0.5145 - val_accuracy: 0.7488 - val_auc_roc: 0.8255
# Epoch 29/30
# 132/132 [==============================] - 10s 78ms/step - loss: 0.5082 - accuracy: 0.7555 - auc_roc: 0.8302 - val_loss: 0.5224 - val_accuracy: 0.7391 - val_auc_roc: 0.8213
# Epoch 30/30
# 132/132 [==============================] - 11s 83ms/step - loss: 0.5057 - accuracy: 0.7571 - auc_roc: 0.8322 - val_loss: 0.5167 - val_accuracy: 0.7437 - val_auc_roc: 0.8244
#  Acc: 0.7780269058295964, MCC: 0.5560415475165102, SN:0.7747747747747747, SP:0.78125,
#  CM:[[175  49]
#  [ 50 172]]

# %%
#model_A = CNN_model()
#model_A.load_weights("")
#model_A.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=['accuracy'])

#model_A.summary()

#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=7,mode='auto')

#history_A = model_A.fit(X_train_CNN, train_ST_labels, batch_size=256, epochs=n_epo_cnn, verbose=1,callbacks=[], validation_data=(X_test_CNN, test_ST_labels))

# Save model
#model_A.save('../models/cv_new/model_A_'+str(iteration)+'.h5')
#model_A.save_weights('../models/model_A.h5')

y_pred = model_A.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

#save plot
#plot(history_A)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))


########### Model B

'''
y_pred = model_B.predict(X_test_full_ST_embedding).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

plot(history_B)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))'''

############# Training Transformer


y_pred = model_C.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

#save plot
#plot(history_C)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
#  Acc: 0.7982062780269058, MCC: 0.5966690977574959, SN:0.8108108108108109, SP:0.7857142857142857,
#  CM:[[176  48]
#  [ 42 180]]
#
#  Acc: 0.7780269058295964, MCC: 0.5560415475165102, SN:0.7747747747747747, SP:0.78125,
#  CM:[[175  49]
#  [ 50 172]]

# %%
# Training DE-Phosphorylation

iteration = 1
n_epo_cnn = 30
n_epo = 10

#model_A = CNN_model()
#model_A.load_weights("")
#model_A.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=['accuracy'])

#model_A.summary()

print("Training CNN model...")

#metrics = ['accuracy', tf.keras.metrics.AUC()]

#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=7,mode='auto')

history_A = model_A.fit(X_train_CNN, train_ST_labels, batch_size=256, epochs=n_epo_cnn, verbose=1, callbacks=[], 
                        validation_data=(X_test_CNN, test_ST_labels))

# Save model
model_A.save_weights('../models/model_A.h5')

y_pred = model_A.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

#save plot
plot(history_A)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))


########### Model B

print("Training Embedding model...")

model_B = prot_t5_model()
model_B.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=3,mode='auto')

history_B = model_B.fit(X_train_full_ST_embedding, train_ST_labels, batch_size=256, epochs=n_epo, verbose=1, callbacks=[], 
                        validation_data=(X_test_full_ST_embedding, test_ST_labels))

model_B.save_weights('../models/model_B.h5')

y_pred = model_B.predict(X_test_full_ST_embedding).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

plot(history_B)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))

############# Training Transformer


#model_C = transformer_model()
#model_C.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=['accuracy'])

#model_C.summary()

print("Training Transformer model...")

#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=7,mode='auto')

history_C = model_C.fit(X_train_CNN, train_ST_labels, batch_size=256, epochs=n_epo_cnn, verbose=1,callbacks=[]
                        , validation_data=(X_test_CNN, test_ST_labels))

# Save model
model_C.save_weights('../models/model_C.h5')

y_pred = model_C.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

#save plot
plot(history_C)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
# Training CNN model...
# Epoch 1/30
# 7/7 [==============================] - 1s 73ms/step - loss: 0.5319 - accuracy: 0.7386 - auc_roc: 0.8126 - val_loss: 0.4724 - val_accuracy: 0.7937 - val_auc_roc: 0.8785
# Epoch 2/30
# 7/7 [==============================] - 0s 63ms/step - loss: 0.5076 - accuracy: 0.7583 - auc_roc: 0.8323 - val_loss: 0.4490 - val_accuracy: 0.7915 - val_auc_roc: 0.8811
# Epoch 3/30
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4983 - accuracy: 0.7628 - auc_roc: 0.8379 - val_loss: 0.4553 - val_accuracy: 0.8049 - val_auc_roc: 0.8867
# Epoch 4/30
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4667 - accuracy: 0.7903 - auc_roc: 0.8616 - val_loss: 0.4363 - val_accuracy: 0.8027 - val_auc_roc: 0.8883
# Epoch 5/30
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4548 - accuracy: 0.7931 - auc_roc: 0.8657 - val_loss: 0.4338 - val_accuracy: 0.8229 - val_auc_roc: 0.8910
# Epoch 6/30
# 7/7 [==============================] - 0s 61ms/step - loss: 0.4385 - accuracy: 0.8055 - auc_roc: 0.8790 - val_loss: 0.4356 - val_accuracy: 0.8049 - val_auc_roc: 0.8871
# Epoch 7/30
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4195 - accuracy: 0.8179 - auc_roc: 0.8887 - val_loss: 0.4340 - val_accuracy: 0.8027 - val_auc_roc: 0.8902
# 7/7 [==============================] - 0s 68ms/step - loss: 0.2456 - accuracy: 0.9095 - auc_roc: 0.9695 - val_loss: 0.4324 - val_accuracy: 0.8027 - val_auc_roc: 0.8851
# Epoch 23/30
# 7/7 [==============================] - 1s 89ms/step - loss: 0.2472 - accuracy: 0.8966 - auc_roc: 0.9656 - val_loss: 0.4397 - val_accuracy: 0.8027 - val_auc_roc: 0.8828
# Epoch 24/30
# 7/7 [==============================] - 1s 102ms/step - loss: 0.2305 - accuracy: 0.9146 - auc_roc: 0.9743 - val_loss: 0.4415 - val_accuracy: 0.7915 - val_auc_roc: 0.8827
# Epoch 25/30
# 7/7 [==============================] - 1s 107ms/step - loss: 0.2274 - accuracy: 0.9140 - auc_roc: 0.9727 - val_loss: 0.4410 - val_accuracy: 0.7960 - val_auc_roc: 0.8822
# Epoch 26/30
# 7/7 [==============================] - 1s 113ms/step - loss: 0.2058 - accuracy: 0.9275 - auc_roc: 0.9807 - val_loss: 0.4491 - val_accuracy: 0.7937 - val_auc_roc: 0.8818
# Epoch 27/30
# 7/7 [==============================] - 1s 111ms/step - loss: 0.2017 - accuracy: 0.9252 - auc_roc: 0.9796 - val_loss: 0.4606 - val_accuracy: 0.7825 - val_auc_roc: 0.8808
# Epoch 28/30
# 7/7 [==============================] - 1s 111ms/step - loss: 0.1983 - accuracy: 0.9303 - auc_roc: 0.9818 - val_loss: 0.4460 - val_accuracy: 0.8094 - val_auc_roc: 0.8801
# Epoch 29/30
# 7/7 [==============================] - 1s 109ms/step - loss: 0.1951 - accuracy: 0.9247 - auc_roc: 0.9811 - val_loss: 0.4538 - val_accuracy: 0.8117 - val_auc_roc: 0.8796
# Epoch 30/30
# 7/7 [==============================] - 1s 110ms/step - loss: 0.1873 - accuracy: 0.9286 - auc_roc: 0.9836 - val_loss: 0.4642 - val_accuracy: 0.8049 - val_auc_roc: 0.8794
#  Acc: 0.804932735426009, MCC: 0.6160752261735762, SN:0.8738738738738738, SP:0.7366071428571429,
#  CM:[[165  59]
#  [ 28 194]]
# Training Embedding model...
# Epoch 1/10
# 7/7 [==============================] - 1s 56ms/step - loss: 0.6072 - accuracy: 0.6678 - auc_roc: 0.7689 - val_loss: 0.5057 - val_accuracy: 0.7668 - val_auc_roc: 0.8309
# Epoch 2/10
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5241 - accuracy: 0.7549 - auc_roc: 0.8217 - val_loss: 0.4857 - val_accuracy: 0.7803 - val_auc_roc: 0.8500
# Epoch 3/10
# 7/7 [==============================] - 0s 13ms/step - loss: 0.4922 - accuracy: 0.7701 - auc_roc: 0.8466 - val_loss: 0.4754 - val_accuracy: 0.7892 - val_auc_roc: 0.8603
# Epoch 4/10
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4787 - accuracy: 0.7746 - auc_roc: 0.8547 - val_loss: 0.4642 - val_accuracy: 0.7960 - val_auc_roc: 0.8619
# Epoch 5/10
# 7/7 [==============================] - 0s 13ms/step - loss: 0.4574 - accuracy: 0.7847 - auc_roc: 0.8674 - val_loss: 0.4686 - val_accuracy: 0.8139 - val_auc_roc: 0.8624
# Epoch 6/10
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4404 - accuracy: 0.7965 - auc_roc: 0.8797 - val_loss: 0.4606 - val_accuracy: 0.8229 - val_auc_roc: 0.8648
# Epoch 7/10
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4242 - accuracy: 0.8117 - auc_roc: 0.8884 - val_loss: 0.4558 - val_accuracy: 0.8229 - val_auc_roc: 0.8670
# Epoch 8/10
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4036 - accuracy: 0.8184 - auc_roc: 0.8991 - val_loss: 0.4630 - val_accuracy: 0.8072 - val_auc_roc: 0.8650
# Epoch 9/10
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3900 - accuracy: 0.8241 - auc_roc: 0.9069 - val_loss: 0.4637 - val_accuracy: 0.8161 - val_auc_roc: 0.8670
# Epoch 10/10
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3791 - accuracy: 0.8291 - auc_roc: 0.9112 - val_loss: 0.4670 - val_accuracy: 0.8072 - val_auc_roc: 0.8657
#  Acc: 0.8071748878923767, MCC: 0.6143420205920206, SN:0.8063063063063063, SP:0.8080357142857143,
#  CM:[[181  43]
#  [ 43 179]]
# Training Transformer model...
# Epoch 1/30
# 7/7 [==============================] - 1s 74ms/step - loss: 0.5398 - accuracy: 0.7330 - auc_roc: 0.8048 - val_loss: 0.4759 - val_accuracy: 0.7758 - val_auc_roc: 0.8556
# Epoch 2/30
# 7/7 [==============================] - 1s 83ms/step - loss: 0.5267 - accuracy: 0.7510 - auc_roc: 0.8169 - val_loss: 0.4699 - val_accuracy: 0.7825 - val_auc_roc: 0.8621
# Epoch 3/30
# 7/7 [==============================] - 1s 89ms/step - loss: 0.5162 - accuracy: 0.7442 - auc_roc: 0.8221 - val_loss: 0.4600 - val_accuracy: 0.7892 - val_auc_roc: 0.8683
# Epoch 4/30
# 7/7 [==============================] - 1s 87ms/step - loss: 0.5161 - accuracy: 0.7605 - auc_roc: 0.8267 - val_loss: 0.4609 - val_accuracy: 0.7870 - val_auc_roc: 0.8666
# Epoch 5/30
# 7/7 [==============================] - 1s 82ms/step - loss: 0.5027 - accuracy: 0.7555 - auc_roc: 0.8351 - val_loss: 0.4637 - val_accuracy: 0.7848 - val_auc_roc: 0.8648
# Epoch 6/30
# 7/7 [==============================] - 1s 87ms/step - loss: 0.4942 - accuracy: 0.7757 - auc_roc: 0.8403 - val_loss: 0.4516 - val_accuracy: 0.8004 - val_auc_roc: 0.8741
# Epoch 7/30
# 7/7 [==============================] - 1s 89ms/step - loss: 0.4864 - accuracy: 0.7662 - auc_roc: 0.8441 - val_loss: 0.4456 - val_accuracy: 0.7982 - val_auc_roc: 0.8755
# Epoch 8/30
# 7/7 [==============================] - 1s 88ms/step - loss: 0.4866 - accuracy: 0.7791 - auc_roc: 0.8444 - val_loss: 0.4482 - val_accuracy: 0.7982 - val_auc_roc: 0.8716
# Epoch 9/30
# 7/7 [==============================] - 1s 81ms/step - loss: 0.4784 - accuracy: 0.7763 - auc_roc: 0.8527 - val_loss: 0.4420 - val_accuracy: 0.7982 - val_auc_roc: 0.8793
# Epoch 10/30
# 7/7 [==============================] - 1s 80ms/step - loss: 0.4829 - accuracy: 0.7752 - auc_roc: 0.8496 - val_loss: 0.4478 - val_accuracy: 0.8094 - val_auc_roc: 0.8727
# Epoch 11/30
# 7/7 [==============================] - 1s 77ms/step - loss: 0.4812 - accuracy: 0.7819 - auc_roc: 0.8501 - val_loss: 0.4424 - val_accuracy: 0.8161 - val_auc_roc: 0.8782
# Epoch 12/30
# 7/7 [==============================] - 1s 82ms/step - loss: 0.4755 - accuracy: 0.7791 - auc_roc: 0.8551 - val_loss: 0.4400 - val_accuracy: 0.8072 - val_auc_roc: 0.8801
# Epoch 13/30
# 7/7 [==============================] - 1s 77ms/step - loss: 0.4710 - accuracy: 0.7847 - auc_roc: 0.8566 - val_loss: 0.4421 - val_accuracy: 0.8094 - val_auc_roc: 0.8757
# Epoch 14/30
# 7/7 [==============================] - 1s 77ms/step - loss: 0.4637 - accuracy: 0.7881 - auc_roc: 0.8604 - val_loss: 0.4357 - val_accuracy: 0.8094 - val_auc_roc: 0.8809
# Epoch 15/30
# 7/7 [==============================] - 1s 95ms/step - loss: 0.4650 - accuracy: 0.7965 - auc_roc: 0.8601 - val_loss: 0.4513 - val_accuracy: 0.7915 - val_auc_roc: 0.8752
# Epoch 16/30
# 7/7 [==============================] - 1s 88ms/step - loss: 0.4680 - accuracy: 0.7780 - auc_roc: 0.8587 - val_loss: 0.4349 - val_accuracy: 0.8049 - val_auc_roc: 0.8817
# Epoch 17/30
# 7/7 [==============================] - 1s 86ms/step - loss: 0.4588 - accuracy: 0.7943 - auc_roc: 0.8658 - val_loss: 0.4448 - val_accuracy: 0.7937 - val_auc_roc: 0.8755
# Epoch 18/30
# 7/7 [==============================] - 1s 84ms/step - loss: 0.4566 - accuracy: 0.7948 - auc_roc: 0.8668 - val_loss: 0.4453 - val_accuracy: 0.7960 - val_auc_roc: 0.8826
# Epoch 19/30
# 7/7 [==============================] - 1s 82ms/step - loss: 0.4600 - accuracy: 0.7875 - auc_roc: 0.8644 - val_loss: 0.4419 - val_accuracy: 0.8072 - val_auc_roc: 0.8777
# Epoch 20/30
# 7/7 [==============================] - 1s 72ms/step - loss: 0.4437 - accuracy: 0.8038 - auc_roc: 0.8749 - val_loss: 0.4348 - val_accuracy: 0.8027 - val_auc_roc: 0.8800
# Epoch 21/30
# 7/7 [==============================] - 1s 77ms/step - loss: 0.4394 - accuracy: 0.8111 - auc_roc: 0.8769 - val_loss: 0.4343 - val_accuracy: 0.8004 - val_auc_roc: 0.8799
# Epoch 22/30
# 7/7 [==============================] - 1s 76ms/step - loss: 0.4450 - accuracy: 0.7960 - auc_roc: 0.8726 - val_loss: 0.4368 - val_accuracy: 0.7982 - val_auc_roc: 0.8783
# Epoch 23/30
# 7/7 [==============================] - 1s 75ms/step - loss: 0.4446 - accuracy: 0.7982 - auc_roc: 0.8736 - val_loss: 0.4421 - val_accuracy: 0.7848 - val_auc_roc: 0.8774
# Epoch 24/30
# 7/7 [==============================] - 1s 79ms/step - loss: 0.4347 - accuracy: 0.8038 - auc_roc: 0.8802 - val_loss: 0.4456 - val_accuracy: 0.7982 - val_auc_roc: 0.8774
# Epoch 25/30
# 7/7 [==============================] - 1s 89ms/step - loss: 0.4361 - accuracy: 0.8117 - auc_roc: 0.8782 - val_loss: 0.4379 - val_accuracy: 0.8094 - val_auc_roc: 0.8762
# Epoch 26/30
# 7/7 [==============================] - 1s 82ms/step - loss: 0.4244 - accuracy: 0.8212 - auc_roc: 0.8856 - val_loss: 0.4339 - val_accuracy: 0.8049 - val_auc_roc: 0.8802
# Epoch 27/30
# 7/7 [==============================] - 1s 87ms/step - loss: 0.4216 - accuracy: 0.8156 - auc_roc: 0.8864 - val_loss: 0.4418 - val_accuracy: 0.7870 - val_auc_roc: 0.8783
# Epoch 28/30
# 7/7 [==============================] - 1s 84ms/step - loss: 0.4230 - accuracy: 0.8089 - auc_roc: 0.8855 - val_loss: 0.4439 - val_accuracy: 0.8072 - val_auc_roc: 0.8745
# Epoch 29/30
# 7/7 [==============================] - 1s 85ms/step - loss: 0.4170 - accuracy: 0.8128 - auc_roc: 0.8900 - val_loss: 0.4392 - val_accuracy: 0.7982 - val_auc_roc: 0.8770
# Epoch 30/30
# 7/7 [==============================] - 1s 93ms/step - loss: 0.4237 - accuracy: 0.8196 - auc_roc: 0.8862 - val_loss: 0.4455 - val_accuracy: 0.7870 - val_auc_roc: 0.8787
#  Acc: 0.7869955156950673, MCC: 0.5748492369309941, SN:0.7567567567567568, SP:0.8169642857142857,
#  CM:[[183  41]
#  [ 54 168]]

# %%
# load models from file
def load_A_models():
    model_A = CNN_model()
    model_A.load_weights('../models/model_A.h5')
    return model_A


def load_B_models():
    model = prot_t5_model()
    model.load_weights('../models/model_B.h5')
    return model

def load_C_models():
    model = transformer_model()
    model.load_weights('../models/model_C.h5')
    return model


# meta learner
def define_stacked_model(members):
    for i in range(len(members)):
        model = members[i]
        for layer in model.layers:
            layer.trainable = False
#             layer.name = 'ensemble_' + str(i+1) + '_' + layer.name
    ensemble_visible = [model.input for model in members]
    ensemble_outputs = [model.output for model in members]
    #print(ensemble_visible)
    #print(ensemble_outputs)
    merge = concatenate(ensemble_outputs)
    hidden = Dense(4, activation='relu', name = 'ds_1')(merge)
#     hidden = Dropout(0.4, name = 'dp_1')(hidden)
#     hidden = Dense(4, activation='relu', name = 'ds_2')(hidden)

#     hidden = Dense(4, activation='relu', name = 'ds_3')(hidden)
#     hidden = Reshape((1,4))(hidden)X_train_embedding_full
#     hidden = Bidirectional(LSTM(32))(hidden)
#     hidden = Dropout(0.4, name = 'dp_2')(hidden)
    output = Dense(1, activation='sigmoid', name = 'ds_4')(hidden)
    model = Model(inputs=ensemble_visible, outputs=output)
    plot_model(model, show_shapes=True, to_file='ensemble_graph.png')
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=metrics)
    model.summary()
    return model


# fit a model
def fit_stacked_model(model, inputX, inputy):
    X = [inputX for _ in range(len(model.input))]
    inputy_enc = to_categorical(inputy)
    model.fit(X, inputy_enc, epochs=10, verbose=1)   


# prediction
def predict_stacked_model(model, inputX):
    X = [inputX for _ in range(len(model.input))]
    return model.predict(X, verbose=0)


# load all models
members = list()
#model_A = load_A_models()
model_B = load_B_models()
model_C = load_C_models()

#members.append(model_A)
members.append(model_B)
members.append(model_C)

n_epo_stacked = 40


#members = load_all_models(['model_A_1', 'model_B_1'])
print('Loaded %d models' % len(members))
stacked_model = define_stacked_model(members)
#print(X_train_embedding_full.shape, X_train_pt5_full.shape)
# fit_stacked_model(stacked_model, x_test, y_test)
#st_history = stacked_model.fit([X_train_embedding_full, X_train_embedding_full, X_train_embedding_full, X_train_embedding_full, X_train_embedding_full, X_train_pt5_full, X_train_pt5_full, X_train_pt5_full, X_train_pt5_full, X_train_pt5_full],y_train, epochs=10, verbose=1)
st_history = stacked_model.fit([X_train_embedding_full, X_train_CNN], train_ST_labels, epochs=n_epo_stacked, 
                               verbose=1, validation_data=([X_test_full_ST_embedding, X_test_CNN], test_ST_labels))

# X_train_full_ST_embedding, X_test_full_ST_embedding

stacked_model.save_weights("../models/composite_model.h5")

# Predict
y_pred = stacked_model.predict([X_test_full_ST_embedding, X_test_CNN]).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

plot(st_history)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
# Loaded 2 models
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# Model: "model_66"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_45 (InputLayer)          [(None, 33)]         0           []
#
#  token_and_position_embedding_3  (None, 33, 32)      1728        ['input_45[0][0]']
#  2 (TokenAndPositionEmbedding)
#
#  input_44 (InputLayer)          [(None, 1024)]       0           []
#
#  transformer_block_32 (Transfor  ((None, 33, 32),    10656       ['token_and_position_embedding_32
#  merBlock)                       (None, 2, 33, 33))              [0][0]']
#
#  dense_261 (Dense)              (None, 256)          262400      ['input_44[0][0]']
#
#  global_average_pooling1d_32 (G  (None, 32)          0           ['transformer_block_32[0][0]']
#  lobalAveragePooling1D)
#
#  dropout_250 (Dropout)          (None, 256)          0           ['dense_261[0][0]']
#
#  dropout_254 (Dropout)          (None, 32)           0           ['global_average_pooling1d_32[0][
#                                                                  0]']
#
#  dense_262 (Dense)              (None, 64)           16448       ['dropout_250[0][0]']
#
#  dense_266 (Dense)              (None, 32)           1056        ['dropout_254[0][0]']
#
#  dropout_251 (Dropout)          (None, 64)           0           ['dense_262[0][0]']
#
#  dropout_255 (Dropout)          (None, 32)           0           ['dense_266[0][0]']
#
#  dense_263 (Dense)              (None, 1)            65          ['dropout_251[0][0]']
#
#  dense_267 (Dense)              (None, 1)            33          ['dropout_255[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 2)            0           ['dense_263[0][0]',
#                                                                   'dense_267[0][0]']
#
#  ds_1 (Dense)                   (None, 4)            12          ['concatenate_14[0][0]']
#
#  ds_4 (Dense)                   (None, 1)            5           ['ds_1[0][0]']
#
# ==================================================================================================
# Total params: 292,403
# Trainable params: 17
# Non-trainable params: 292,386
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[452], line 79
#      75 stacked_model = define_stacked_model(members)
#      76 #print(X_train_embedding_full.shape, X_train_pt5_full.shape)
#      77 # fit_stacked_model(stacked_model, x_test, y_test)
#      78 #st_history = stacked_model.fit([X_train_embedding_full, X_train_embedding_full, X_train_embedding_full, X_train_embedding_full, X_train_embedding_full, X_train_pt5_full, X_train_pt5_full, X_train_pt5_full, X_train_pt5_full, X_train_pt5_full],y_train, epochs=10, verbose=1)
# ---> 79 st_history = stacked_model.fit([X_train_embedding_full, X_train_CNN], train_ST_labels, epochs=n_epo_stacked,
#      80                                verbose=1, validation_data=([X_test_full_ST_embedding, X_test_CNN], test_ST_labels))
#      82 # X_train_full_ST_embedding, X_test_full_ST_embedding
#      84 stacked_model.save_weights("../models/composite_model.h5")
#
# NameError: name 'X_train_embedding_full' is not defined

# %%
# load pretrained model
from tensorflow.keras.models import Sequential, load_model, Model
from sklearn.manifold import TSNE
import pandas as pd
import seaborn as sns
import h5py

#ANN_model = load_model("../models/composite_model.h5")

print(stacked_model.layers, len(stacked_model.layers))

# create truncated model
truncated_ANN_model = Model(inputs=stacked_model.input,
                                 outputs=stacked_model.get_layer(index=9).output)

hidden_features = truncated_ANN_model.predict([X_test_CNN])

print(hidden_features.shape)

df = pd.DataFrame()
df['Target'] = test_ST_labels
# Out:
# [<keras.engine.input_layer.InputLayer object at 0x7f97904f41c0>, <__main__.TokenAndPositionEmbedding object at 0x7f97904f4820>, <__main__.TransformerBlock object at 0x7f97904f45e0>, <keras.layers.pooling.GlobalAveragePooling1D object at 0x7f97904a6f70>, <keras.layers.core.dropout.Dropout object at 0x7f97206b4820>, <keras.layers.core.dense.Dense object at 0x7f972113baf0>, <keras.layers.core.dropout.Dropout object at 0x7f97806e3e50>, <keras.layers.core.dense.Dense object at 0x7f97aa46bd90>, <keras.layers.merge.Concatenate object at 0x7f9792ef8100>, <keras.layers.core.dense.Dense object at 0x7f9792ef8220>, <keras.layers.core.dense.Dense object at 0x7f97806f3a00>] 11
# (446, 4)

# %%
m = TSNE() #learning_rate = 10, perplexity=30
tsne_features = m.fit_transform(hidden_features)
df['Dimension-1'] = tsne_features[:,0]
df['Dimension-2'] = tsne_features[:,1]

sns.scatterplot(x="Dimension-1", y="Dimension-2", hue='Target',data=df)
plt.tick_params(top=False,
               bottom=False,
               left=False,
               right=False,
               labelleft=False,
               labelbottom=False)

# plt.axis('off')
# plt.set_xlabel('Subplot 1')
plt.legend().set_visible(False)
filename = "TSNE_ANN_protT5.png"
plt.savefig(filename,dpi=1600,bbox_inches='tight')
plt.show()
# Out:
# /home/anupkumar/anaconda3/envs/succsite/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/anupkumar/anaconda3/envs/succsite/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
from umap import UMAP
from matplotlib.pyplot import figure

figsize = (8, 8)
figure(figsize=figsize, dpi=150)

n_colors = 10

n_neighbors = 30
min_dist= 0.09

n_components=2

metric='euclidean'

umap_2d = UMAP(n_components=n_components, n_neighbors=n_neighbors, min_dist=min_dist, init='random', random_state=0)

#tsne_features = m.fit_transform(hidden_features)

#df['Dimension-1'] = tsne_features[:,0]
#df['Dimension-2'] = tsne_features[:,1]

proj_2d = umap_2d.fit_transform(hidden_features)

df_umap = pd.DataFrame()

df_umap["comp-1"] = proj_2d[:,0]
df_umap["comp-2"] = proj_2d[:,1]

sns.scatterplot(x="comp-1", y="comp-2", hue=test_ST_labels, data=df_umap).set(title="UMAP projection") #palette=sns.color_palette("hls", n_colors)
# Out:
# [Text(0.5, 1.0, 'UMAP projection')]
