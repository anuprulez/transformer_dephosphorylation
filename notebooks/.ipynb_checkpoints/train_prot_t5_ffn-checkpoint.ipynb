# %%
from keras.models import Model
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate

import pandas as pd
import tqdm
import h5py
from Bio import SeqIO

import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# import keras functions
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Input, Flatten, LSTM, Dropout, Bidirectional, GRU, SpatialDropout1D
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import EarlyStopping

# performance matrices
from sklearn.metrics import confusion_matrix, matthews_corrcoef, accuracy_score

# plots
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape, Lambda, LeakyReLU
from keras.layers import Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint
import numpy as np
from Bio import SeqIO
from numpy import array
from numpy import argmax
from sklearn.model_selection import train_test_split
from keras.layers.embeddings import Embedding
from keras import backend as K
from keras.backend import expand_dims
import matplotlib.pyplot as plt
from keras.regularizers import l1, l2

from tensorflow.keras import backend as K
from tensorflow.keras.layers import MultiHeadAttention, LayerNormalization, Layer, GlobalAveragePooling1D, Input, GlobalAveragePooling2D

# %%
def plot_save(history, filename):
    # learning curves of model accuracy
    plt.plot(history.history['accuracy'], label='train_acc')
    plt.plot(history.history['val_accuracy'], label='val_acc')
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['auc_roc'], label='Train AUC')
    plt.plot(history.history['val_auc_roc'], label='Val AUC')
    plt.legend()
    plt.savefig(filename)
    plt.show()
    
def plot(history):
    # learning curves of model accuracy
    plt.plot(history.history['accuracy'], label='train_acc')
    plt.plot(history.history['val_accuracy'], label='val_acc')
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['auc_roc'], label='Train AUC')
    plt.plot(history.history['val_auc_roc'], label='Val AUC')
    plt.legend()
    plt.show()

# %%
def read_h5(path):
    hf = h5py.File(path, 'r')
    mat = np.array(hf["embedding"])
    hf.close()
    return mat

# %%
test_positive_ST_embedding_pos = read_h5("../embeddings/test_positive_ST_embedding.h5")
test_negative_ST_embedding_pos = read_h5("../embeddings/test_negative_ST_embedding.h5")

# %%
test_positive_ST_labels = np.ones(test_positive_ST_embedding_pos.shape[0])
test_negative_ST_labels = np.zeros(test_negative_ST_embedding_pos.shape[0])

test_ST_labels = np.concatenate((test_positive_ST_labels, test_negative_ST_labels), axis = 0)
X_test_full_ST_embedding = np.vstack((test_positive_ST_embedding_pos, test_negative_ST_embedding_pos))

# %%
train_positive_ST_embedding_pos = read_h5("../embeddings/train_positive_ST_embedding.h5")
train_negative_ST_embedding_pos = read_h5("../embeddings/train_negative_ST_embedding.h5")

# %%
train_positive_ST_labels = np.ones(train_positive_ST_embedding_pos.shape[0])
train_negative_ST_labels = np.zeros(train_negative_ST_embedding_pos.shape[0])

train_ST_labels = np.concatenate((train_positive_ST_labels, train_negative_ST_labels), axis = 0)
X_train_full_ST_embedding = np.vstack((train_positive_ST_embedding_pos, train_negative_ST_embedding_pos))

# %%
X_train_full_ST_embedding.shape, train_ST_labels.shape,  X_test_full_ST_embedding.shape, test_ST_labels.shape
# Out:
# ((1779, 1024), (1779,), (446, 1024), (446,))

# %%
def get_input_for_embedding(fasta_file):
    # This is returning just integers to feed to embedding layer
    
    encodings = []
    
    # define universe of possible input values
    alphabet = 'ARNDCQEGHILKMFPSTWYV-'
    
    # define a mapping of chars to integers
    char_to_int = dict((c, i) for i, c in enumerate(alphabet))
    int_to_char = dict((i, c) for i, c in enumerate(alphabet))
    
    #print(char_to_int)
    
    for seq_record in SeqIO.parse(fasta_file, "fasta"):
        data = seq_record.seq
        try:
            integer_encoded = [char_to_int[char] for char in data]
        except:
            continue
        encodings.append(integer_encoded)
    encodings = np.array(encodings)
    print(encodings.shape)
    return encodings


# convert sequences to integer encoding, for embedding
test_positive_ST_CNN = get_input_for_embedding('../dataset/test_Pos_ST.fasta')
test_negative_ST_CNN = get_input_for_embedding('../dataset/test_Neg_ST.fasta')

train_positive_ST_CNN = get_input_for_embedding('../dataset/train_Pos_ST.fasta')
train_negative_ST_CNN = get_input_for_embedding('../dataset/train_Neg_ST.fasta')
# Out:
# (222, 33)
# (224, 33)
# (890, 33)
# (889, 33)

# %%
X_train_CNN = np.vstack((train_positive_ST_CNN, train_negative_ST_CNN))
X_test_CNN = np.vstack((test_positive_ST_CNN, test_negative_ST_CNN))
X_train_CNN.shape, X_test_CNN.shape, train_ST_labels.shape, test_ST_labels.shape
# Out:
# ((1779, 33), (446, 33), (1779,), (446,))

# %%
X_train_CNN, train_ST_labels
# Out:
# (array([[ 2, 18, 16, ..., 15, 14, 15],
#         [15,  7, 12, ...,  1, 16,  5],
#         [ 5, 14,  5, ..., 15, 16, 18],
#         ...,
#         [ 0, 14, 10, ..., 19, 15,  7],
#         [ 8,  0, 15, ...,  1, 10, 10],
#         [ 3,  0, 10, ...,  3, 18, 11]]),
#  array([1., 1., 1., ..., 0., 0., 0.]))

# %%
# Pretraining with Phosphorylation dataset

# S
pre_test_positive_S_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/test_pos_S.fasta')
pre_test_negative_S_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/test_neg_S.fasta')

pre_train_positive_S_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/train_pos_S.fasta')
pre_train_negative_S_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/train_neg_S.fasta')

# T
pre_test_positive_T_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/test_pos_T.fasta')
pre_test_negative_T_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/test_neg_T.fasta')

pre_train_positive_T_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/train_pos_T.fasta')
pre_train_negative_T_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/train_neg_T.fasta')


pre_test_pos_ST_CNN = np.vstack((pre_test_positive_S_CNN, pre_test_positive_T_CNN))
pre_test_neg_ST_CNN = np.vstack((pre_test_negative_S_CNN, pre_test_negative_T_CNN))

pre_train_pos_ST_CNN = np.vstack((pre_train_positive_S_CNN, pre_train_positive_T_CNN))
pre_train_neg_ST_CNN = np.vstack((pre_train_negative_S_CNN, pre_train_negative_T_CNN))
# Out:
# (3367, 33)
# (3367, 33)
# (13465, 33)
# (13461, 33)
# (856, 33)
# (858, 33)
# (3420, 33)
# (3421, 33)

# %%
pre_test_pos_ST_CNN.shape, pre_test_neg_ST_CNN.shape, pre_train_pos_ST_CNN.shape, pre_train_neg_ST_CNN.shape
# Out:
# ((4223, 33), (4225, 33), (16885, 33), (16882, 33))

# %%
pre_test_ST = np.vstack((pre_test_pos_ST_CNN, pre_test_neg_ST_CNN))

pre_test_positive_ST_labels = np.ones(pre_test_pos_ST_CNN.shape[0])
pre_test_negative_ST_labels = np.zeros(pre_test_neg_ST_CNN.shape[0])

pre_test_ST_labels = np.concatenate((pre_test_positive_ST_labels, pre_test_negative_ST_labels), axis = 0)
pre_test_ST.shape, pre_test_ST_labels.shape
# Out:
# ((8448, 33), (8448,))

# %%
pre_train_ST = np.vstack((pre_train_pos_ST_CNN, pre_train_neg_ST_CNN))

pre_train_positive_ST_labels = np.ones(pre_train_pos_ST_CNN.shape[0])
pre_train_negative_ST_labels = np.zeros(pre_train_neg_ST_CNN.shape[0])

pre_train_ST_labels = np.concatenate((pre_train_positive_ST_labels, pre_train_negative_ST_labels), axis = 0)
pre_train_ST.shape, pre_train_ST_labels.shape
# Out:
# ((33767, 33), (33767,))

# %%
### Assemble dataset for pretraining CNN and Transformer from Phophosite_org

# Pretraining with Phosphosite ORG dataset

# S
pre_test_positive_S_CNN_ORG = get_input_for_embedding('../dataset/phosphosite_org/test_pos_S.fasta')
pre_test_negative_S_CNN_ORG = get_input_for_embedding('../dataset/phosphosite_org/test_neg_S.fasta')

pre_train_positive_S_CNN_ORG = get_input_for_embedding('../dataset/phosphosite_org/train_pos_S.fasta')
pre_train_negative_S_CNN_ORG = get_input_for_embedding('../dataset/phosphosite_org/train_neg_S.fasta')

# T
pre_test_positive_T_CNN_ORG = get_input_for_embedding('../dataset/phosphosite_org/test_pos_T.fasta')
pre_test_negative_T_CNN_ORG = get_input_for_embedding('../dataset/phosphosite_org/test_neg_T.fasta')

pre_train_positive_T_CNN_ORG = get_input_for_embedding('../dataset/phosphosite_org/train_pos_T.fasta')
pre_train_negative_T_CNN_ORG = get_input_for_embedding('../dataset/phosphosite_org/train_neg_T.fasta')


pre_test_pos_ST_CNN_ORG = np.vstack((pre_test_positive_S_CNN_ORG, pre_test_positive_T_CNN_ORG))
pre_test_neg_ST_CNN_ORG = np.vstack((pre_test_negative_S_CNN_ORG, pre_test_negative_T_CNN_ORG))

pre_train_pos_ST_CNN_ORG = np.vstack((pre_train_positive_S_CNN_ORG, pre_train_positive_T_CNN_ORG))
pre_train_neg_ST_CNN_ORG = np.vstack((pre_train_negative_S_CNN_ORG, pre_train_negative_T_CNN_ORG))


pre_test_ST_CNN_ORG = np.vstack((pre_test_pos_ST_CNN_ORG, pre_test_neg_ST_CNN_ORG))
pre_train_ST_CNN_ORG = np.vstack((pre_train_pos_ST_CNN_ORG, pre_train_neg_ST_CNN_ORG))
pre_test_ST_CNN_ORG.shape, pre_train_ST_CNN_ORG.shape
# Out:
# (24736, 33)
# (24738, 33)
# (98936, 33)
# (98933, 33)
# (10572, 33)
# (10573, 33)
# (42286, 33)
# (42284, 33)
# ((70619, 33), (282439, 33))

# %%
pre_test_positive_ST_ORG_labels = np.ones(pre_test_pos_ST_CNN_ORG.shape[0])
pre_test_negative_ST_ORG_labels = np.zeros(pre_test_neg_ST_CNN_ORG.shape[0])

pre_test_ST_ORG_labels = np.concatenate((pre_test_positive_ST_ORG_labels, pre_test_negative_ST_ORG_labels), axis = 0)
pre_test_ST_CNN_ORG.shape, pre_test_ST_ORG_labels.shape
# Out:
# ((70619, 33), (70619,))

# %%
pre_train_positive_ST_ORG_labels = np.ones(pre_train_pos_ST_CNN_ORG.shape[0])
pre_train_negative_ST_ORG_labels = np.zeros(pre_train_neg_ST_CNN_ORG.shape[0])

pre_train_ST_ORG_labels = np.concatenate((pre_train_positive_ST_ORG_labels, pre_train_negative_ST_ORG_labels), axis = 0)
pre_train_ST_CNN_ORG.shape, pre_train_ST_ORG_labels.shape
# Out:
# ((282439, 33), (282439,))

# %%
### Assemble dataset for pretraining CNN and Transformer from DBPAF

# Pretraining with Phosphosite DBPAF dataset

# S
pre_test_positive_S_CNN_DBPAF = get_input_for_embedding('../dataset/dbpaf/test_pos_S.fasta')
pre_test_negative_S_CNN_DBPAF = get_input_for_embedding('../dataset/dbpaf/test_neg_S.fasta')

pre_train_positive_S_CNN_DBPAF = get_input_for_embedding('../dataset/dbpaf/train_pos_S.fasta')
pre_train_negative_S_CNN_DBPAF = get_input_for_embedding('../dataset/dbpaf/train_neg_S.fasta')

# T
pre_test_positive_T_CNN_DBPAF = get_input_for_embedding('../dataset/dbpaf/test_pos_T.fasta')
pre_test_negative_T_CNN_DBPAF = get_input_for_embedding('../dataset/dbpaf/test_neg_T.fasta')

pre_train_positive_T_CNN_DBPAF = get_input_for_embedding('../dataset/dbpaf/train_pos_T.fasta')
pre_train_negative_T_CNN_DBPAF = get_input_for_embedding('../dataset/dbpaf/train_neg_T.fasta')


pre_test_pos_ST_CNN_DBPAF = np.vstack((pre_test_positive_S_CNN_DBPAF, pre_test_positive_T_CNN_DBPAF))
pre_test_neg_ST_CNN_DBPAF = np.vstack((pre_test_negative_S_CNN_DBPAF, pre_test_negative_T_CNN_DBPAF))

pre_train_pos_ST_CNN_DBPAF = np.vstack((pre_train_positive_S_CNN_DBPAF, pre_train_positive_T_CNN_DBPAF))
pre_train_neg_ST_CNN_DBPAF = np.vstack((pre_train_negative_S_CNN_DBPAF, pre_train_negative_T_CNN_DBPAF))


pre_test_ST_CNN_DBPAF = np.vstack((pre_test_pos_ST_CNN_DBPAF, pre_test_neg_ST_CNN_DBPAF))
pre_train_ST_CNN_DBPAF = np.vstack((pre_train_pos_ST_CNN_DBPAF, pre_train_neg_ST_CNN_DBPAF))
pre_test_ST_CNN_DBPAF.shape, pre_train_ST_CNN_DBPAF.shape
# Out:
# (25597, 33)
# (25595, 33)
# (102385, 33)
# (102362, 33)
# (11037, 33)
# (11037, 33)
# (44150, 33)
# (44137, 33)
# ((73266, 33), (293034, 33))

# %%
pre_test_positive_ST_DBPAF_labels = np.ones(pre_test_pos_ST_CNN_DBPAF.shape[0])
pre_test_negative_ST_DBPAF_labels = np.zeros(pre_test_neg_ST_CNN_DBPAF.shape[0])

pre_test_ST_DBPAF_labels = np.concatenate((pre_test_positive_ST_DBPAF_labels, pre_test_negative_ST_DBPAF_labels), axis = 0)
pre_test_ST_CNN_DBPAF.shape, pre_test_ST_DBPAF_labels.shape
# Out:
# ((73266, 33), (73266,))

# %%
pre_train_positive_ST_DBPAF_labels = np.ones(pre_train_pos_ST_CNN_DBPAF.shape[0])
pre_train_negative_ST_DBPAF_labels = np.zeros(pre_train_neg_ST_CNN_DBPAF.shape[0])

pre_train_ST_DBPAF_labels = np.concatenate((pre_train_positive_ST_DBPAF_labels, pre_train_negative_ST_DBPAF_labels), axis = 0)
pre_train_ST_CNN_DBPAF.shape, pre_train_ST_DBPAF_labels.shape
# Out:
# ((293034, 33), (293034,))

# %%
##### Combine Phosphosite ORG with DBPAF ELM

pre_test_ST_CNN = np.vstack((pre_test_ST_CNN_ORG, pre_test_ST_CNN_DBPAF))
pre_test_ST_CNN_labels = np.concatenate((pre_test_ST_ORG_labels, pre_test_ST_DBPAF_labels), axis = 0)
pre_test_ST_CNN.shape, pre_test_ST_CNN_labels.shape
# Out:
# ((143885, 33), (143885,))

# %%
pre_train_ST_CNN = np.vstack((pre_train_ST_CNN_ORG, pre_train_ST_CNN_DBPAF))
pre_train_ST_CNN_labels = np.concatenate((pre_train_ST_ORG_labels, pre_train_ST_DBPAF_labels), axis = 0)
pre_train_ST_CNN.shape, pre_train_ST_CNN_labels.shape
# Out:
# ((575473, 33), (575473,))

# %%
### Assemble dataset for pretraining embeddings

pre_test_positive_S_embedding = read_h5("../embeddings/phospho.elm/test_positive_S_embedding.h5")
pre_test_negative_S_embedding = read_h5("../embeddings/phospho.elm/test_negative_S_embedding.h5")

pre_train_positive_S_embedding = read_h5("../embeddings/phospho.elm/train_positive_S_embedding.h5")
pre_train_negative_S_embedding = read_h5("../embeddings/phospho.elm/train_negative_S_embedding.h5")

pre_test_positive_T_embedding = read_h5("../embeddings/phospho.elm/test_positive_T_embedding.h5")
pre_test_negative_T_embedding = read_h5("../embeddings/phospho.elm/test_negative_T_embedding.h5")

pre_train_positive_T_embedding = read_h5("../embeddings/phospho.elm/train_positive_T_embedding.h5")
pre_train_negative_T_embedding = read_h5("../embeddings/phospho.elm/train_negative_T_embedding.h5")

pre_test_positive_S_embedding.shape, pre_test_negative_S_embedding.shape, pre_train_positive_S_embedding.shape, pre_train_negative_S_embedding.shape
# Out:
# ((3367, 1024), (3369, 1024), (13466, 1024), (13468, 1024))

# %%
pre_test_positive_T_embedding.shape, pre_test_negative_T_embedding.shape, pre_train_positive_T_embedding.shape, pre_train_negative_T_embedding.shape
# Out:
# ((856, 1024), (858, 1024), (3420, 1024), (3422, 1024))

# %%
pre_test_pos_ST_Embed = np.vstack((pre_test_positive_S_embedding, pre_test_positive_T_embedding))
pre_test_neg_ST_Embed = np.vstack((pre_test_negative_S_embedding, pre_test_negative_T_embedding))

pre_train_pos_ST_Embed = np.vstack((pre_train_positive_S_embedding, pre_train_positive_T_embedding))
pre_train_neg_ST_Embed = np.vstack((pre_train_negative_S_embedding, pre_train_negative_T_embedding))

pre_test_pos_ST_Embed.shape, pre_test_neg_ST_Embed.shape, pre_train_pos_ST_Embed.shape, pre_train_neg_ST_Embed.shape
# Out:
# ((4223, 1024), (4227, 1024), (16886, 1024), (16890, 1024))

# %%
pre_train_ST_Embed = np.vstack((pre_train_pos_ST_Embed, pre_train_neg_ST_Embed))

pre_train_positive_ST_Embed_labels = np.ones(pre_train_pos_ST_Embed.shape[0])
pre_train_negative_ST_Embed_labels = np.zeros(pre_train_neg_ST_Embed.shape[0])

pre_train_ST_labels_Embed = np.concatenate((pre_train_positive_ST_Embed_labels, pre_train_negative_ST_Embed_labels), axis = 0)
pre_train_ST_Embed.shape, pre_train_ST_labels_Embed.shape
# Out:
# ((33776, 1024), (33776,))

# %%
pre_test_ST_Embed = np.vstack((pre_test_pos_ST_Embed, pre_test_neg_ST_Embed))

pre_test_positive_ST_Embed_labels = np.ones(pre_test_pos_ST_Embed.shape[0])
pre_test_negative_ST_Embed_labels = np.zeros(pre_test_neg_ST_Embed.shape[0])

pre_test_ST_labels_Embed = np.concatenate((pre_test_positive_ST_Embed_labels, pre_test_negative_ST_Embed_labels), axis = 0)
pre_test_ST_Embed.shape, pre_test_ST_labels_Embed.shape
# Out:
# ((8450, 1024), (8450,))

# %%
# Pretraining CNN

def CNN_model():
    model = Sequential()
    model.add(Embedding(256, 21, input_length=33))
    model.add(Lambda(lambda x: tf.expand_dims(x, 3)))
    model.add(Conv2D(128, kernel_size=(16, 3), activation = 'relu', kernel_initializer='he_normal', padding = 'VALID'))
    model.add(Dropout(0.4))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(256, kernel_size=(8, 3), activation = 'relu', kernel_initializer='he_normal', padding = 'VALID'))
    model.add(Dropout(0.4))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_normal'))
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    return model


n_epo_cnn = 40

metrics = ['accuracy', tf.keras.metrics.AUC(name='auc_roc')]

model_A = CNN_model()
model_A.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)

#model_A.summary()

print("PRE Training CNN model...")

checkpointer = ModelCheckpoint(filepath="../models/pre_model_A.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)

pre_history_A = model_A.fit(pre_train_ST_CNN, pre_train_ST_CNN_labels, batch_size=1024, epochs=n_epo_cnn, verbose=1, callbacks=[checkpointer],
    validation_data=(pre_test_ST_CNN, pre_test_ST_CNN_labels))
    
#pre_history_A = model_A.fit(pre_train_ST, pre_train_ST_labels, batch_size=256, epochs=n_epo_cnn, verbose=1, callbacks=[checkpointer],
#    validation_data=(pre_test_ST, pre_test_ST_labels))

# Save model
#model_A.save_weights('../models/pre_model_A.h5')
# Out:
# PRE Training CNN model...
# Epoch 1/40
# 562/562 [==============================] - 35s 60ms/step - loss: 0.6172 - accuracy: 0.6551 - auc_roc: 0.7144 - val_loss: 0.6135 - val_accuracy: 0.6765 - val_auc_roc: 0.7424
# Epoch 2/40
# 562/562 [==============================] - 33s 58ms/step - loss: 0.5991 - accuracy: 0.6753 - auc_roc: 0.7392 - val_loss: 0.6076 - val_accuracy: 0.6822 - val_auc_roc: 0.7494
# Epoch 3/40
# 562/562 [==============================] - 34s 60ms/step - loss: 0.5945 - accuracy: 0.6795 - auc_roc: 0.7447 - val_loss: 0.6006 - val_accuracy: 0.6839 - val_auc_roc: 0.7524
# Epoch 4/40
# 562/562 [==============================] - 36s 64ms/step - loss: 0.5915 - accuracy: 0.6822 - auc_roc: 0.7483 - val_loss: 0.6036 - val_accuracy: 0.6828 - val_auc_roc: 0.7527
# Epoch 5/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5887 - accuracy: 0.6843 - auc_roc: 0.7515 - val_loss: 0.5955 - val_accuracy: 0.6856 - val_auc_roc: 0.7537
# Epoch 6/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5867 - accuracy: 0.6853 - auc_roc: 0.7537 - val_loss: 0.5938 - val_accuracy: 0.6884 - val_auc_roc: 0.7572
# Epoch 7/40
# 562/562 [==============================] - 36s 64ms/step - loss: 0.5842 - accuracy: 0.6882 - auc_roc: 0.7564 - val_loss: 0.5905 - val_accuracy: 0.6881 - val_auc_roc: 0.7563
# Epoch 8/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5822 - accuracy: 0.6898 - auc_roc: 0.7585 - val_loss: 0.5909 - val_accuracy: 0.6905 - val_auc_roc: 0.7592
# Epoch 9/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5799 - accuracy: 0.6921 - auc_roc: 0.7610 - val_loss: 0.5882 - val_accuracy: 0.6911 - val_auc_roc: 0.7601
# Epoch 10/40
# 562/562 [==============================] - 33s 58ms/step - loss: 0.5782 - accuracy: 0.6935 - auc_roc: 0.7628 - val_loss: 0.5840 - val_accuracy: 0.6919 - val_auc_roc: 0.7610
# Epoch 11/40
# 562/562 [==============================] - 36s 63ms/step - loss: 0.5759 - accuracy: 0.6953 - auc_roc: 0.7650 - val_loss: 0.5829 - val_accuracy: 0.6918 - val_auc_roc: 0.7616
# Epoch 12/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5737 - accuracy: 0.6969 - auc_roc: 0.7672 - val_loss: 0.5811 - val_accuracy: 0.6933 - val_auc_roc: 0.7617
# Epoch 13/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5714 - accuracy: 0.6985 - auc_roc: 0.7694 - val_loss: 0.5846 - val_accuracy: 0.6921 - val_auc_roc: 0.7606
# Epoch 14/40
# 562/562 [==============================] - 36s 64ms/step - loss: 0.5690 - accuracy: 0.7006 - auc_roc: 0.7717 - val_loss: 0.5796 - val_accuracy: 0.6945 - val_auc_roc: 0.7637
# Epoch 15/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5673 - accuracy: 0.7011 - auc_roc: 0.7734 - val_loss: 0.5839 - val_accuracy: 0.6949 - val_auc_roc: 0.7642
# Epoch 16/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5652 - accuracy: 0.7027 - auc_roc: 0.7753 - val_loss: 0.5800 - val_accuracy: 0.6941 - val_auc_roc: 0.7643
# Epoch 17/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5625 - accuracy: 0.7055 - auc_roc: 0.7781 - val_loss: 0.5786 - val_accuracy: 0.6958 - val_auc_roc: 0.7646
# Epoch 18/40
# 562/562 [==============================] - 36s 64ms/step - loss: 0.5602 - accuracy: 0.7069 - auc_roc: 0.7801 - val_loss: 0.5793 - val_accuracy: 0.6960 - val_auc_roc: 0.7651
# Epoch 19/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5572 - accuracy: 0.7092 - auc_roc: 0.7828 - val_loss: 0.5777 - val_accuracy: 0.6957 - val_auc_roc: 0.7659
# Epoch 20/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5544 - accuracy: 0.7110 - auc_roc: 0.7853 - val_loss: 0.5760 - val_accuracy: 0.6956 - val_auc_roc: 0.7662
# Epoch 21/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5519 - accuracy: 0.7130 - auc_roc: 0.7875 - val_loss: 0.5739 - val_accuracy: 0.6973 - val_auc_roc: 0.7679
# Epoch 22/40
# 562/562 [==============================] - 36s 64ms/step - loss: 0.5491 - accuracy: 0.7148 - auc_roc: 0.7902 - val_loss: 0.5735 - val_accuracy: 0.6987 - val_auc_roc: 0.7680
# Epoch 23/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5466 - accuracy: 0.7170 - auc_roc: 0.7923 - val_loss: 0.5735 - val_accuracy: 0.6993 - val_auc_roc: 0.7692
# Epoch 24/40
# 562/562 [==============================] - 33s 58ms/step - loss: 0.5435 - accuracy: 0.7199 - auc_roc: 0.7953 - val_loss: 0.5732 - val_accuracy: 0.6999 - val_auc_roc: 0.7690
# Epoch 25/40
# 562/562 [==============================] - 36s 63ms/step - loss: 0.5406 - accuracy: 0.7216 - auc_roc: 0.7974 - val_loss: 0.5710 - val_accuracy: 0.7006 - val_auc_roc: 0.7699
# Epoch 26/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5377 - accuracy: 0.7240 - auc_roc: 0.8003 - val_loss: 0.5720 - val_accuracy: 0.6999 - val_auc_roc: 0.7706
# Epoch 27/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5353 - accuracy: 0.7261 - auc_roc: 0.8024 - val_loss: 0.5688 - val_accuracy: 0.7019 - val_auc_roc: 0.7715
# Epoch 28/40
# 562/562 [==============================] - 33s 58ms/step - loss: 0.5316 - accuracy: 0.7282 - auc_roc: 0.8054 - val_loss: 0.5676 - val_accuracy: 0.7038 - val_auc_roc: 0.7725
# Epoch 29/40
# 562/562 [==============================] - 36s 64ms/step - loss: 0.5290 - accuracy: 0.7303 - auc_roc: 0.8077 - val_loss: 0.5678 - val_accuracy: 0.7024 - val_auc_roc: 0.7725
# Epoch 30/40
# 562/562 [==============================] - 33s 58ms/step - loss: 0.5269 - accuracy: 0.7320 - auc_roc: 0.8094 - val_loss: 0.5666 - val_accuracy: 0.7029 - val_auc_roc: 0.7731
# Epoch 31/40
# 562/562 [==============================] - 33s 58ms/step - loss: 0.5236 - accuracy: 0.7348 - auc_roc: 0.8123 - val_loss: 0.5669 - val_accuracy: 0.7039 - val_auc_roc: 0.7738
# Epoch 32/40
# 562/562 [==============================] - 40s 71ms/step - loss: 0.5218 - accuracy: 0.7363 - auc_roc: 0.8137 - val_loss: 0.5669 - val_accuracy: 0.7047 - val_auc_roc: 0.7738
# Epoch 33/40
# 562/562 [==============================] - 33s 58ms/step - loss: 0.5188 - accuracy: 0.7383 - auc_roc: 0.8164 - val_loss: 0.5688 - val_accuracy: 0.7040 - val_auc_roc: 0.7731
# Epoch 34/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5171 - accuracy: 0.7393 - auc_roc: 0.8178 - val_loss: 0.5654 - val_accuracy: 0.7056 - val_auc_roc: 0.7746
# Epoch 35/40
# 562/562 [==============================] - 33s 58ms/step - loss: 0.5146 - accuracy: 0.7412 - auc_roc: 0.8199 - val_loss: 0.5654 - val_accuracy: 0.7059 - val_auc_roc: 0.7748
# Epoch 36/40
# 562/562 [==============================] - 35s 63ms/step - loss: 0.5127 - accuracy: 0.7432 - auc_roc: 0.8213 - val_loss: 0.5649 - val_accuracy: 0.7059 - val_auc_roc: 0.7753
# Epoch 37/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5103 - accuracy: 0.7447 - auc_roc: 0.8230 - val_loss: 0.5631 - val_accuracy: 0.7073 - val_auc_roc: 0.7762
# Epoch 38/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5085 - accuracy: 0.7461 - auc_roc: 0.8244 - val_loss: 0.5638 - val_accuracy: 0.7089 - val_auc_roc: 0.7766
# Epoch 39/40
# 562/562 [==============================] - 35s 61ms/step - loss: 0.5060 - accuracy: 0.7478 - auc_roc: 0.8266 - val_loss: 0.5639 - val_accuracy: 0.7082 - val_auc_roc: 0.7764
# Epoch 40/40
# 562/562 [==============================] - 34s 61ms/step - loss: 0.5046 - accuracy: 0.7485 - auc_roc: 0.8276 - val_loss: 0.5618 - val_accuracy: 0.7096 - val_auc_roc: 0.7768

# %%
loaded_model_A = CNN_model()
loaded_model_A.load_weights("../models/pre_model_A.h5")
y_pred = loaded_model_A.predict(pre_test_ST_CNN).reshape(pre_test_ST_CNN_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
pre_test_ST_CNN_labels = np.array(pre_test_ST_CNN_labels)
y_pred = np.array(y_pred)


# pre_test_ST_CNN, pre_test_ST_CNN_labels

cm = confusion_matrix(pre_test_ST_CNN_labels, y_pred)
mcc = matthews_corrcoef(pre_test_ST_CNN_labels, y_pred)
acc = accuracy_score(pre_test_ST_CNN_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

#save plot
plot(pre_history_A)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
#  Acc: 0.7096361677728742, MCC: 0.4236363003026613, SN:0.7812126435183898, SP:0.6380606869327106,
#  CM:[[45904 26039]
#  [15740 56202]]

# %%
########### Model B

def prot_t5_model():
    # prot_t5
    M1_input = Input(shape=(1024,))
    M1_dense_1 = Dense(256)(M1_input)
    drop_out = Dropout(0.4)(M1_dense_1)
    M1_dense_2 = Dense(128, activation='relu')(drop_out)
    drop_out = Dropout(0.4)(M1_dense_2)
    M1_dense_3 = Dense(1, activation = 'sigmoid')(drop_out)
    model = Model(inputs=M1_input, outputs=M1_dense_3)
    '''model = Sequential()
    model.add(tf.keras.layers.Reshape((32, 32), input_shape=(1024,)))
    model.add(Lambda(lambda x: tf.expand_dims(x, 3)))
    model.add(Conv2D(256, kernel_size=(17, 3), activation = 'relu', kernel_initializer='he_normal', padding = 'VALID'))
    model.add(Dropout(0.4))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_normal'))
    model.add(Dropout(0.4))
    model.add(Dense(32, activation='relu', kernel_initializer='he_normal'))
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))'''
    return model

print("Pre Training Embedding model...")

metrics = ['accuracy', tf.keras.metrics.AUC(name='auc_roc')]
n_epo_embed = 20
model_B = prot_t5_model()
model_B.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3, mode='auto')

checkpointer = ModelCheckpoint(filepath="../models/pre_model_B.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)

history_B = model_B.fit(pre_train_ST_Embed, pre_train_ST_labels_Embed, batch_size=256, epochs=n_epo_embed, verbose=1, 
                        callbacks=[checkpointer], validation_data=(pre_test_ST_Embed, pre_test_ST_labels_Embed))

# pre_train_ST_Embed.shape, pre_train_ST_labels_Embed.shape
# pre_test_ST_Embed.shape, pre_test_ST_labels_Embed.shape

plot(history_B)

print()

loaded_model_B = prot_t5_model()
loaded_model_B.load_weights("../models/pre_model_B.h5")
y_pred = loaded_model_B.predict(pre_test_ST_Embed).reshape(pre_test_ST_labels_Embed.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
pre_test_ST_labels_Embed = np.array(pre_test_ST_labels_Embed)
y_pred = np.array(y_pred)

cm = confusion_matrix(pre_test_ST_labels_Embed, y_pred)
mcc = matthews_corrcoef(pre_test_ST_labels_Embed, y_pred)
acc = accuracy_score(pre_test_ST_labels_Embed, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
# Pre Training Embedding model...
# Epoch 1/20
# 106/106 [==============================] - 2s 13ms/step - loss: 0.5433 - accuracy: 0.7355 - auc_roc: 0.8038 - val_loss: 0.5008 - val_accuracy: 0.7650 - val_auc_roc: 0.8377
# Epoch 2/20
# 106/106 [==============================] - 1s 8ms/step - loss: 0.5143 - accuracy: 0.7549 - auc_roc: 0.8265 - val_loss: 0.5002 - val_accuracy: 0.7620 - val_auc_roc: 0.8378
# Epoch 3/20
# 106/106 [==============================] - 1s 13ms/step - loss: 0.5040 - accuracy: 0.7600 - auc_roc: 0.8339 - val_loss: 0.4991 - val_accuracy: 0.7656 - val_auc_roc: 0.8414
# Epoch 4/20
# 106/106 [==============================] - 1s 11ms/step - loss: 0.4997 - accuracy: 0.7647 - auc_roc: 0.8373 - val_loss: 0.4982 - val_accuracy: 0.7703 - val_auc_roc: 0.8411
# Epoch 5/20
# 106/106 [==============================] - 1s 8ms/step - loss: 0.4947 - accuracy: 0.7651 - auc_roc: 0.8409 - val_loss: 0.4954 - val_accuracy: 0.7693 - val_auc_roc: 0.8414
# Epoch 6/20
# 106/106 [==============================] - 1s 8ms/step - loss: 0.4894 - accuracy: 0.7706 - auc_roc: 0.8442 - val_loss: 0.4989 - val_accuracy: 0.7657 - val_auc_roc: 0.8401
# Epoch 7/20
# 106/106 [==============================] - 1s 8ms/step - loss: 0.4830 - accuracy: 0.7728 - auc_roc: 0.8485 - val_loss: 0.5024 - val_accuracy: 0.7683 - val_auc_roc: 0.8408
# Epoch 8/20
# 106/106 [==============================] - 1s 10ms/step - loss: 0.4817 - accuracy: 0.7749 - auc_roc: 0.8494 - val_loss: 0.4997 - val_accuracy: 0.7726 - val_auc_roc: 0.8425
# Epoch 9/20
# 106/106 [==============================] - 1s 8ms/step - loss: 0.4774 - accuracy: 0.7778 - auc_roc: 0.8524 - val_loss: 0.4972 - val_accuracy: 0.7690 - val_auc_roc: 0.8407
# Epoch 10/20
# 106/106 [==============================] - 1s 10ms/step - loss: 0.4711 - accuracy: 0.7804 - auc_roc: 0.8564 - val_loss: 0.4993 - val_accuracy: 0.7738 - val_auc_roc: 0.8420
# Epoch 11/20
# 106/106 [==============================] - 1s 8ms/step - loss: 0.4704 - accuracy: 0.7817 - auc_roc: 0.8564 - val_loss: 0.5057 - val_accuracy: 0.7675 - val_auc_roc: 0.8416
# Epoch 12/20
# 106/106 [==============================] - 1s 8ms/step - loss: 0.4655 - accuracy: 0.7848 - auc_roc: 0.8597 - val_loss: 0.5047 - val_accuracy: 0.7598 - val_auc_roc: 0.8393
# Epoch 13/20
# 106/106 [==============================] - 1s 8ms/step - loss: 0.4631 - accuracy: 0.7881 - auc_roc: 0.8621 - val_loss: 0.5060 - val_accuracy: 0.7650 - val_auc_roc: 0.8377
# Epoch 14/20
# 106/106 [==============================] - 1s 9ms/step - loss: 0.4571 - accuracy: 0.7897 - auc_roc: 0.8652 - val_loss: 0.5062 - val_accuracy: 0.7692 - val_auc_roc: 0.8389
# Epoch 15/20
# 106/106 [==============================] - 1s 9ms/step - loss: 0.4558 - accuracy: 0.7901 - auc_roc: 0.8658 - val_loss: 0.5062 - val_accuracy: 0.7694 - val_auc_roc: 0.8376
# Epoch 16/20
# 106/106 [==============================] - 1s 9ms/step - loss: 0.4550 - accuracy: 0.7919 - auc_roc: 0.8669 - val_loss: 0.5099 - val_accuracy: 0.7660 - val_auc_roc: 0.8379
# Epoch 17/20
# 106/106 [==============================] - 1s 10ms/step - loss: 0.4498 - accuracy: 0.7925 - auc_roc: 0.8698 - val_loss: 0.5219 - val_accuracy: 0.7653 - val_auc_roc: 0.8374
# Epoch 18/20
# 106/106 [==============================] - 1s 9ms/step - loss: 0.4446 - accuracy: 0.7956 - auc_roc: 0.8726 - val_loss: 0.5091 - val_accuracy: 0.7726 - val_auc_roc: 0.8386
# Epoch 19/20
# 106/106 [==============================] - 1s 10ms/step - loss: 0.4409 - accuracy: 0.7980 - auc_roc: 0.8748 - val_loss: 0.5200 - val_accuracy: 0.7620 - val_auc_roc: 0.8333
# Epoch 20/20
# 106/106 [==============================] - 1s 10ms/step - loss: 0.4380 - accuracy: 0.7973 - auc_roc: 0.8767 - val_loss: 0.5221 - val_accuracy: 0.7641 - val_auc_roc: 0.8357
#  Acc: 0.7737529691211401, MCC: 0.547815259183534, SN:0.7567567567567568, SP:0.7907390917186109,
#  CM:[[2664  705]
#  [ 819 2548]]

# %%
# transformer based embedding model
class TransformerBlock(Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=rate)
        self.ffn = Sequential(
            [Dense(ff_dim, activation="relu"), Dense(2 * ff_dim, activation="relu"), Dense(embed_dim)]
        )
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)
        
    def get_config(self):
        config = super().get_config()
        return config

    def call(self, inputs, training):
        attn_output, attention_scores = self.att(inputs, inputs, inputs, return_attention_scores=True, training=training)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output), attention_scores


class TokenAndPositionEmbedding(Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb = Embedding(input_dim=vocab_size, output_dim=embed_dim, mask_zero=True)
        self.pos_emb = Embedding(input_dim=maxlen, output_dim=embed_dim, mask_zero=True)
        
    def get_config(self):
        config = super().get_config()
        return config

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions


def transformer_model():
    vocab_size = 21
    embed_dim = 128 #config["embedding_dim"]
    ff_dim = 128 #config["feed_forward_dim"]
    max_len = 33 #config["maximum_path_length"]
    dropout = 0.4 #config["dropout"]
    n_heads = 2

    inputs = Input(shape=(max_len,))
    embedding_layer = TokenAndPositionEmbedding(max_len, vocab_size, embed_dim)
    x = embedding_layer(inputs)
    transformer_block = TransformerBlock(embed_dim, n_heads, ff_dim)
    x, weights = transformer_block(x)
    x = GlobalAveragePooling1D()(x) #GlobalAveragePooling1D
    x = Dropout(dropout)(x)
    x = Dense(ff_dim, activation="relu")(x)
    x = Dropout(dropout)(x)
    outputs = Dense(1, activation="sigmoid")(x)
    return Model(inputs=inputs, outputs=[outputs])

# %%
# Pretraining transformer

n_epo_transformer = 40
model_C = transformer_model()
model_C.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)

#model_C.summary()

checkpointer = ModelCheckpoint(filepath="../models/pre_model_C.h5",
                                monitor = "val_accuracy",
                                verbose = 0,
                                save_weights_only=True,
                                save_best_only=True)

print("PRE Training Transformer model...")

#pre_history_C = model_C.fit(pre_train_ST, pre_train_ST_labels, batch_size=256, epochs=n_epo_transformer, verbose=1, callbacks=[checkpointer],
#    validation_data=(pre_test_ST, pre_test_ST_labels))

pre_history_C = model_C.fit(pre_train_ST_CNN, pre_train_ST_CNN_labels, batch_size=1024, epochs=n_epo_transformer, verbose=1, callbacks=[checkpointer],
    validation_data=(pre_test_ST_CNN, pre_test_ST_CNN_labels))

# pre_train_ST_CNN, pre_train_ST_CNN_labels, batch_size=256, epochs=n_epo_cnn, verbose=1, callbacks=[checkpointer],
# validation_data=(pre_test_ST_CNN, pre_test_ST_CNN_labels)

# Save model
#model_C.save_weights('../models/pre_model_C.h5')
# Out:
# PRE Training Transformer model...
# Epoch 1/40
# 562/562 [==============================] - 43s 65ms/step - loss: 0.6280 - accuracy: 0.6456 - auc_roc: 0.6993 - val_loss: 0.6034 - val_accuracy: 0.6699 - val_auc_roc: 0.7328
# Epoch 2/40
# 562/562 [==============================] - 25s 44ms/step - loss: 0.6080 - accuracy: 0.6661 - auc_roc: 0.7277 - val_loss: 0.6037 - val_accuracy: 0.6700 - val_auc_roc: 0.7372
# Epoch 3/40
# 562/562 [==============================] - 31s 55ms/step - loss: 0.6046 - accuracy: 0.6694 - auc_roc: 0.7320 - val_loss: 0.5992 - val_accuracy: 0.6751 - val_auc_roc: 0.7403
# Epoch 4/40
# 562/562 [==============================] - 31s 56ms/step - loss: 0.6020 - accuracy: 0.6722 - auc_roc: 0.7353 - val_loss: 0.5962 - val_accuracy: 0.6758 - val_auc_roc: 0.7417
# Epoch 5/40
# 562/562 [==============================] - 28s 50ms/step - loss: 0.6004 - accuracy: 0.6730 - auc_roc: 0.7372 - val_loss: 0.5958 - val_accuracy: 0.6775 - val_auc_roc: 0.7435
# Epoch 6/40
# 562/562 [==============================] - 27s 48ms/step - loss: 0.5989 - accuracy: 0.6754 - auc_roc: 0.7393 - val_loss: 0.5950 - val_accuracy: 0.6787 - val_auc_roc: 0.7450
# Epoch 7/40
# 562/562 [==============================] - 32s 57ms/step - loss: 0.5976 - accuracy: 0.6759 - auc_roc: 0.7408 - val_loss: 0.5980 - val_accuracy: 0.6725 - val_auc_roc: 0.7438
# Epoch 8/40
# 562/562 [==============================] - 34s 61ms/step - loss: 0.5960 - accuracy: 0.6775 - auc_roc: 0.7427 - val_loss: 0.5913 - val_accuracy: 0.6808 - val_auc_roc: 0.7477
# Epoch 9/40
# 562/562 [==============================] - 35s 63ms/step - loss: 0.5944 - accuracy: 0.6791 - auc_roc: 0.7447 - val_loss: 0.5930 - val_accuracy: 0.6787 - val_auc_roc: 0.7469
# Epoch 10/40
# 562/562 [==============================] - 33s 58ms/step - loss: 0.5934 - accuracy: 0.6805 - auc_roc: 0.7459 - val_loss: 0.5891 - val_accuracy: 0.6824 - val_auc_roc: 0.7504
# Epoch 11/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5926 - accuracy: 0.6803 - auc_roc: 0.7468 - val_loss: 0.5936 - val_accuracy: 0.6805 - val_auc_roc: 0.7505
# Epoch 12/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5920 - accuracy: 0.6814 - auc_roc: 0.7476 - val_loss: 0.5887 - val_accuracy: 0.6830 - val_auc_roc: 0.7511
# Epoch 13/40
# 562/562 [==============================] - 34s 61ms/step - loss: 0.5909 - accuracy: 0.6825 - auc_roc: 0.7487 - val_loss: 0.5894 - val_accuracy: 0.6812 - val_auc_roc: 0.7500
# Epoch 14/40
# 562/562 [==============================] - 32s 56ms/step - loss: 0.5907 - accuracy: 0.6825 - auc_roc: 0.7490 - val_loss: 0.5910 - val_accuracy: 0.6811 - val_auc_roc: 0.7515
# Epoch 15/40
# 562/562 [==============================] - 34s 60ms/step - loss: 0.5899 - accuracy: 0.6832 - auc_roc: 0.7498 - val_loss: 0.5876 - val_accuracy: 0.6837 - val_auc_roc: 0.7518
# Epoch 16/40
# 562/562 [==============================] - 34s 61ms/step - loss: 0.5892 - accuracy: 0.6835 - auc_roc: 0.7507 - val_loss: 0.5913 - val_accuracy: 0.6803 - val_auc_roc: 0.7521
# Epoch 17/40
# 562/562 [==============================] - 32s 58ms/step - loss: 0.5888 - accuracy: 0.6841 - auc_roc: 0.7512 - val_loss: 0.5881 - val_accuracy: 0.6829 - val_auc_roc: 0.7537
# Epoch 18/40
# 562/562 [==============================] - 34s 61ms/step - loss: 0.5882 - accuracy: 0.6847 - auc_roc: 0.7519 - val_loss: 0.5865 - val_accuracy: 0.6846 - val_auc_roc: 0.7535
# Epoch 19/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5875 - accuracy: 0.6857 - auc_roc: 0.7526 - val_loss: 0.5876 - val_accuracy: 0.6842 - val_auc_roc: 0.7521
# Epoch 20/40
# 562/562 [==============================] - 34s 60ms/step - loss: 0.5869 - accuracy: 0.6858 - auc_roc: 0.7533 - val_loss: 0.5870 - val_accuracy: 0.6853 - val_auc_roc: 0.7534
# Epoch 21/40
# 562/562 [==============================] - 33s 60ms/step - loss: 0.5863 - accuracy: 0.6870 - auc_roc: 0.7540 - val_loss: 0.5872 - val_accuracy: 0.6842 - val_auc_roc: 0.7525
# Epoch 22/40
# 562/562 [==============================] - 34s 61ms/step - loss: 0.5857 - accuracy: 0.6868 - auc_roc: 0.7546 - val_loss: 0.5841 - val_accuracy: 0.6861 - val_auc_roc: 0.7554
# Epoch 23/40
# 562/562 [==============================] - 35s 63ms/step - loss: 0.5853 - accuracy: 0.6872 - auc_roc: 0.7551 - val_loss: 0.5864 - val_accuracy: 0.6853 - val_auc_roc: 0.7540
# Epoch 24/40
# 562/562 [==============================] - 32s 57ms/step - loss: 0.5846 - accuracy: 0.6876 - auc_roc: 0.7558 - val_loss: 0.5856 - val_accuracy: 0.6860 - val_auc_roc: 0.7539
# Epoch 25/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5838 - accuracy: 0.6879 - auc_roc: 0.7566 - val_loss: 0.5873 - val_accuracy: 0.6825 - val_auc_roc: 0.7529
# Epoch 26/40
# 562/562 [==============================] - 34s 61ms/step - loss: 0.5833 - accuracy: 0.6885 - auc_roc: 0.7571 - val_loss: 0.5846 - val_accuracy: 0.6870 - val_auc_roc: 0.7552
# Epoch 27/40
# 562/562 [==============================] - 35s 62ms/step - loss: 0.5828 - accuracy: 0.6889 - auc_roc: 0.7577 - val_loss: 0.5840 - val_accuracy: 0.6862 - val_auc_roc: 0.7559
# Epoch 28/40
# 562/562 [==============================] - 32s 57ms/step - loss: 0.5826 - accuracy: 0.6895 - auc_roc: 0.7580 - val_loss: 0.5862 - val_accuracy: 0.6854 - val_auc_roc: 0.7553
# Epoch 29/40
# 562/562 [==============================] - 33s 58ms/step - loss: 0.5816 - accuracy: 0.6896 - auc_roc: 0.7589 - val_loss: 0.5848 - val_accuracy: 0.6858 - val_auc_roc: 0.7551
# Epoch 30/40
# 562/562 [==============================] - 34s 61ms/step - loss: 0.5811 - accuracy: 0.6904 - auc_roc: 0.7596 - val_loss: 0.5851 - val_accuracy: 0.6864 - val_auc_roc: 0.7556
# Epoch 31/40
# 562/562 [==============================] - 34s 60ms/step - loss: 0.5806 - accuracy: 0.6907 - auc_roc: 0.7600 - val_loss: 0.5848 - val_accuracy: 0.6858 - val_auc_roc: 0.7557
# Epoch 32/40
# 562/562 [==============================] - 32s 56ms/step - loss: 0.5799 - accuracy: 0.6913 - auc_roc: 0.7606 - val_loss: 0.5856 - val_accuracy: 0.6858 - val_auc_roc: 0.7554
# Epoch 33/40
# 562/562 [==============================] - 32s 58ms/step - loss: 0.5794 - accuracy: 0.6917 - auc_roc: 0.7612 - val_loss: 0.5848 - val_accuracy: 0.6858 - val_auc_roc: 0.7549
# Epoch 34/40
# 562/562 [==============================] - 34s 61ms/step - loss: 0.5788 - accuracy: 0.6918 - auc_roc: 0.7618 - val_loss: 0.5851 - val_accuracy: 0.6866 - val_auc_roc: 0.7548
# Epoch 35/40
# 562/562 [==============================] - 33s 59ms/step - loss: 0.5786 - accuracy: 0.6922 - auc_roc: 0.7620 - val_loss: 0.5855 - val_accuracy: 0.6861 - val_auc_roc: 0.7552
# Epoch 36/40
# 562/562 [==============================] - 33s 58ms/step - loss: 0.5781 - accuracy: 0.6924 - auc_roc: 0.7626 - val_loss: 0.5857 - val_accuracy: 0.6859 - val_auc_roc: 0.7567
# Epoch 37/40
# 562/562 [==============================] - 34s 60ms/step - loss: 0.5772 - accuracy: 0.6936 - auc_roc: 0.7635 - val_loss: 0.5839 - val_accuracy: 0.6868 - val_auc_roc: 0.7564
# Epoch 38/40
# 562/562 [==============================] - 35s 63ms/step - loss: 0.5766 - accuracy: 0.6938 - auc_roc: 0.7640 - val_loss: 0.5854 - val_accuracy: 0.6878 - val_auc_roc: 0.7569
# Epoch 39/40
# 562/562 [==============================] - 28s 50ms/step - loss: 0.5759 - accuracy: 0.6944 - auc_roc: 0.7648 - val_loss: 0.5833 - val_accuracy: 0.6870 - val_auc_roc: 0.7571
# Epoch 40/40
# 562/562 [==============================] - 24s 43ms/step - loss: 0.5756 - accuracy: 0.6945 - auc_roc: 0.7651 - val_loss: 0.5842 - val_accuracy: 0.6870 - val_auc_roc: 0.7561

# %%
loaded_model_C = transformer_model()
loaded_model_C.load_weights("../models/pre_model_C.h5")
y_pred = loaded_model_C.predict(pre_test_ST_CNN).reshape(pre_test_ST_CNN_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
pre_test_ST_labels = np.array(pre_test_ST_CNN_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(pre_test_ST_CNN_labels, y_pred)
mcc = matthews_corrcoef(pre_test_ST_CNN_labels, y_pred)
acc = accuracy_score(pre_test_ST_CNN_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

plot(pre_history_C)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
#  Acc: 0.6877853841609619, MCC: 0.3762477689991858, SN:0.7177587501042506, SP:0.6578124348442517,
#  CM:[[47325 24618]
#  [20305 51637]]

# %%
### PRE train GRU model
'''

model = Sequential()
model.add(Embedding(256, 21, input_length=33))
model.add(Lambda(lambda x: tf.expand_dims(x, 3)))
model.add(Conv2D(32, kernel_size=(17, 3), activation = 'relu', kernel_initializer='he_normal', padding = 'VALID'))
model.add(Dropout(0.4))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(16, activation='relu', kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Dense(1, activation='sigmoid'))

'''

def RNN_model():
    
    model = Sequential()
    model.add(Embedding(256, 21, input_length=33))
    model.add(GRU(128, dropout=0.2, recurrent_dropout=0.2, return_sequences=False, activation="relu"))
    #model.add(GRU(128, dropout=0.2, recurrent_dropout=0.2, return_sequences=True, activation="relu"))
    model.add(Dropout(0.2))
    #model.add(GRU(128, dropout=0.2, recurrent_dropout=0.2, return_sequences=False, activation="relu"))
    #model.add(Dropout(0.2))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    return model   

            

# Pretraining transformer

n_epo_RNN = 30
model_D = RNN_model()
model_D.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)

checkpointer = ModelCheckpoint(filepath="../models/pre_model_D.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)

print("PRE Training RNN model...")

pre_history_D = model_D.fit(pre_train_ST, pre_train_ST_labels, batch_size=1024, epochs=n_epo_RNN, verbose=1, callbacks=[checkpointer],
    validation_data=(pre_test_ST, pre_test_ST_labels))

#pre_history_C = model_C.fit(pre_train_ST_CNN, pre_train_ST_CNN_labels, batch_size=256, epochs=n_epo_transformer, verbose=1, callbacks=[checkpointer],
#    validation_data=(pre_test_ST_CNN, pre_test_ST_CNN_labels))

# pre_train_ST_CNN, pre_train_ST_CNN_labels, batch_size=256, epochs=n_epo_cnn, verbose=1, callbacks=[checkpointer],
# validation_data=(pre_test_ST_CNN, pre_test_ST_CNN_labels)

# Save model
#model_C.save_weights('../models/pre_model_C.h5')

loaded_model_D = RNN_model()
loaded_model_D.load_weights('../models/pre_model_D.h5')
y_pred = loaded_model_D.predict(pre_test_ST).reshape(pre_test_ST_labels.shape[0],)

y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
pre_test_ST_labels = np.array(pre_test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(pre_test_ST_labels, y_pred)
mcc = matthews_corrcoef(pre_test_ST_labels, y_pred)
acc = accuracy_score(pre_test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

#save plot
plot(pre_history_D)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# PRE Training RNN model...
# Epoch 1/30
# 132/132 [==============================] - 31s 217ms/step - loss: 0.6606 - accuracy: 0.5877 - auc_roc: 0.6678 - val_loss: 0.6038 - val_accuracy: 0.6796 - val_auc_roc: 0.7262
# Epoch 2/30
# 132/132 [==============================] - 30s 224ms/step - loss: 0.6052 - accuracy: 0.6755 - auc_roc: 0.7253 - val_loss: 0.5959 - val_accuracy: 0.6790 - val_auc_roc: 0.7401
# Epoch 3/30
# 132/132 [==============================] - 35s 263ms/step - loss: 0.5989 - accuracy: 0.6792 - auc_roc: 0.7344 - val_loss: 0.5900 - val_accuracy: 0.6868 - val_auc_roc: 0.7446
# Epoch 4/30
# 132/132 [==============================] - 27s 208ms/step - loss: 0.5944 - accuracy: 0.6826 - auc_roc: 0.7406 - val_loss: 0.5941 - val_accuracy: 0.6869 - val_auc_roc: 0.7487
# Epoch 5/30
# 132/132 [==============================] - 28s 209ms/step - loss: 0.5889 - accuracy: 0.6838 - auc_roc: 0.7471 - val_loss: 0.5868 - val_accuracy: 0.6918 - val_auc_roc: 0.7521
# Epoch 6/30
# 132/132 [==============================] - 26s 197ms/step - loss: 0.5899 - accuracy: 0.6855 - auc_roc: 0.7465 - val_loss: 0.5880 - val_accuracy: 0.6892 - val_auc_roc: 0.7525
# Epoch 7/30
# 132/132 [==============================] - 30s 226ms/step - loss: 0.5871 - accuracy: 0.6875 - auc_roc: 0.7493 - val_loss: 0.5808 - val_accuracy: 0.6966 - val_auc_roc: 0.7553
# Epoch 8/30
# 132/132 [==============================] - 26s 194ms/step - loss: 0.5854 - accuracy: 0.6879 - auc_roc: 0.7524 - val_loss: 0.5797 - val_accuracy: 0.6978 - val_auc_roc: 0.7590
# Epoch 9/30
# 132/132 [==============================] - 27s 205ms/step - loss: 0.5825 - accuracy: 0.6911 - auc_roc: 0.7555 - val_loss: 0.5898 - val_accuracy: 0.6877 - val_auc_roc: 0.7638
# Epoch 10/30
# 132/132 [==============================] - 31s 237ms/step - loss: 0.5773 - accuracy: 0.6952 - auc_roc: 0.7628 - val_loss: 0.5591 - val_accuracy: 0.7105 - val_auc_roc: 0.7839
# Epoch 11/30
# 132/132 [==============================] - 26s 195ms/step - loss: 0.5642 - accuracy: 0.7089 - auc_roc: 0.7787 - val_loss: 0.5482 - val_accuracy: 0.7201 - val_auc_roc: 0.7989
# Epoch 12/30
# 132/132 [==============================] - 27s 203ms/step - loss: 0.5550 - accuracy: 0.7195 - auc_roc: 0.7875 - val_loss: 0.5374 - val_accuracy: 0.7353 - val_auc_roc: 0.8057
# Epoch 13/30
# 132/132 [==============================] - 25s 189ms/step - loss: 0.5493 - accuracy: 0.7259 - auc_roc: 0.7935 - val_loss: 0.5322 - val_accuracy: 0.7409 - val_auc_roc: 0.8120
# Epoch 14/30
# 132/132 [==============================] - 26s 196ms/step - loss: 0.5433 - accuracy: 0.7289 - auc_roc: 0.7988 - val_loss: 0.5281 - val_accuracy: 0.7421 - val_auc_roc: 0.8152
# Epoch 15/30
# 132/132 [==============================] - 24s 184ms/step - loss: 0.5408 - accuracy: 0.7328 - auc_roc: 0.8013 - val_loss: 0.5212 - val_accuracy: 0.7491 - val_auc_roc: 0.8211
# Epoch 16/30
# 132/132 [==============================] - 30s 232ms/step - loss: 0.5339 - accuracy: 0.7378 - auc_roc: 0.8077 - val_loss: 0.5198 - val_accuracy: 0.7495 - val_auc_roc: 0.8217
# Epoch 17/30
# 132/132 [==============================] - 27s 207ms/step - loss: 0.5285 - accuracy: 0.7417 - auc_roc: 0.8120 - val_loss: 0.5145 - val_accuracy: 0.7576 - val_auc_roc: 0.8264
# Epoch 18/30
# 132/132 [==============================] - 27s 203ms/step - loss: 0.5264 - accuracy: 0.7437 - auc_roc: 0.8142 - val_loss: 0.5099 - val_accuracy: 0.7565 - val_auc_roc: 0.8289
# Epoch 19/30
# 132/132 [==============================] - 26s 194ms/step - loss: 0.5213 - accuracy: 0.7463 - auc_roc: 0.8182 - val_loss: 0.5048 - val_accuracy: 0.7591 - val_auc_roc: 0.8321
# Epoch 20/30
# 132/132 [==============================] - 25s 188ms/step - loss: 0.5195 - accuracy: 0.7491 - auc_roc: 0.8197 - val_loss: 0.5080 - val_accuracy: 0.7566 - val_auc_roc: 0.8322
# Epoch 21/30
# 132/132 [==============================] - 29s 224ms/step - loss: 0.5156 - accuracy: 0.7530 - auc_roc: 0.8230 - val_loss: 0.5018 - val_accuracy: 0.7602 - val_auc_roc: 0.8350
# Epoch 22/30
# 132/132 [==============================] - 27s 205ms/step - loss: 0.5127 - accuracy: 0.7551 - auc_roc: 0.8253 - val_loss: 0.5001 - val_accuracy: 0.7599 - val_auc_roc: 0.8361
# Epoch 23/30
# 132/132 [==============================] - 28s 209ms/step - loss: 0.5097 - accuracy: 0.7568 - auc_roc: 0.8277 - val_loss: 0.5048 - val_accuracy: 0.7627 - val_auc_roc: 0.8371
# Epoch 24/30
# 132/132 [==============================] - 27s 207ms/step - loss: 0.5093 - accuracy: 0.7571 - auc_roc: 0.8281 - val_loss: 0.5024 - val_accuracy: 0.7603 - val_auc_roc: 0.8382
# Epoch 25/30
# 132/132 [==============================] - 34s 256ms/step - loss: 0.5082 - accuracy: 0.7566 - auc_roc: 0.8291 - val_loss: 0.4957 - val_accuracy: 0.7659 - val_auc_roc: 0.8390
# Epoch 26/30
# 132/132 [==============================] - 29s 219ms/step - loss: 0.5076 - accuracy: 0.7570 - auc_roc: 0.8296 - val_loss: 0.5004 - val_accuracy: 0.7636 - val_auc_roc: 0.8383
# Epoch 27/30
# 132/132 [==============================] - 26s 198ms/step - loss: 0.5039 - accuracy: 0.7603 - auc_roc: 0.8326 - val_loss: 0.5038 - val_accuracy: 0.7616 - val_auc_roc: 0.8377
# Epoch 28/30
# 132/132 [==============================] - 26s 200ms/step - loss: 0.5019 - accuracy: 0.7606 - auc_roc: 0.8343 - val_loss: 0.4966 - val_accuracy: 0.7649 - val_auc_roc: 0.8394
# Epoch 29/30
# 132/132 [==============================] - 30s 229ms/step - loss: 0.4993 - accuracy: 0.7648 - auc_roc: 0.8358 - val_loss: 0.4974 - val_accuracy: 0.7647 - val_auc_roc: 0.8392
# Epoch 30/30
# 132/132 [==============================] - 27s 203ms/step - loss: 0.4995 - accuracy: 0.7629 - auc_roc: 0.8360 - val_loss: 0.4943 - val_accuracy: 0.7660 - val_auc_roc: 0.8405
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  Acc: 0.7659801136363636, MCC: 0.5319703606024018, SN:0.7627279185413214, SP:0.7692307692307693,
#  CM:[[3250  975]
#  [1002 3221]]

# %%
## Predict on real data using CNN

loaded_model_A = CNN_model()
loaded_model_A.load_weights('../models/pre_model_A.h5')
y_pred = loaded_model_A.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))

### Predict on real data using embedding 

loaded_model_B = prot_t5_model()
loaded_model_B.load_weights("../models/pre_model_B.h5")
y_pred = loaded_model_B.predict(X_test_full_ST_embedding).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))

## Predict on real data using transformers

loaded_model_C = transformer_model()
loaded_model_C.load_weights("../models/pre_model_C.h5")
y_pred = loaded_model_C.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))

# Predict on real data using RNN
loaded_model_D = RNN_model()
loaded_model_D.load_weights("../models/pre_model_D.h5")
y_pred = loaded_model_D.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
#  Acc: 0.8116591928251121, MCC: 0.6271316882011174, SN:0.8648648648648649, SP:0.7589285714285714,
#  CM:[[170  54]
#  [ 30 192]]
#
#  Acc: 0.7982062780269058, MCC: 0.6055560006505397, SN:0.8828828828828829, SP:0.7142857142857143,
#  CM:[[160  64]
#  [ 26 196]]
#
#  Acc: 0.7937219730941704, MCC: 0.5890856672626991, SN:0.8288288288288288, SP:0.7589285714285714,
#  CM:[[170  54]
#  [ 38 184]]
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  Acc: 0.7869955156950673, MCC: 0.5740839816210079, SN:0.7747747747747747, SP:0.7991071428571429,
#  CM:[[179  45]
#  [ 50 172]]

# %%
# Training DE-Phosphorylation

iteration = 1
n_epo_cnn = 50

model_A = CNN_model()
model_A.compile(optimizer=Adam(learning_rate=1e-4), loss=BinaryCrossentropy(), metrics=metrics)
model_A.load_weights('../models/pre_model_A.h5')
#model_A.summary()

print("Training CNN model...")

#metrics = ['accuracy', tf.keras.metrics.AUC()]

#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=7,mode='auto')

checkpointer = ModelCheckpoint(filepath="../models/re_train_model_A.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)

history_A = model_A.fit(X_train_CNN, train_ST_labels, batch_size=32, epochs=n_epo_cnn, verbose=1, callbacks=[checkpointer], 
                        validation_data=(X_test_CNN, test_ST_labels))

# Save model
#model_A.save_weights('../models/re_train_model_A.h5')

#save plot
plot(history_A)
print()
# Out:
# Training CNN model...
# Epoch 1/50
# 56/56 [==============================] - 2s 20ms/step - loss: 0.5615 - accuracy: 0.7201 - auc_roc: 0.8166 - val_loss: 0.5068 - val_accuracy: 0.7466 - val_auc_roc: 0.8610
# Epoch 2/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.5186 - accuracy: 0.7442 - auc_roc: 0.8242 - val_loss: 0.4919 - val_accuracy: 0.7646 - val_auc_roc: 0.8664
# Epoch 3/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.5130 - accuracy: 0.7476 - auc_roc: 0.8195 - val_loss: 0.4835 - val_accuracy: 0.7803 - val_auc_roc: 0.8704
# Epoch 4/50
# 56/56 [==============================] - 1s 12ms/step - loss: 0.4920 - accuracy: 0.7577 - auc_roc: 0.8382 - val_loss: 0.4784 - val_accuracy: 0.7825 - val_auc_roc: 0.8728
# Epoch 5/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.4848 - accuracy: 0.7650 - auc_roc: 0.8397 - val_loss: 0.4715 - val_accuracy: 0.7825 - val_auc_roc: 0.8761
# Epoch 6/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.4716 - accuracy: 0.7797 - auc_roc: 0.8528 - val_loss: 0.4684 - val_accuracy: 0.7892 - val_auc_roc: 0.8764
# Epoch 7/50
# 56/56 [==============================] - 1s 16ms/step - loss: 0.4599 - accuracy: 0.7898 - auc_roc: 0.8597 - val_loss: 0.4655 - val_accuracy: 0.7915 - val_auc_roc: 0.8778
# Epoch 8/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.4413 - accuracy: 0.7892 - auc_roc: 0.8742 - val_loss: 0.4616 - val_accuracy: 0.7960 - val_auc_roc: 0.8786
# Epoch 9/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.4335 - accuracy: 0.8010 - auc_roc: 0.8772 - val_loss: 0.4587 - val_accuracy: 0.7960 - val_auc_roc: 0.8805
# Epoch 10/50
# 56/56 [==============================] - 1s 17ms/step - loss: 0.4264 - accuracy: 0.7993 - auc_roc: 0.8811 - val_loss: 0.4562 - val_accuracy: 0.8027 - val_auc_roc: 0.8806
# Epoch 11/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.4130 - accuracy: 0.8027 - auc_roc: 0.8902 - val_loss: 0.4547 - val_accuracy: 0.8072 - val_auc_roc: 0.8818
# Epoch 12/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.4040 - accuracy: 0.8145 - auc_roc: 0.8927 - val_loss: 0.4532 - val_accuracy: 0.8049 - val_auc_roc: 0.8820
# Epoch 13/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.3805 - accuracy: 0.8263 - auc_roc: 0.9069 - val_loss: 0.4497 - val_accuracy: 0.8072 - val_auc_roc: 0.8815
# Epoch 14/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.3832 - accuracy: 0.8325 - auc_roc: 0.9063 - val_loss: 0.4481 - val_accuracy: 0.8094 - val_auc_roc: 0.8819
# Epoch 15/50
# 56/56 [==============================] - 1s 14ms/step - loss: 0.3770 - accuracy: 0.8381 - auc_roc: 0.9091 - val_loss: 0.4463 - val_accuracy: 0.8139 - val_auc_roc: 0.8825
# Epoch 16/50
# 56/56 [==============================] - 1s 12ms/step - loss: 0.3681 - accuracy: 0.8364 - auc_roc: 0.9148 - val_loss: 0.4440 - val_accuracy: 0.8139 - val_auc_roc: 0.8839
# Epoch 17/50
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3426 - accuracy: 0.8465 - auc_roc: 0.9274 - val_loss: 0.4418 - val_accuracy: 0.8184 - val_auc_roc: 0.8839
# Epoch 18/50
# 56/56 [==============================] - 1s 11ms/step - loss: 0.3401 - accuracy: 0.8477 - auc_roc: 0.9276 - val_loss: 0.4418 - val_accuracy: 0.8184 - val_auc_roc: 0.8841
# Epoch 19/50
# 56/56 [==============================] - 1s 16ms/step - loss: 0.3279 - accuracy: 0.8600 - auc_roc: 0.9344 - val_loss: 0.4405 - val_accuracy: 0.8206 - val_auc_roc: 0.8844
# Epoch 20/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.3226 - accuracy: 0.8567 - auc_roc: 0.9331 - val_loss: 0.4393 - val_accuracy: 0.8184 - val_auc_roc: 0.8854
# Epoch 21/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2952 - accuracy: 0.8713 - auc_roc: 0.9483 - val_loss: 0.4381 - val_accuracy: 0.8184 - val_auc_roc: 0.8859
# Epoch 22/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2932 - accuracy: 0.8786 - auc_roc: 0.9468 - val_loss: 0.4389 - val_accuracy: 0.8094 - val_auc_roc: 0.8853
# Epoch 23/50
# 56/56 [==============================] - 1s 12ms/step - loss: 0.2732 - accuracy: 0.8909 - auc_roc: 0.9549 - val_loss: 0.4393 - val_accuracy: 0.8161 - val_auc_roc: 0.8846
# Epoch 24/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2747 - accuracy: 0.8825 - auc_roc: 0.9556 - val_loss: 0.4396 - val_accuracy: 0.8117 - val_auc_roc: 0.8834
# Epoch 25/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2724 - accuracy: 0.8820 - auc_roc: 0.9543 - val_loss: 0.4403 - val_accuracy: 0.8117 - val_auc_roc: 0.8822
# Epoch 26/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.2680 - accuracy: 0.8926 - auc_roc: 0.9573 - val_loss: 0.4394 - val_accuracy: 0.8094 - val_auc_roc: 0.8823
# Epoch 27/50
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2503 - accuracy: 0.8954 - auc_roc: 0.9630 - val_loss: 0.4398 - val_accuracy: 0.8184 - val_auc_roc: 0.8822
# Epoch 28/50
# 56/56 [==============================] - 1s 14ms/step - loss: 0.2491 - accuracy: 0.8932 - auc_roc: 0.9618 - val_loss: 0.4419 - val_accuracy: 0.8139 - val_auc_roc: 0.8819
# Epoch 29/50
# 56/56 [==============================] - 1s 15ms/step - loss: 0.2297 - accuracy: 0.9050 - auc_roc: 0.9680 - val_loss: 0.4436 - val_accuracy: 0.8184 - val_auc_roc: 0.8820
# Epoch 30/50
# 56/56 [==============================] - 2s 32ms/step - loss: 0.2328 - accuracy: 0.9089 - auc_roc: 0.9677 - val_loss: 0.4424 - val_accuracy: 0.8161 - val_auc_roc: 0.8807
# Epoch 31/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.2217 - accuracy: 0.9089 - auc_roc: 0.9714 - val_loss: 0.4426 - val_accuracy: 0.8184 - val_auc_roc: 0.8815
# Epoch 32/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.2029 - accuracy: 0.9280 - auc_roc: 0.9755 - val_loss: 0.4436 - val_accuracy: 0.8161 - val_auc_roc: 0.8813
# Epoch 33/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.2037 - accuracy: 0.9275 - auc_roc: 0.9744 - val_loss: 0.4452 - val_accuracy: 0.8139 - val_auc_roc: 0.8808
# Epoch 34/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.1848 - accuracy: 0.9275 - auc_roc: 0.9816 - val_loss: 0.4455 - val_accuracy: 0.8161 - val_auc_roc: 0.8806
# Epoch 35/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.1934 - accuracy: 0.9269 - auc_roc: 0.9765 - val_loss: 0.4474 - val_accuracy: 0.8072 - val_auc_roc: 0.8808
# Epoch 36/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.1837 - accuracy: 0.9264 - auc_roc: 0.9803 - val_loss: 0.4481 - val_accuracy: 0.8117 - val_auc_roc: 0.8811
# Epoch 37/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.1894 - accuracy: 0.9224 - auc_roc: 0.9785 - val_loss: 0.4474 - val_accuracy: 0.8094 - val_auc_roc: 0.8818
# Epoch 38/50
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1653 - accuracy: 0.9325 - auc_roc: 0.9843 - val_loss: 0.4513 - val_accuracy: 0.8117 - val_auc_roc: 0.8802
# Epoch 39/50
# 56/56 [==============================] - 1s 23ms/step - loss: 0.1566 - accuracy: 0.9438 - auc_roc: 0.9861 - val_loss: 0.4532 - val_accuracy: 0.8117 - val_auc_roc: 0.8807
# Epoch 40/50
# 56/56 [==============================] - 1s 18ms/step - loss: 0.1517 - accuracy: 0.9438 - auc_roc: 0.9867 - val_loss: 0.4567 - val_accuracy: 0.8139 - val_auc_roc: 0.8821
# Epoch 41/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.1546 - accuracy: 0.9421 - auc_roc: 0.9860 - val_loss: 0.4567 - val_accuracy: 0.8094 - val_auc_roc: 0.8809
# Epoch 42/50
# 56/56 [==============================] - 1s 14ms/step - loss: 0.1512 - accuracy: 0.9421 - auc_roc: 0.9861 - val_loss: 0.4583 - val_accuracy: 0.8139 - val_auc_roc: 0.8801
# Epoch 43/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.1312 - accuracy: 0.9494 - auc_roc: 0.9907 - val_loss: 0.4586 - val_accuracy: 0.8117 - val_auc_roc: 0.8806
# Epoch 44/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.1271 - accuracy: 0.9517 - auc_roc: 0.9915 - val_loss: 0.4590 - val_accuracy: 0.8072 - val_auc_roc: 0.8815
# Epoch 45/50
# 56/56 [==============================] - 1s 20ms/step - loss: 0.1251 - accuracy: 0.9511 - auc_roc: 0.9914 - val_loss: 0.4621 - val_accuracy: 0.8094 - val_auc_roc: 0.8825
# Epoch 46/50
# 56/56 [==============================] - 1s 21ms/step - loss: 0.1159 - accuracy: 0.9578 - auc_roc: 0.9934 - val_loss: 0.4609 - val_accuracy: 0.8004 - val_auc_roc: 0.8823
# Epoch 47/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.1322 - accuracy: 0.9511 - auc_roc: 0.9894 - val_loss: 0.4656 - val_accuracy: 0.8027 - val_auc_roc: 0.8827
# Epoch 48/50
# 56/56 [==============================] - 1s 12ms/step - loss: 0.1148 - accuracy: 0.9601 - auc_roc: 0.9923 - val_loss: 0.4661 - val_accuracy: 0.8072 - val_auc_roc: 0.8843
# Epoch 49/50
# 56/56 [==============================] - 1s 13ms/step - loss: 0.1085 - accuracy: 0.9545 - auc_roc: 0.9940 - val_loss: 0.4621 - val_accuracy: 0.8094 - val_auc_roc: 0.8824
# Epoch 50/50
# 56/56 [==============================] - 1s 11ms/step - loss: 0.1144 - accuracy: 0.9567 - auc_roc: 0.9924 - val_loss: 0.4691 - val_accuracy: 0.8072 - val_auc_roc: 0.8823
#  Acc: 0.8071748878923767, MCC: 0.6210090295484362, SN:0.8783783783783784, SP:0.7366071428571429,
#  CM:[[165  59]
#  [ 27 195]]

# %%
loaded_model_A = CNN_model()
loaded_model_A.load_weights("../models/re_train_model_A.h5")
y_pred = loaded_model_A.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
#  Acc: 0.820627802690583, MCC: 0.651029797843788, SN:0.9054054054054054, SP:0.7366071428571429,
#  CM:[[165  59]
#  [ 21 201]]

# %%
########### Model B

print("Training Embedding model...")

n_epo_embed = 20
model_B = prot_t5_model()
model_B.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)
model_B.load_weights('../models/pre_model_B.h5')

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3, mode='auto')

checkpointer = ModelCheckpoint(filepath="../models/re_train_model_B.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)

history_B = model_B.fit(X_train_full_ST_embedding, train_ST_labels, batch_size=256, epochs=n_epo_embed, verbose=1, 
                        callbacks=[checkpointer], validation_data=(X_test_full_ST_embedding, test_ST_labels))

plot(history_B)
print()

loaded_model_B = prot_t5_model()
loaded_model_B.load_weights("../models/re_train_model_B.h5")
y_pred = loaded_model_B.predict(X_test_full_ST_embedding).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
# Training Embedding model...
# Epoch 1/20
# 7/7 [==============================] - 1s 74ms/step - loss: 0.4912 - accuracy: 0.7707 - auc_roc: 0.8519 - val_loss: 0.4315 - val_accuracy: 0.8296 - val_auc_roc: 0.8863
# Epoch 2/20
# 7/7 [==============================] - 0s 33ms/step - loss: 0.4551 - accuracy: 0.7943 - auc_roc: 0.8686 - val_loss: 0.4290 - val_accuracy: 0.8341 - val_auc_roc: 0.8870
# Epoch 3/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4268 - accuracy: 0.8055 - auc_roc: 0.8845 - val_loss: 0.4264 - val_accuracy: 0.8341 - val_auc_roc: 0.8858
# Epoch 4/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.4132 - accuracy: 0.8139 - auc_roc: 0.8919 - val_loss: 0.4257 - val_accuracy: 0.8229 - val_auc_roc: 0.8867
# Epoch 5/20
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3967 - accuracy: 0.8229 - auc_roc: 0.8992 - val_loss: 0.4226 - val_accuracy: 0.8318 - val_auc_roc: 0.8875
# Epoch 6/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.3796 - accuracy: 0.8246 - auc_roc: 0.9092 - val_loss: 0.4257 - val_accuracy: 0.8251 - val_auc_roc: 0.8866
# Epoch 7/20
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3663 - accuracy: 0.8381 - auc_roc: 0.9160 - val_loss: 0.4265 - val_accuracy: 0.8318 - val_auc_roc: 0.8873
# Epoch 8/20
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3625 - accuracy: 0.8392 - auc_roc: 0.9160 - val_loss: 0.4257 - val_accuracy: 0.8296 - val_auc_roc: 0.8870
# Epoch 9/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3423 - accuracy: 0.8544 - auc_roc: 0.9275 - val_loss: 0.4314 - val_accuracy: 0.8296 - val_auc_roc: 0.8858
# Epoch 10/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3257 - accuracy: 0.8572 - auc_roc: 0.9337 - val_loss: 0.4424 - val_accuracy: 0.8296 - val_auc_roc: 0.8844
# Epoch 11/20
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3133 - accuracy: 0.8657 - auc_roc: 0.9389 - val_loss: 0.4478 - val_accuracy: 0.8251 - val_auc_roc: 0.8804
# Epoch 12/20
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2994 - accuracy: 0.8713 - auc_roc: 0.9450 - val_loss: 0.4532 - val_accuracy: 0.8229 - val_auc_roc: 0.8801
# Epoch 13/20
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2836 - accuracy: 0.8763 - auc_roc: 0.9503 - val_loss: 0.4673 - val_accuracy: 0.8274 - val_auc_roc: 0.8800
# Epoch 14/20
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2756 - accuracy: 0.8836 - auc_roc: 0.9529 - val_loss: 0.4776 - val_accuracy: 0.8229 - val_auc_roc: 0.8739
# Epoch 15/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2730 - accuracy: 0.8808 - auc_roc: 0.9561 - val_loss: 0.4866 - val_accuracy: 0.8094 - val_auc_roc: 0.8699
# Epoch 16/20
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2626 - accuracy: 0.8915 - auc_roc: 0.9584 - val_loss: 0.4990 - val_accuracy: 0.8161 - val_auc_roc: 0.8737
# Epoch 17/20
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2454 - accuracy: 0.8971 - auc_roc: 0.9621 - val_loss: 0.5111 - val_accuracy: 0.8161 - val_auc_roc: 0.8684
# Epoch 18/20
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2341 - accuracy: 0.9039 - auc_roc: 0.9675 - val_loss: 0.5088 - val_accuracy: 0.8139 - val_auc_roc: 0.8652
# Epoch 19/20
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2282 - accuracy: 0.9050 - auc_roc: 0.9691 - val_loss: 0.5420 - val_accuracy: 0.8117 - val_auc_roc: 0.8661
# Epoch 20/20
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2198 - accuracy: 0.9050 - auc_roc: 0.9712 - val_loss: 0.5568 - val_accuracy: 0.8161 - val_auc_roc: 0.8612
#  Acc: 0.8183856502242153, MCC: 0.6372176236092627, SN:0.7972972972972973, SP:0.8392857142857143,
#  CM:[[188  36]
#  [ 45 177]]
#
#
#  Acc: 0.8340807174887892, MCC: 0.6684367400444008, SN:0.8468468468468469, SP:0.8214285714285714,
#  CM:[[184  40]
#  [ 34 188]]

# %%
############# Training Transformer


model_C = transformer_model()
model_C.load_weights('../models/pre_model_C.h5')
model_C.compile(optimizer=Adam(learning_rate=1e-4), loss=BinaryCrossentropy(), metrics=metrics)

#model_C.summary()

n_epo_transformer = 40

print("Training Transformer model...")

checkpointer = ModelCheckpoint(filepath="../models/re_train_model_C.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)

#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=7,mode='auto')

history_C = model_C.fit(X_train_CNN, train_ST_labels, batch_size=256, epochs=n_epo_transformer, verbose=1
                        ,callbacks=[checkpointer]
                        , validation_data=(X_test_CNN, test_ST_labels))

plot(history_C)
print()

loaded_model_C = transformer_model()
loaded_model_C.load_weights("../models/re_train_model_C.h5")
y_pred = loaded_model_C.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
# Training Transformer model...
# Epoch 1/40
# 7/7 [==============================] - 6s 210ms/step - loss: 0.5425 - accuracy: 0.7263 - auc_roc: 0.7567 - val_loss: 0.4877 - val_accuracy: 0.7735 - val_auc_roc: 0.8644
# Epoch 2/40
# 7/7 [==============================] - 0s 57ms/step - loss: 0.5288 - accuracy: 0.7409 - auc_roc: 0.8200 - val_loss: 0.4705 - val_accuracy: 0.7803 - val_auc_roc: 0.8666
# Epoch 3/40
# 7/7 [==============================] - 0s 65ms/step - loss: 0.5115 - accuracy: 0.7544 - auc_roc: 0.8293 - val_loss: 0.4613 - val_accuracy: 0.7892 - val_auc_roc: 0.8704
# Epoch 4/40
# 7/7 [==============================] - 0s 69ms/step - loss: 0.5042 - accuracy: 0.7628 - auc_roc: 0.8342 - val_loss: 0.4547 - val_accuracy: 0.7915 - val_auc_roc: 0.8745
# Epoch 5/40
# 7/7 [==============================] - 1s 75ms/step - loss: 0.4980 - accuracy: 0.7639 - auc_roc: 0.8377 - val_loss: 0.4494 - val_accuracy: 0.7960 - val_auc_roc: 0.8760
# Epoch 6/40
# 7/7 [==============================] - 0s 58ms/step - loss: 0.4892 - accuracy: 0.7628 - auc_roc: 0.8456 - val_loss: 0.4449 - val_accuracy: 0.8004 - val_auc_roc: 0.8777
# Epoch 7/40
# 7/7 [==============================] - 0s 30ms/step - loss: 0.4779 - accuracy: 0.7841 - auc_roc: 0.8548 - val_loss: 0.4412 - val_accuracy: 0.8004 - val_auc_roc: 0.8798
# Epoch 8/40
# 7/7 [==============================] - 0s 66ms/step - loss: 0.4808 - accuracy: 0.7802 - auc_roc: 0.8509 - val_loss: 0.4382 - val_accuracy: 0.8049 - val_auc_roc: 0.8811
# Epoch 9/40
# 7/7 [==============================] - 0s 24ms/step - loss: 0.4724 - accuracy: 0.7825 - auc_roc: 0.8559 - val_loss: 0.4351 - val_accuracy: 0.8049 - val_auc_roc: 0.8824
# Epoch 10/40
# 7/7 [==============================] - 0s 24ms/step - loss: 0.4691 - accuracy: 0.7841 - auc_roc: 0.8582 - val_loss: 0.4323 - val_accuracy: 0.8049 - val_auc_roc: 0.8833
# Epoch 11/40
# 7/7 [==============================] - 0s 55ms/step - loss: 0.4665 - accuracy: 0.7853 - auc_roc: 0.8597 - val_loss: 0.4297 - val_accuracy: 0.8094 - val_auc_roc: 0.8838
# Epoch 12/40
# 7/7 [==============================] - 0s 48ms/step - loss: 0.4617 - accuracy: 0.7926 - auc_roc: 0.8635 - val_loss: 0.4279 - val_accuracy: 0.8117 - val_auc_roc: 0.8848
# Epoch 13/40
# 7/7 [==============================] - 0s 28ms/step - loss: 0.4578 - accuracy: 0.7926 - auc_roc: 0.8654 - val_loss: 0.4267 - val_accuracy: 0.8139 - val_auc_roc: 0.8852
# Epoch 14/40
# 7/7 [==============================] - 0s 27ms/step - loss: 0.4502 - accuracy: 0.7971 - auc_roc: 0.8700 - val_loss: 0.4257 - val_accuracy: 0.8139 - val_auc_roc: 0.8864
# Epoch 15/40
# 7/7 [==============================] - 0s 23ms/step - loss: 0.4465 - accuracy: 0.7943 - auc_roc: 0.8723 - val_loss: 0.4254 - val_accuracy: 0.8072 - val_auc_roc: 0.8864
# Epoch 16/40
# 7/7 [==============================] - 0s 23ms/step - loss: 0.4465 - accuracy: 0.8061 - auc_roc: 0.8720 - val_loss: 0.4247 - val_accuracy: 0.8117 - val_auc_roc: 0.8865
# Epoch 17/40
# 7/7 [==============================] - 0s 25ms/step - loss: 0.4376 - accuracy: 0.8010 - auc_roc: 0.8779 - val_loss: 0.4241 - val_accuracy: 0.8094 - val_auc_roc: 0.8867
# Epoch 18/40
# 7/7 [==============================] - 0s 21ms/step - loss: 0.4360 - accuracy: 0.8094 - auc_roc: 0.8786 - val_loss: 0.4238 - val_accuracy: 0.8072 - val_auc_roc: 0.8871
# Epoch 19/40
# 7/7 [==============================] - 0s 23ms/step - loss: 0.4378 - accuracy: 0.8033 - auc_roc: 0.8769 - val_loss: 0.4234 - val_accuracy: 0.8072 - val_auc_roc: 0.8875
# Epoch 20/40
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4266 - accuracy: 0.8128 - auc_roc: 0.8842 - val_loss: 0.4234 - val_accuracy: 0.8072 - val_auc_roc: 0.8878
# Epoch 21/40
# 7/7 [==============================] - 0s 28ms/step - loss: 0.4222 - accuracy: 0.8156 - auc_roc: 0.8862 - val_loss: 0.4233 - val_accuracy: 0.8117 - val_auc_roc: 0.8880
# Epoch 22/40
# 7/7 [==============================] - 0s 23ms/step - loss: 0.4194 - accuracy: 0.8207 - auc_roc: 0.8882 - val_loss: 0.4234 - val_accuracy: 0.8139 - val_auc_roc: 0.8879
# Epoch 23/40
# 7/7 [==============================] - 0s 25ms/step - loss: 0.4194 - accuracy: 0.8173 - auc_roc: 0.8877 - val_loss: 0.4230 - val_accuracy: 0.8117 - val_auc_roc: 0.8881
# Epoch 24/40
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4179 - accuracy: 0.8168 - auc_roc: 0.8889 - val_loss: 0.4236 - val_accuracy: 0.8094 - val_auc_roc: 0.8883
# Epoch 25/40
# 7/7 [==============================] - 0s 26ms/step - loss: 0.4066 - accuracy: 0.8218 - auc_roc: 0.8958 - val_loss: 0.4237 - val_accuracy: 0.8072 - val_auc_roc: 0.8886
# Epoch 26/40
# 7/7 [==============================] - 0s 31ms/step - loss: 0.4065 - accuracy: 0.8201 - auc_roc: 0.8957 - val_loss: 0.4230 - val_accuracy: 0.8072 - val_auc_roc: 0.8886
# Epoch 27/40
# 7/7 [==============================] - 0s 32ms/step - loss: 0.3938 - accuracy: 0.8297 - auc_roc: 0.9025 - val_loss: 0.4231 - val_accuracy: 0.8049 - val_auc_roc: 0.8884
# Epoch 28/40
# 7/7 [==============================] - 0s 23ms/step - loss: 0.3943 - accuracy: 0.8342 - auc_roc: 0.9019 - val_loss: 0.4234 - val_accuracy: 0.8027 - val_auc_roc: 0.8885
# Epoch 29/40
# 7/7 [==============================] - 0s 22ms/step - loss: 0.3882 - accuracy: 0.8359 - auc_roc: 0.9061 - val_loss: 0.4237 - val_accuracy: 0.8027 - val_auc_roc: 0.8886
# Epoch 30/40
# 7/7 [==============================] - 0s 31ms/step - loss: 0.3883 - accuracy: 0.8263 - auc_roc: 0.9043 - val_loss: 0.4236 - val_accuracy: 0.8072 - val_auc_roc: 0.8891
# Epoch 31/40
# 7/7 [==============================] - 0s 48ms/step - loss: 0.3865 - accuracy: 0.8319 - auc_roc: 0.9053 - val_loss: 0.4247 - val_accuracy: 0.8072 - val_auc_roc: 0.8888
# Epoch 32/40
# 7/7 [==============================] - 0s 48ms/step - loss: 0.3796 - accuracy: 0.8415 - auc_roc: 0.9090 - val_loss: 0.4256 - val_accuracy: 0.8094 - val_auc_roc: 0.8888
# Epoch 33/40
# 7/7 [==============================] - 0s 49ms/step - loss: 0.3715 - accuracy: 0.8477 - auc_roc: 0.9129 - val_loss: 0.4263 - val_accuracy: 0.8072 - val_auc_roc: 0.8894
# Epoch 34/40
# 7/7 [==============================] - 0s 39ms/step - loss: 0.3656 - accuracy: 0.8404 - auc_roc: 0.9172 - val_loss: 0.4249 - val_accuracy: 0.7982 - val_auc_roc: 0.8896
# Epoch 35/40
# 7/7 [==============================] - 0s 49ms/step - loss: 0.3660 - accuracy: 0.8443 - auc_roc: 0.9166 - val_loss: 0.4252 - val_accuracy: 0.8004 - val_auc_roc: 0.8903
# Epoch 36/40
# 7/7 [==============================] - 0s 50ms/step - loss: 0.3585 - accuracy: 0.8572 - auc_roc: 0.9187 - val_loss: 0.4264 - val_accuracy: 0.8072 - val_auc_roc: 0.8905
# Epoch 37/40
# 7/7 [==============================] - 0s 48ms/step - loss: 0.3537 - accuracy: 0.8494 - auc_roc: 0.9221 - val_loss: 0.4274 - val_accuracy: 0.8049 - val_auc_roc: 0.8902
# Epoch 38/40
# 7/7 [==============================] - 0s 49ms/step - loss: 0.3543 - accuracy: 0.8567 - auc_roc: 0.9202 - val_loss: 0.4285 - val_accuracy: 0.8094 - val_auc_roc: 0.8908
# Epoch 39/40
# 7/7 [==============================] - 0s 51ms/step - loss: 0.3516 - accuracy: 0.8477 - auc_roc: 0.9224 - val_loss: 0.4284 - val_accuracy: 0.8049 - val_auc_roc: 0.8905
# Epoch 40/40
# 7/7 [==============================] - 0s 51ms/step - loss: 0.3484 - accuracy: 0.8494 - auc_roc: 0.9235 - val_loss: 0.4280 - val_accuracy: 0.8027 - val_auc_roc: 0.8913
#  Acc: 0.8139013452914798, MCC: 0.6283743578143943, SN:0.8333333333333334, SP:0.7946428571428571,
#  CM:[[178  46]
#  [ 37 185]]

# %%
model_D = RNN_model()
model_D.load_weights('../models/pre_model_D.h5')
model_D.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)

n_epo_RNN = 30

print("Training Transformer model...")

checkpointer = ModelCheckpoint(filepath="../models/re_train_model_D.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)

history_D = model_D.fit(X_train_CNN, train_ST_labels, batch_size=256, epochs=n_epo_transformer, verbose=1
                        ,callbacks=[checkpointer], validation_data=(X_test_CNN, test_ST_labels))

plot(history_D)
print()

loaded_model_D = RNN_model()
loaded_model_D.load_weights("../models/re_train_model_D.h5")
y_pred = loaded_model_D.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Training Transformer model...
# Epoch 1/30
# 7/7 [==============================] - 5s 317ms/step - loss: 0.5384 - accuracy: 0.7319 - auc_roc: 0.8345 - val_loss: 0.4776 - val_accuracy: 0.7915 - val_auc_roc: 0.8629
# Epoch 2/30
# 7/7 [==============================] - 2s 219ms/step - loss: 0.5235 - accuracy: 0.7369 - auc_roc: 0.8155 - val_loss: 0.4718 - val_accuracy: 0.7870 - val_auc_roc: 0.8620
# Epoch 3/30
# 7/7 [==============================] - 2s 237ms/step - loss: 0.5093 - accuracy: 0.7544 - auc_roc: 0.8297 - val_loss: 0.4734 - val_accuracy: 0.7803 - val_auc_roc: 0.8621
# Epoch 4/30
# 7/7 [==============================] - 1s 208ms/step - loss: 0.5028 - accuracy: 0.7600 - auc_roc: 0.8349 - val_loss: 0.4683 - val_accuracy: 0.8049 - val_auc_roc: 0.8647
# Epoch 5/30
# 7/7 [==============================] - 1s 214ms/step - loss: 0.4966 - accuracy: 0.7499 - auc_roc: 0.8399 - val_loss: 0.4608 - val_accuracy: 0.7982 - val_auc_roc: 0.8677
# Epoch 6/30
# 7/7 [==============================] - 1s 206ms/step - loss: 0.4891 - accuracy: 0.7634 - auc_roc: 0.8444 - val_loss: 0.4562 - val_accuracy: 0.8094 - val_auc_roc: 0.8692
# Epoch 7/30
# 7/7 [==============================] - 1s 187ms/step - loss: 0.4891 - accuracy: 0.7701 - auc_roc: 0.8452 - val_loss: 0.4549 - val_accuracy: 0.8072 - val_auc_roc: 0.8696
# Epoch 8/30
# 7/7 [==============================] - 1s 189ms/step - loss: 0.4784 - accuracy: 0.7723 - auc_roc: 0.8523 - val_loss: 0.4574 - val_accuracy: 0.7960 - val_auc_roc: 0.8697
# Epoch 9/30
# 7/7 [==============================] - 1s 188ms/step - loss: 0.4829 - accuracy: 0.7634 - auc_roc: 0.8486 - val_loss: 0.4550 - val_accuracy: 0.8072 - val_auc_roc: 0.8700
# Epoch 10/30
# 7/7 [==============================] - 1s 205ms/step - loss: 0.4765 - accuracy: 0.7791 - auc_roc: 0.8519 - val_loss: 0.4559 - val_accuracy: 0.8072 - val_auc_roc: 0.8689
# Epoch 11/30
# 7/7 [==============================] - 1s 203ms/step - loss: 0.4833 - accuracy: 0.7634 - auc_roc: 0.8478 - val_loss: 0.4572 - val_accuracy: 0.7982 - val_auc_roc: 0.8668
# Epoch 12/30
# 7/7 [==============================] - 1s 188ms/step - loss: 0.4755 - accuracy: 0.7735 - auc_roc: 0.8538 - val_loss: 0.4569 - val_accuracy: 0.7892 - val_auc_roc: 0.8676
# Epoch 13/30
# 7/7 [==============================] - 1s 201ms/step - loss: 0.4746 - accuracy: 0.7678 - auc_roc: 0.8539 - val_loss: 0.4538 - val_accuracy: 0.8004 - val_auc_roc: 0.8698
# Epoch 14/30
# 7/7 [==============================] - 2s 223ms/step - loss: 0.4686 - accuracy: 0.7797 - auc_roc: 0.8585 - val_loss: 0.4521 - val_accuracy: 0.8049 - val_auc_roc: 0.8726
# Epoch 15/30
# 7/7 [==============================] - 1s 190ms/step - loss: 0.4621 - accuracy: 0.7785 - auc_roc: 0.8611 - val_loss: 0.4509 - val_accuracy: 0.7960 - val_auc_roc: 0.8723
# Epoch 16/30
# 7/7 [==============================] - 1s 200ms/step - loss: 0.4656 - accuracy: 0.7701 - auc_roc: 0.8596 - val_loss: 0.4518 - val_accuracy: 0.7960 - val_auc_roc: 0.8711
# Epoch 17/30
# 7/7 [==============================] - 1s 187ms/step - loss: 0.4580 - accuracy: 0.7988 - auc_roc: 0.8649 - val_loss: 0.4504 - val_accuracy: 0.7960 - val_auc_roc: 0.8711
# Epoch 18/30
# 7/7 [==============================] - 1s 187ms/step - loss: 0.4500 - accuracy: 0.7915 - auc_roc: 0.8688 - val_loss: 0.4538 - val_accuracy: 0.7937 - val_auc_roc: 0.8690
# Epoch 19/30
# 7/7 [==============================] - 1s 191ms/step - loss: 0.4520 - accuracy: 0.7892 - auc_roc: 0.8683 - val_loss: 0.4603 - val_accuracy: 0.7937 - val_auc_roc: 0.8675
# Epoch 20/30
# 7/7 [==============================] - 1s 188ms/step - loss: 0.4469 - accuracy: 0.7976 - auc_roc: 0.8714 - val_loss: 0.4572 - val_accuracy: 0.7892 - val_auc_roc: 0.8678
# Epoch 21/30
# 7/7 [==============================] - 1s 184ms/step - loss: 0.4444 - accuracy: 0.7943 - auc_roc: 0.8733 - val_loss: 0.4597 - val_accuracy: 0.7960 - val_auc_roc: 0.8675
# Epoch 22/30
# 7/7 [==============================] - 1s 185ms/step - loss: 0.4505 - accuracy: 0.7858 - auc_roc: 0.8686 - val_loss: 0.4585 - val_accuracy: 0.7892 - val_auc_roc: 0.8685
# Epoch 23/30
# 7/7 [==============================] - 1s 190ms/step - loss: 0.4411 - accuracy: 0.7881 - auc_roc: 0.8741 - val_loss: 0.4610 - val_accuracy: 0.7803 - val_auc_roc: 0.8657
# Epoch 24/30
# 7/7 [==============================] - 1s 193ms/step - loss: 0.4466 - accuracy: 0.7813 - auc_roc: 0.8722 - val_loss: 0.4585 - val_accuracy: 0.7937 - val_auc_roc: 0.8682
# Epoch 25/30
# 7/7 [==============================] - 1s 199ms/step - loss: 0.4307 - accuracy: 0.7971 - auc_roc: 0.8813 - val_loss: 0.4606 - val_accuracy: 0.7915 - val_auc_roc: 0.8656
# Epoch 26/30
# 7/7 [==============================] - 1s 198ms/step - loss: 0.4296 - accuracy: 0.8004 - auc_roc: 0.8832 - val_loss: 0.4633 - val_accuracy: 0.7937 - val_auc_roc: 0.8675
# Epoch 27/30
# 7/7 [==============================] - 1s 194ms/step - loss: 0.4338 - accuracy: 0.8010 - auc_roc: 0.8773 - val_loss: 0.4555 - val_accuracy: 0.7848 - val_auc_roc: 0.8689
# Epoch 28/30
# 7/7 [==============================] - 1s 196ms/step - loss: 0.4289 - accuracy: 0.7965 - auc_roc: 0.8812 - val_loss: 0.4623 - val_accuracy: 0.7892 - val_auc_roc: 0.8699
# Epoch 29/30
# 7/7 [==============================] - 1s 193ms/step - loss: 0.4252 - accuracy: 0.8061 - auc_roc: 0.8841 - val_loss: 0.4608 - val_accuracy: 0.7848 - val_auc_roc: 0.8668
# Epoch 30/30
# 7/7 [==============================] - 1s 214ms/step - loss: 0.4314 - accuracy: 0.7915 - auc_roc: 0.8807 - val_loss: 0.4680 - val_accuracy: 0.7825 - val_auc_roc: 0.8669
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  Acc: 0.8094170403587444, MCC: 0.6190779266209061, SN:0.7927927927927928, SP:0.8258928571428571,
#  CM:[[185  39]
#  [ 46 176]]

# %%
# load models from file
def load_A_models():
    model = CNN_model()
    model.load_weights('../models/re_train_model_A.h5')
    return model


def load_B_models():
    model = prot_t5_model()
    model.load_weights('../models/re_train_model_B.h5')
    return model


def load_C_models():
    model = transformer_model()
    model.load_weights('../models/re_train_model_C.h5')
    return model

def load_D_models():
    model = RNN_model()
    model.load_weights('../models/re_train_model_D.h5')
    return model


# meta learner
def define_stacked_model(members):
    for i in range(len(members)):
        model = members[i]
        for layer in model.layers:
            layer.trainable = False
    ensemble_inputs = [model.input for model in members]
    #ensemble_outputs = [model.output for model in members]
    ensemble_outputs = [model.get_layer(index = len(model.layers) - 1).output for model in members]
    #print(ensemble_outputs)
    #for item in ensemble_outputs:
    #    print(item)
    # outputs=re_stacked_model.get_layer(index=26).output
    merge = concatenate(ensemble_outputs)
    hidden = Dropout(0.4, name = 'dp_2')(merge)
    hidden = Dense(128, activation='relu', name = 'ds_1')(merge)
    hidden = Dropout(0.4, name = 'dp_1')(hidden)
    hidden = Dense(32, activation='relu', name = 'ds_2')(merge)
    hidden = Dropout(0.4, name = 'dp_3')(hidden)
    output = Dense(1, activation='sigmoid', name = 'ds_4')(hidden)
    model = Model(inputs=ensemble_inputs, outputs=output)
    model.compile(optimizer=Adam(learning_rate=1e-4), loss=BinaryCrossentropy(), metrics=metrics)
    #model.compile(loss='binary_crossentropy', optimizer='adam', metrics=metrics)
    #model.summary()
    return model


# load all models
members = list()
model_A = load_A_models()
model_B = load_B_models()
model_C = load_C_models()
model_D = load_D_models()

members.append(model_A)
members.append(model_B)
members.append(model_C)
#members.append(model_D)

n_epo_stacked = 100


print('Loaded %d models' % len(members))
stacked_model = define_stacked_model(members)


checkpointer = ModelCheckpoint(filepath="../models/pre_re_train_composite_model.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)


st_history = stacked_model.fit([X_train_CNN, X_train_full_ST_embedding, X_train_CNN], train_ST_labels, 
                               epochs=n_epo_stacked, verbose=1, callbacks = [checkpointer],
                               validation_data=([X_test_CNN, X_test_full_ST_embedding, X_test_CNN], test_ST_labels))

# X_train_full_ST_embedding, X_test_full_ST_embedding


plot(st_history)
print()
# Out:
# WARNING:tensorflow:Layer gru_52 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_52 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Loaded 3 models
# Epoch 1/100
# 56/56 [==============================] - 4s 28ms/step - loss: 0.7438 - accuracy: 0.5171 - auc_roc: 0.4881 - val_loss: 0.7396 - val_accuracy: 0.4731 - val_auc_roc: 0.1291
# Epoch 2/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.7284 - accuracy: 0.5155 - auc_roc: 0.3477 - val_loss: 0.7272 - val_accuracy: 0.4417 - val_auc_roc: 0.1468
# Epoch 3/100
# 56/56 [==============================] - 1s 14ms/step - loss: 0.7166 - accuracy: 0.5408 - auc_roc: 0.4168 - val_loss: 0.7159 - val_accuracy: 0.4283 - val_auc_roc: 0.1836
# Epoch 4/100
# 56/56 [==============================] - 1s 24ms/step - loss: 0.7070 - accuracy: 0.5334 - auc_roc: 0.4517 - val_loss: 0.7056 - val_accuracy: 0.3767 - val_auc_roc: 0.2418
# Epoch 5/100
# 56/56 [==============================] - 1s 26ms/step - loss: 0.6931 - accuracy: 0.5649 - auc_roc: 0.5294 - val_loss: 0.6964 - val_accuracy: 0.4193 - val_auc_roc: 0.4008
# Epoch 6/100
# 56/56 [==============================] - 2s 31ms/step - loss: 0.6810 - accuracy: 0.6009 - auc_roc: 0.6021 - val_loss: 0.6877 - val_accuracy: 0.5964 - val_auc_roc: 0.6467
# Epoch 7/100
# 56/56 [==============================] - 2s 27ms/step - loss: 0.6743 - accuracy: 0.6003 - auc_roc: 0.6290 - val_loss: 0.6800 - val_accuracy: 0.6256 - val_auc_roc: 0.7586
# Epoch 8/100
# 56/56 [==============================] - 1s 27ms/step - loss: 0.6637 - accuracy: 0.6554 - auc_roc: 0.6920 - val_loss: 0.6726 - val_accuracy: 0.6413 - val_auc_roc: 0.8131
# Epoch 9/100
# 56/56 [==============================] - 1s 27ms/step - loss: 0.6564 - accuracy: 0.6807 - auc_roc: 0.7223 - val_loss: 0.6655 - val_accuracy: 0.6659 - val_auc_roc: 0.8432
# Epoch 10/100
# 56/56 [==============================] - 1s 26ms/step - loss: 0.6465 - accuracy: 0.7105 - auc_roc: 0.7724 - val_loss: 0.6586 - val_accuracy: 0.6771 - val_auc_roc: 0.8621
# Epoch 11/100
# 56/56 [==============================] - 1s 22ms/step - loss: 0.6376 - accuracy: 0.7341 - auc_roc: 0.8062 - val_loss: 0.6517 - val_accuracy: 0.6883 - val_auc_roc: 0.8734
# Epoch 12/100
# 56/56 [==============================] - 1s 23ms/step - loss: 0.6297 - accuracy: 0.7521 - auc_roc: 0.8286 - val_loss: 0.6449 - val_accuracy: 0.7040 - val_auc_roc: 0.8812
# Epoch 13/100
# 56/56 [==============================] - 2s 45ms/step - loss: 0.6258 - accuracy: 0.7532 - auc_roc: 0.8260 - val_loss: 0.6381 - val_accuracy: 0.7063 - val_auc_roc: 0.8870
# Epoch 14/100
# 32/56 [================>.............] - ETA: 0s - loss: 0.6153 - accuracy: 0.7686 - auc_roc: 0.8457

# %%
# Predict
re_stacked_model = define_stacked_model(members)
re_stacked_model.load_weights("../models/pre_re_train_composite_model.h5")
y_pred = re_stacked_model.predict([X_test_CNN, X_test_full_ST_embedding, X_test_CNN]).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
#  Acc: 0.8430493273542601, MCC: 0.6944146303914154, SN:0.918918918918919, SP:0.7678571428571429,
#  CM:[[172  52]
#  [ 18 204]]

# %%
# load pretrained model
from tensorflow.keras.models import Sequential, load_model, Model
from sklearn.manifold import TSNE
from matplotlib.pyplot import figure
import pandas as pd
import seaborn as sns
import h5py

print("Number of layers: ", len(re_stacked_model.layers))

# create truncated model
truncated_ANN_model = Model(inputs=re_stacked_model.input,
                                 outputs=re_stacked_model.get_layer(index=len(re_stacked_model.layers) - 2).output) #20

hidden_features = truncated_ANN_model.predict([X_test_CNN, X_test_full_ST_embedding, X_test_CNN])

hidden_labels = test_ST_labels

print(hidden_features.shape)

df = pd.DataFrame()
df['Target'] = hidden_labels
# Out:
# Number of layers:  31
# (446, 32)

# %%
m = TSNE(learning_rate = "auto", perplexity = 100, random_state = 20)
tsne_features = m.fit_transform(hidden_features)
df['Dimension-1'] = tsne_features[:,0]
df['Dimension-2'] = tsne_features[:,1]

figsize = (4, 4)
figure(figsize=figsize, dpi=150)

sns.scatterplot(x="Dimension-1", y="Dimension-2", hue='Target',data=df)
plt.tick_params(top=False,
               bottom=False,
               left=False,
               right=False,
               labelleft=False,
               labelbottom=False)

plt.title("TSNE projection")
plt.legend().set_visible(True)
filename = "TSNE_Embedding_Pos_Neg.png"
plt.savefig(filename, dpi=150, bbox_inches='tight')
plt.show()
# Out:
# /opt/conda/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
#!pip install umap-learn

# %%
from umap import UMAP
from matplotlib.pyplot import figure

figsize = (4, 4)
figure(figsize=figsize, dpi=150)

n_colors = 10

n_neighbors = 100

min_dist = 0.99

n_components = 2

metric = "hsl_dist" #'euclidean'

umap_2d = UMAP(n_components=n_components, n_neighbors = n_neighbors, min_dist = min_dist, init = 'random', random_state = 0)

proj_2d = umap_2d.fit_transform(hidden_features)

df_umap = pd.DataFrame()

df_umap["Dimension-1"] = proj_2d[:,0]
df_umap["Dimension-2"] = proj_2d[:,1]

sns_plot = sns.scatterplot(x="Dimension-1", y="Dimension-2", hue=hidden_labels, data=df_umap).set(title="UMAP projection (pLM embeddings trained with 2 deep layers)")
filename = "UMAP_Embedding_Pos_Neg.png"
plt.savefig(filename, dpi=150, bbox_inches='tight')

# %%
hidden_features_raw = X_test_full_ST_embedding
df = pd.DataFrame()
df['Target'] = test_ST_labels

m_raw = TSNE(learning_rate = "auto", perplexity = 100, random_state = 20)

tsne_features = m_raw.fit_transform(hidden_features_raw)

df['Dimension-1'] = tsne_features[:,0]
df['Dimension-2'] = tsne_features[:,1]

figsize = (4, 4)
figure(figsize=figsize, dpi=150)

sns.scatterplot(x="Dimension-1", y="Dimension-2", hue='Target',data=df)
plt.tick_params(top=False,
               bottom=False,
               left=False,
               right=False,
               labelleft=False,
               labelbottom=False)

plt.title("TSNE projection")
plt.legend().set_visible(True)
filename = "TSNE_Embedding_Pos_Neg_Raw.png"
plt.savefig(filename, dpi=150, bbox_inches='tight')
plt.show()
# Out:
# /opt/conda/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
figsize = (4, 4)
figure(figsize=figsize, dpi=150)

n_colors = 10

#n_neighbors = 1000

#min_dist = 0.99

#n_components=2

#metric='euclidean'

umap_2d_raw = UMAP(n_components=n_components, n_neighbors=n_neighbors, min_dist=min_dist, init='random', random_state=0)

proj_2d = umap_2d_raw.fit_transform(hidden_features_raw)

df_umap = pd.DataFrame()

df_umap["Dimension-1"] = proj_2d[:,0]
df_umap["Dimension-2"] = proj_2d[:,1]

sns_plot = sns.scatterplot(x="Dimension-1", y="Dimension-2", hue=hidden_labels, data=df_umap).set(title="UMAP projection (pLM embeddings)")
filename = "UMAP_Embedding_Pos_Neg_pLM_embeddings.png"
plt.savefig(filename, dpi=150, bbox_inches='tight')
