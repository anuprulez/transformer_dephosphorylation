# %%
from keras.models import Model
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate

import pandas as pd
import tqdm
import h5py
from Bio import SeqIO

import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# import keras functions
import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv1D, Dense, MaxPooling1D, Input, Flatten, LSTM, Dropout, Bidirectional
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import EarlyStopping

# performance matrices
from sklearn.metrics import confusion_matrix, matthews_corrcoef, accuracy_score

# plots
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Reshape, Lambda, LeakyReLU
from keras.layers import Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint
import numpy as np
from Bio import SeqIO
from numpy import array
from numpy import argmax
from sklearn.model_selection import train_test_split
from keras.layers.embeddings import Embedding
from keras import backend as K
from keras.backend import expand_dims
import matplotlib.pyplot as plt
from keras.regularizers import l1, l2
# Out:
# 2023-05-12 08:32:01.239606: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-12 08:32:01.239635: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
def plot_save(history, filename):
    # learning curves of model accuracy
    plt.plot(history.history['accuracy'], label='train_acc')
    plt.plot(history.history['val_accuracy'], label='val_acc')
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['auc_roc'], label='Train AUC')
    plt.plot(history.history['val_auc_roc'], label='Val AUC')
    plt.legend()
    plt.savefig(filename)
    plt.show()
    
def plot(history):
    # learning curves of model accuracy
    plt.plot(history.history['accuracy'], label='train_acc')
    plt.plot(history.history['val_accuracy'], label='val_acc')
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['auc_roc'], label='Train AUC')
    plt.plot(history.history['val_auc_roc'], label='Val AUC')
    plt.legend()
    plt.show()

# %%
def prot_t5_model():
    # prot_t5
    M1_input = Input(shape=(1024,))
    M1_dense_1 = Dense(256)(M1_input)
    drop_out = Dropout(0.4)(M1_dense_1)
   
    M1_dense_2 = Dense(64, activation='relu')(drop_out)
    drop_out = Dropout(0.4)(M1_dense_2)
    M1_dense_3 = Dense(1, activation = 'sigmoid')(drop_out)
    model = Model(inputs=M1_input, outputs=M1_dense_3)
    return model

# %%
def read_h5(path):
    hf = h5py.File(path, 'r')
    mat = np.array(hf["embedding"])
    hf.close()
    return mat

# %%
test_positive_ST_embedding_pos = read_h5("../embeddings/test_positive_ST_embedding.h5")
test_negative_ST_embedding_pos = read_h5("../embeddings/test_negative_ST_embedding.h5")

# %%
test_positive_ST_labels = np.ones(test_positive_ST_embedding_pos.shape[0])
test_negative_ST_labels = np.zeros(test_negative_ST_embedding_pos.shape[0])

test_ST_labels = np.concatenate((test_positive_ST_labels, test_negative_ST_labels), axis = 0)
X_test_full_ST_embedding = np.vstack((test_positive_ST_embedding_pos, test_negative_ST_embedding_pos))

# %%
train_positive_ST_embedding_pos = read_h5("../embeddings/train_positive_ST_embedding.h5")
train_negative_ST_embedding_pos = read_h5("../embeddings/train_negative_ST_embedding.h5")

# %%
train_positive_ST_labels = np.ones(train_positive_ST_embedding_pos.shape[0])
train_negative_ST_labels = np.zeros(train_negative_ST_embedding_pos.shape[0])

train_ST_labels = np.concatenate((train_positive_ST_labels, train_negative_ST_labels), axis = 0)
X_train_full_ST_embedding = np.vstack((train_positive_ST_embedding_pos, train_negative_ST_embedding_pos))

# %%
X_train_full_ST_embedding.shape, train_ST_labels.shape,  X_test_full_ST_embedding.shape, test_ST_labels.shape
# Out:
# ((1779, 1024), (1779,), (446, 1024), (446,))

# %%
def get_input_for_embedding(fasta_file):
    # This is returning just integers to feed to embedding layer
    
    encodings = []
    
    # define universe of possible input values
    alphabet = 'ARNDCQEGHILKMFPSTWYV-'
    
    # define a mapping of chars to integers
    char_to_int = dict((c, i) for i, c in enumerate(alphabet))
    int_to_char = dict((i, c) for i, c in enumerate(alphabet))
    
    #print(char_to_int)
    
    for seq_record in SeqIO.parse(fasta_file, "fasta"):
        data = seq_record.seq
        try:
            integer_encoded = [char_to_int[char] for char in data]
        except:
            continue
        encodings.append(integer_encoded)
    encodings = np.array(encodings)
    print(encodings.shape)
    return encodings


# convert sequences to integer encoding, for embedding
test_positive_ST_CNN = get_input_for_embedding('../dataset/test_Pos_ST.fasta')
test_negative_ST_CNN = get_input_for_embedding('../dataset/test_Neg_ST.fasta')

train_positive_ST_CNN = get_input_for_embedding('../dataset/train_Pos_ST.fasta')
train_negative_ST_CNN = get_input_for_embedding('../dataset/train_Neg_ST.fasta')
# Out:
# (222, 33)
# (224, 33)
# (890, 33)
# (889, 33)

# %%
X_train_CNN = np.vstack((train_positive_ST_CNN, train_negative_ST_CNN))
X_test_CNN = np.vstack((test_positive_ST_CNN, test_negative_ST_CNN))
X_train_CNN.shape, X_test_CNN.shape, train_ST_labels.shape, test_ST_labels.shape
# Out:
# ((1779, 33), (446, 33), (1779,), (446,))

# %%
X_train_CNN, train_ST_labels
# Out:
# (array([[ 2, 18, 16, ..., 15, 14, 15],
#         [15,  7, 12, ...,  1, 16,  5],
#         [ 5, 14,  5, ..., 15, 16, 18],
#         ...,
#         [ 0, 14, 10, ..., 19, 15,  7],
#         [ 8,  0, 15, ...,  1, 10, 10],
#         [ 3,  0, 10, ...,  3, 18, 11]]),
#  array([1., 1., 1., ..., 0., 0., 0.]))

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.layers import MultiHeadAttention, LayerNormalization, Layer, GlobalAveragePooling1D, Input, GlobalAveragePooling2D


def CNN_model():
    model = Sequential()
    model.add(Embedding(256, 21, input_length=33))
    model.add(Lambda(lambda x: tf.expand_dims(x, 3)))
    model.add(Conv2D(32, kernel_size=(17, 3), activation = 'relu', kernel_initializer='he_normal', padding = 'VALID'))
    model.add(Dropout(0.4))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(16, activation='relu', kernel_initializer='he_normal'))
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid'))
    return model



class TransformerBlock(Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=rate)
        self.ffn = Sequential(
            [Dense(ff_dim, activation="relu"), Dense(2 * ff_dim, activation="relu"), Dense(embed_dim)] #Dense(4 * ff_dim, activation="relu")
        )
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)
        
    def get_config(self):
        config = super().get_config()
        return config

    def call(self, inputs, training):
        attn_output, attention_scores = self.att(inputs, inputs, inputs, return_attention_scores=True, training=training)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output), attention_scores


class TokenAndPositionEmbedding(Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.token_emb = Embedding(input_dim=vocab_size, output_dim=embed_dim, mask_zero=True)
        self.pos_emb = Embedding(input_dim=maxlen, output_dim=embed_dim, mask_zero=True)
        
    def get_config(self):
        config = super().get_config()
        return config

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        x = self.token_emb(x)
        return x + positions

# %%
# Pretraining with Phosphorylation dataset

# S
pre_test_positive_S_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/test_pos_S.fasta')
pre_test_negative_S_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/test_neg_S.fasta')

pre_train_positive_S_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/train_pos_S.fasta')
pre_train_negative_S_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/train_neg_S.fasta')

# T
pre_test_positive_T_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/test_pos_T.fasta')
pre_test_negative_T_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/test_neg_T.fasta')

pre_train_positive_T_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/train_pos_T.fasta')
pre_train_negative_T_CNN = get_input_for_embedding('../dataset/phospho.elm_dataset/phosphoELM_all_latest.dump/train_neg_T.fasta')


pre_test_pos_ST_CNN = np.vstack((pre_test_positive_S_CNN, pre_test_positive_T_CNN))
pre_test_neg_ST_CNN = np.vstack((pre_test_negative_S_CNN, pre_test_negative_T_CNN))

pre_train_pos_ST_CNN = np.vstack((pre_train_positive_S_CNN, pre_train_positive_T_CNN))
pre_train_neg_ST_CNN = np.vstack((pre_train_negative_S_CNN, pre_train_negative_T_CNN))
# Out:
# (3366, 33)
# (3367, 33)
# (13466, 33)
# (13464, 33)
# (856, 33)
# (858, 33)
# (3420, 33)
# (3419, 33)

# %%
pre_test_pos_ST_CNN.shape, pre_test_neg_ST_CNN.shape, pre_train_pos_ST_CNN.shape, pre_train_neg_ST_CNN.shape
# Out:
# ((4222, 33), (4225, 33), (16886, 33), (16883, 33))

# %%
pre_test_ST = np.vstack((pre_test_pos_ST_CNN, pre_test_neg_ST_CNN))

pre_test_positive_ST_labels = np.ones(pre_test_pos_ST_CNN.shape[0])
pre_test_negative_ST_labels = np.zeros(pre_test_neg_ST_CNN.shape[0])

pre_test_ST_labels = np.concatenate((pre_test_positive_ST_labels, pre_test_negative_ST_labels), axis = 0)
pre_test_ST.shape, pre_test_ST_labels.shape
# Out:
# ((8447, 33), (8447,))

# %%
pre_train_ST = np.vstack((pre_train_pos_ST_CNN, pre_train_neg_ST_CNN))

pre_train_positive_ST_labels = np.ones(pre_train_pos_ST_CNN.shape[0])
pre_train_negative_ST_labels = np.zeros(pre_train_neg_ST_CNN.shape[0])

pre_train_ST_labels = np.concatenate((pre_train_positive_ST_labels, pre_train_negative_ST_labels), axis = 0)
pre_train_ST.shape, pre_train_ST_labels.shape
# Out:
# ((33769, 33), (33769,))

# %%
pre_train_ST, pre_train_ST_labels
# Out:
# (array([[ 5,  3,  7, ...,  3,  9,  5],
#         [14,  0, 14, ..., 14,  2,  5],
#         [ 5, 10,  0, ..., 16, 13, 14],
#         ...,
#         [11, 18,  0, ..., 10, 10, 14],
#         [18, 18, 18, ...,  6,  6,  6],
#         [ 2,  0,  6, ..., 13, 19, 16]]),
#  array([1., 1., 1., ..., 0., 0., 0.]))

# %%
X_train_CNN, train_ST_labels
# Out:
# (array([[ 2, 18, 16, ..., 15, 14, 15],
#         [15,  7, 12, ...,  1, 16,  5],
#         [ 5, 14,  5, ..., 15, 16, 18],
#         ...,
#         [ 0, 14, 10, ..., 19, 15,  7],
#         [ 8,  0, 15, ...,  1, 10, 10],
#         [ 3,  0, 10, ...,  3, 18, 11]]),
#  array([1., 1., 1., ..., 0., 0., 0.]))

# %%
# Pretraining CNN

n_epo_cnn = 20

metrics = ['accuracy', tf.keras.metrics.AUC(name='auc_roc')]

model_A = CNN_model()
model_A.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)

#model_A.summary()

print("PRE Training CNN model...")

checkpointer = ModelCheckpoint(filepath="../models/pre_model_A.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)

#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=7,mode='auto')

pre_history_A = model_A.fit(pre_train_ST, pre_train_ST_labels, batch_size=256, epochs=n_epo_cnn, verbose=1, callbacks=[checkpointer],
    validation_data=(pre_test_ST, pre_test_ST_labels))

# Save model
#model_A.save_weights('../models/pre_model_A.h5')

y_pred = model_A.predict(pre_test_ST).reshape(pre_test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
a_pre_test_ST_labels = np.array(pre_test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(a_pre_test_ST_labels, y_pred)
mcc = matthews_corrcoef(a_pre_test_ST_labels, y_pred)
acc = accuracy_score(a_pre_test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

#save plot
plot(pre_history_A)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
# PRE Training CNN model...
# Epoch 1/20
# 132/132 [==============================] - 13s 93ms/step - loss: 0.6217 - accuracy: 0.6477 - auc_roc: 0.7138 - val_loss: 0.5595 - val_accuracy: 0.7264 - val_auc_roc: 0.8029
# Epoch 2/20
# 132/132 [==============================] - 12s 95ms/step - loss: 0.5609 - accuracy: 0.7211 - auc_roc: 0.7864 - val_loss: 0.5419 - val_accuracy: 0.7379 - val_auc_roc: 0.8145
# Epoch 3/20
# 132/132 [==============================] - 13s 95ms/step - loss: 0.5539 - accuracy: 0.7272 - auc_roc: 0.7958 - val_loss: 0.5370 - val_accuracy: 0.7449 - val_auc_roc: 0.8198
# Epoch 4/20
# 132/132 [==============================] - 12s 94ms/step - loss: 0.5480 - accuracy: 0.7323 - auc_roc: 0.8001 - val_loss: 0.5366 - val_accuracy: 0.7496 - val_auc_roc: 0.8231
# Epoch 5/20
# 132/132 [==============================] - 13s 102ms/step - loss: 0.5426 - accuracy: 0.7343 - auc_roc: 0.8050 - val_loss: 0.5329 - val_accuracy: 0.7500 - val_auc_roc: 0.8262
# Epoch 6/20
# 132/132 [==============================] - 13s 95ms/step - loss: 0.5406 - accuracy: 0.7369 - auc_roc: 0.8076 - val_loss: 0.5270 - val_accuracy: 0.7548 - val_auc_roc: 0.8294
# Epoch 7/20
# 132/132 [==============================] - 12s 92ms/step - loss: 0.5359 - accuracy: 0.7413 - auc_roc: 0.8112 - val_loss: 0.5196 - val_accuracy: 0.7603 - val_auc_roc: 0.8315
# Epoch 8/20
# 132/132 [==============================] - 12s 94ms/step - loss: 0.5313 - accuracy: 0.7437 - auc_roc: 0.8151 - val_loss: 0.5184 - val_accuracy: 0.7633 - val_auc_roc: 0.8335
# Epoch 9/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.5289 - accuracy: 0.7482 - auc_roc: 0.8172 - val_loss: 0.5203 - val_accuracy: 0.7591 - val_auc_roc: 0.8347
# Epoch 10/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.5250 - accuracy: 0.7491 - auc_roc: 0.8204 - val_loss: 0.5167 - val_accuracy: 0.7542 - val_auc_roc: 0.8353
# Epoch 11/20
# 132/132 [==============================] - 14s 106ms/step - loss: 0.5207 - accuracy: 0.7505 - auc_roc: 0.8234 - val_loss: 0.5140 - val_accuracy: 0.7562 - val_auc_roc: 0.8372
# Epoch 12/20
# 132/132 [==============================] - 15s 112ms/step - loss: 0.5185 - accuracy: 0.7522 - auc_roc: 0.8252 - val_loss: 0.5063 - val_accuracy: 0.7604 - val_auc_roc: 0.8372
# Epoch 13/20
# 132/132 [==============================] - 13s 102ms/step - loss: 0.5156 - accuracy: 0.7560 - auc_roc: 0.8282 - val_loss: 0.5014 - val_accuracy: 0.7648 - val_auc_roc: 0.8381
# Epoch 14/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.5144 - accuracy: 0.7576 - auc_roc: 0.8288 - val_loss: 0.5031 - val_accuracy: 0.7603 - val_auc_roc: 0.8388
# Epoch 15/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.5138 - accuracy: 0.7592 - auc_roc: 0.8301 - val_loss: 0.4986 - val_accuracy: 0.7655 - val_auc_roc: 0.8387
# Epoch 16/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.5075 - accuracy: 0.7635 - auc_roc: 0.8338 - val_loss: 0.5075 - val_accuracy: 0.7652 - val_auc_roc: 0.8389
# Epoch 17/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.5050 - accuracy: 0.7632 - auc_roc: 0.8356 - val_loss: 0.5001 - val_accuracy: 0.7670 - val_auc_roc: 0.8392
# Epoch 18/20
# 132/132 [==============================] - 12s 91ms/step - loss: 0.5031 - accuracy: 0.7656 - auc_roc: 0.8371 - val_loss: 0.5029 - val_accuracy: 0.7655 - val_auc_roc: 0.8389
# Epoch 19/20
# 132/132 [==============================] - 13s 99ms/step - loss: 0.5022 - accuracy: 0.7647 - auc_roc: 0.8380 - val_loss: 0.5042 - val_accuracy: 0.7669 - val_auc_roc: 0.8397
# Epoch 20/20
# 132/132 [==============================] - 13s 96ms/step - loss: 0.4982 - accuracy: 0.7680 - auc_roc: 0.8410 - val_loss: 0.5015 - val_accuracy: 0.7662 - val_auc_roc: 0.8400
#  Acc: 0.7661891795903871, MCC: 0.533605720027152, SN:0.7998578872572241, SP:0.7325443786982249,
#  CM:[[3095 1130]
#  [ 845 3377]]

# %%
# transformer based embedding model
def transformer_model():
    vocab_size = 21
    embed_dim = 128 #config["embedding_dim"]
    ff_dim = 128 #config["feed_forward_dim"]
    max_len = 33 #config["maximum_path_length"]
    dropout = 0.4 #config["dropout"]
    n_heads = 2

    inputs = Input(shape=(max_len,))
    embedding_layer = TokenAndPositionEmbedding(max_len, vocab_size, embed_dim)
    x = embedding_layer(inputs)
    transformer_block = TransformerBlock(embed_dim, n_heads, ff_dim)
    x, weights = transformer_block(x)
    x = GlobalAveragePooling1D()(x) #GlobalAveragePooling1D
    x = Dropout(dropout)(x)
    x = Dense(ff_dim, activation="relu")(x)
    x = Dropout(dropout)(x)
    outputs = Dense(1, activation="sigmoid")(x)
    return Model(inputs=inputs, outputs=[outputs])

# %%
# Pretraining transformer

n_epo_transformer = 20
model_C = transformer_model()
model_C.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)

#model_C.summary()

checkpointer = ModelCheckpoint(filepath="../models/pre_model_C.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)

print("PRE Training Transformer model...")

pre_history_C = model_C.fit(pre_train_ST, pre_train_ST_labels, batch_size=256, epochs=n_epo_transformer, verbose=1, callbacks=[checkpointer],
    validation_data=(pre_test_ST, pre_test_ST_labels))

# Save model
#model_C.save_weights('../models/pre_model_C.h5')

y_pred = model_C.predict(pre_test_ST).reshape(pre_test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
a_pre_test_ST_labels = np.array(pre_test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(a_pre_test_ST_labels, y_pred)
mcc = matthews_corrcoef(a_pre_test_ST_labels, y_pred)
acc = accuracy_score(a_pre_test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

#save plot
plot(pre_history_C)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
# PRE Training Transformer model...
# Epoch 1/20
# 132/132 [==============================] - 43s 318ms/step - loss: 0.6241 - accuracy: 0.6528 - auc_roc: 0.7237 - val_loss: 0.5867 - val_accuracy: 0.6888 - val_auc_roc: 0.7526
# Epoch 2/20
# 132/132 [==============================] - 45s 339ms/step - loss: 0.5934 - accuracy: 0.6843 - auc_roc: 0.7441 - val_loss: 0.5509 - val_accuracy: 0.7319 - val_auc_roc: 0.8075
# Epoch 3/20
# 132/132 [==============================] - 48s 361ms/step - loss: 0.5514 - accuracy: 0.7229 - auc_roc: 0.7935 - val_loss: 0.5388 - val_accuracy: 0.7328 - val_auc_roc: 0.8185
# Epoch 4/20
# 132/132 [==============================] - 46s 347ms/step - loss: 0.5397 - accuracy: 0.7340 - auc_roc: 0.8048 - val_loss: 0.5245 - val_accuracy: 0.7449 - val_auc_roc: 0.8224
# Epoch 5/20
# 132/132 [==============================] - 44s 334ms/step - loss: 0.5310 - accuracy: 0.7402 - auc_roc: 0.8119 - val_loss: 0.5110 - val_accuracy: 0.7547 - val_auc_roc: 0.8278
# Epoch 6/20
# 132/132 [==============================] - 45s 338ms/step - loss: 0.5270 - accuracy: 0.7432 - auc_roc: 0.8154 - val_loss: 0.5088 - val_accuracy: 0.7581 - val_auc_roc: 0.8301
# Epoch 7/20
# 132/132 [==============================] - 41s 313ms/step - loss: 0.5244 - accuracy: 0.7454 - auc_roc: 0.8175 - val_loss: 0.5074 - val_accuracy: 0.7575 - val_auc_roc: 0.8305
# Epoch 8/20
# 132/132 [==============================] - 44s 333ms/step - loss: 0.5223 - accuracy: 0.7477 - auc_roc: 0.8189 - val_loss: 0.5118 - val_accuracy: 0.7491 - val_auc_roc: 0.8325
# Epoch 9/20
# 132/132 [==============================] - 47s 360ms/step - loss: 0.5184 - accuracy: 0.7495 - auc_roc: 0.8224 - val_loss: 0.5037 - val_accuracy: 0.7593 - val_auc_roc: 0.8331
# Epoch 10/20
# 132/132 [==============================] - 44s 336ms/step - loss: 0.5171 - accuracy: 0.7497 - auc_roc: 0.8234 - val_loss: 0.5053 - val_accuracy: 0.7593 - val_auc_roc: 0.8337
# Epoch 11/20
# 132/132 [==============================] - 42s 321ms/step - loss: 0.5153 - accuracy: 0.7502 - auc_roc: 0.8247 - val_loss: 0.5018 - val_accuracy: 0.7635 - val_auc_roc: 0.8362
# Epoch 12/20
# 132/132 [==============================] - 44s 332ms/step - loss: 0.5151 - accuracy: 0.7516 - auc_roc: 0.8253 - val_loss: 0.5055 - val_accuracy: 0.7599 - val_auc_roc: 0.8326
# Epoch 13/20
# 132/132 [==============================] - 43s 326ms/step - loss: 0.5111 - accuracy: 0.7542 - auc_roc: 0.8280 - val_loss: 0.4985 - val_accuracy: 0.7622 - val_auc_roc: 0.8375
# Epoch 14/20
# 132/132 [==============================] - 49s 370ms/step - loss: 0.5125 - accuracy: 0.7523 - auc_roc: 0.8268 - val_loss: 0.5023 - val_accuracy: 0.7602 - val_auc_roc: 0.8373
# Epoch 15/20
# 132/132 [==============================] - 41s 310ms/step - loss: 0.5071 - accuracy: 0.7574 - auc_roc: 0.8311 - val_loss: 0.5000 - val_accuracy: 0.7630 - val_auc_roc: 0.8382
# Epoch 16/20
# 132/132 [==============================] - 43s 325ms/step - loss: 0.5048 - accuracy: 0.7559 - auc_roc: 0.8327 - val_loss: 0.4975 - val_accuracy: 0.7642 - val_auc_roc: 0.8397
# Epoch 17/20
# 132/132 [==============================] - 41s 310ms/step - loss: 0.5060 - accuracy: 0.7562 - auc_roc: 0.8318 - val_loss: 0.5362 - val_accuracy: 0.7298 - val_auc_roc: 0.8314
# Epoch 18/20
# 132/132 [==============================] - 41s 308ms/step - loss: 0.5070 - accuracy: 0.7565 - auc_roc: 0.8313 - val_loss: 0.5007 - val_accuracy: 0.7611 - val_auc_roc: 0.8363
# Epoch 19/20
# 132/132 [==============================] - 41s 307ms/step - loss: 0.5024 - accuracy: 0.7608 - auc_roc: 0.8347 - val_loss: 0.4965 - val_accuracy: 0.7638 - val_auc_roc: 0.8394
# Epoch 20/20
# 132/132 [==============================] - 40s 306ms/step - loss: 0.5004 - accuracy: 0.7617 - auc_roc: 0.8361 - val_loss: 0.4965 - val_accuracy: 0.7650 - val_auc_roc: 0.8386
#  Acc: 0.7650053273351486, MCC: 0.5302868904111047, SN:0.780909521553766, SP:0.749112426035503,
#  CM:[[3165 1060]
#  [ 925 3297]]

# %%
## Predict on real data using CNN

y_pred = model_A.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))

## Predict on real data using transformers

y_pred = model_C.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
#  Acc: 0.8071748878923767, MCC: 0.6227782118420341, SN:0.8873873873873874, SP:0.7276785714285714,
#  CM:[[163  61]
#  [ 25 197]]
#
#  Acc: 0.7914798206278026, MCC: 0.5852370850957291, SN:0.8333333333333334, SP:0.75,
#  CM:[[168  56]
#  [ 37 185]]

# %%
# Training DE-Phosphorylation

iteration = 1
n_epo_cnn = 50

model_A = CNN_model()
model_A.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)
model_A.load_weights('../models/pre_model_A.h5')
#model_A.summary()

print("Training CNN model...")

#metrics = ['accuracy', tf.keras.metrics.AUC()]

#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=7,mode='auto')

checkpointer = ModelCheckpoint(filepath="../models/re_train_model_A.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)

history_A = model_A.fit(X_train_CNN, train_ST_labels, batch_size=256, epochs=n_epo_cnn, verbose=1, callbacks=[checkpointer], 
                        validation_data=(X_test_CNN, test_ST_labels))

# Save model
#model_A.save_weights('../models/re_train_model_A.h5')

y_pred = model_A.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

#save plot
plot(history_A)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
print()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_16 (Embedding)    (None, 33, 21)            5376
#
#  lambda_6 (Lambda)           (None, 33, 21, 1)         0
#
#  conv2d_6 (Conv2D)           (None, 17, 19, 32)        1664
#
#  dropout_36 (Dropout)        (None, 17, 19, 32)        0
#
#  max_pooling2d_6 (MaxPooling  (None, 8, 9, 32)         0
#  2D)
#
#  flatten_6 (Flatten)         (None, 2304)              0
#
#  dense_43 (Dense)            (None, 16)                36880
#
#  dropout_37 (Dropout)        (None, 16)                0
#
#  dense_44 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 43,937
# Trainable params: 43,937
# Non-trainable params: 0
# _________________________________________________________________
# Training CNN model...
# Epoch 1/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.5321 - accuracy: 0.7459 - auc_roc: 0.8341 - val_loss: 0.4631 - val_accuracy: 0.8049 - val_auc_roc: 0.8824
# Epoch 2/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.5084 - accuracy: 0.7532 - auc_roc: 0.8308 - val_loss: 0.4682 - val_accuracy: 0.8004 - val_auc_roc: 0.8809
# Epoch 3/50
# 7/7 [==============================] - 0s 68ms/step - loss: 0.5058 - accuracy: 0.7572 - auc_roc: 0.8346 - val_loss: 0.4645 - val_accuracy: 0.8027 - val_auc_roc: 0.8825
# Epoch 4/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4996 - accuracy: 0.7684 - auc_roc: 0.8406 - val_loss: 0.4480 - val_accuracy: 0.8049 - val_auc_roc: 0.8859
# Epoch 5/50
# 7/7 [==============================] - 0s 73ms/step - loss: 0.4818 - accuracy: 0.7752 - auc_roc: 0.8497 - val_loss: 0.4479 - val_accuracy: 0.8072 - val_auc_roc: 0.8880
# Epoch 6/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4805 - accuracy: 0.7746 - auc_roc: 0.8495 - val_loss: 0.4497 - val_accuracy: 0.8094 - val_auc_roc: 0.8895
# Epoch 7/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4679 - accuracy: 0.7841 - auc_roc: 0.8614 - val_loss: 0.4432 - val_accuracy: 0.8027 - val_auc_roc: 0.8909
# Epoch 8/50
# 7/7 [==============================] - 0s 63ms/step - loss: 0.4644 - accuracy: 0.7858 - auc_roc: 0.8609 - val_loss: 0.4448 - val_accuracy: 0.7960 - val_auc_roc: 0.8913
# Epoch 9/50
# 7/7 [==============================] - 0s 62ms/step - loss: 0.4681 - accuracy: 0.7881 - auc_roc: 0.8607 - val_loss: 0.4479 - val_accuracy: 0.8004 - val_auc_roc: 0.8913
# Epoch 10/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4589 - accuracy: 0.8044 - auc_roc: 0.8664 - val_loss: 0.4393 - val_accuracy: 0.8117 - val_auc_roc: 0.8930
# Epoch 11/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4457 - accuracy: 0.8049 - auc_roc: 0.8743 - val_loss: 0.4369 - val_accuracy: 0.8139 - val_auc_roc: 0.8918
# Epoch 12/50
# 7/7 [==============================] - 0s 71ms/step - loss: 0.4432 - accuracy: 0.8010 - auc_roc: 0.8752 - val_loss: 0.4324 - val_accuracy: 0.8004 - val_auc_roc: 0.8930
# Epoch 13/50
# 7/7 [==============================] - 0s 70ms/step - loss: 0.4430 - accuracy: 0.7993 - auc_roc: 0.8752 - val_loss: 0.4328 - val_accuracy: 0.7982 - val_auc_roc: 0.8923
# Epoch 14/50
# 7/7 [==============================] - 0s 64ms/step - loss: 0.4382 - accuracy: 0.8100 - auc_roc: 0.8820 - val_loss: 0.4366 - val_accuracy: 0.7982 - val_auc_roc: 0.8925
# Epoch 15/50
# 7/7 [==============================] - 0s 73ms/step - loss: 0.4298 - accuracy: 0.8151 - auc_roc: 0.8861 - val_loss: 0.4380 - val_accuracy: 0.8004 - val_auc_roc: 0.8923
# Epoch 16/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4272 - accuracy: 0.8083 - auc_roc: 0.8859 - val_loss: 0.4305 - val_accuracy: 0.8117 - val_auc_roc: 0.8934
# Epoch 17/50
# 7/7 [==============================] - 0s 71ms/step - loss: 0.4325 - accuracy: 0.8078 - auc_roc: 0.8814 - val_loss: 0.4383 - val_accuracy: 0.8139 - val_auc_roc: 0.8935
# Epoch 18/50
# 7/7 [==============================] - 0s 69ms/step - loss: 0.4241 - accuracy: 0.8111 - auc_roc: 0.8880 - val_loss: 0.4301 - val_accuracy: 0.8117 - val_auc_roc: 0.8935
# Epoch 19/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.4069 - accuracy: 0.8218 - auc_roc: 0.8970 - val_loss: 0.4310 - val_accuracy: 0.8117 - val_auc_roc: 0.8936
# Epoch 20/50
# 7/7 [==============================] - 0s 69ms/step - loss: 0.4054 - accuracy: 0.8235 - auc_roc: 0.8981 - val_loss: 0.4306 - val_accuracy: 0.8072 - val_auc_roc: 0.8928
# Epoch 21/50
# 7/7 [==============================] - 0s 67ms/step - loss: 0.4068 - accuracy: 0.8168 - auc_roc: 0.8976 - val_loss: 0.4366 - val_accuracy: 0.8094 - val_auc_roc: 0.8908
# Epoch 22/50
# 7/7 [==============================] - 0s 65ms/step - loss: 0.3897 - accuracy: 0.8269 - auc_roc: 0.9063 - val_loss: 0.4263 - val_accuracy: 0.8117 - val_auc_roc: 0.8919
# Epoch 23/50
# 7/7 [==============================] - 1s 82ms/step - loss: 0.3913 - accuracy: 0.8297 - auc_roc: 0.9063 - val_loss: 0.4323 - val_accuracy: 0.8049 - val_auc_roc: 0.8903
# Epoch 24/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.3843 - accuracy: 0.8274 - auc_roc: 0.9089 - val_loss: 0.4294 - val_accuracy: 0.8049 - val_auc_roc: 0.8901
# Epoch 25/50
# 7/7 [==============================] - 1s 114ms/step - loss: 0.3867 - accuracy: 0.8331 - auc_roc: 0.9063 - val_loss: 0.4315 - val_accuracy: 0.8049 - val_auc_roc: 0.8892
# Epoch 26/50
# 7/7 [==============================] - 1s 141ms/step - loss: 0.3811 - accuracy: 0.8319 - auc_roc: 0.9088 - val_loss: 0.4331 - val_accuracy: 0.8049 - val_auc_roc: 0.8890
# Epoch 27/50
# 7/7 [==============================] - 1s 129ms/step - loss: 0.3734 - accuracy: 0.8336 - auc_roc: 0.9150 - val_loss: 0.4267 - val_accuracy: 0.8094 - val_auc_roc: 0.8902
# Epoch 28/50
# 7/7 [==============================] - 1s 114ms/step - loss: 0.3711 - accuracy: 0.8342 - auc_roc: 0.9149 - val_loss: 0.4282 - val_accuracy: 0.8049 - val_auc_roc: 0.8896
# Epoch 29/50
# 7/7 [==============================] - 1s 109ms/step - loss: 0.3557 - accuracy: 0.8432 - auc_roc: 0.9239 - val_loss: 0.4338 - val_accuracy: 0.8027 - val_auc_roc: 0.8883
# Epoch 30/50
# 7/7 [==============================] - 1s 107ms/step - loss: 0.3500 - accuracy: 0.8499 - auc_roc: 0.9273 - val_loss: 0.4273 - val_accuracy: 0.8117 - val_auc_roc: 0.8885
# Epoch 31/50
# 7/7 [==============================] - 1s 113ms/step - loss: 0.3428 - accuracy: 0.8443 - auc_roc: 0.9269 - val_loss: 0.4266 - val_accuracy: 0.8117 - val_auc_roc: 0.8875
# Epoch 32/50
# 7/7 [==============================] - 1s 129ms/step - loss: 0.3515 - accuracy: 0.8527 - auc_roc: 0.9251 - val_loss: 0.4296 - val_accuracy: 0.8094 - val_auc_roc: 0.8872
# Epoch 33/50
# 7/7 [==============================] - 1s 115ms/step - loss: 0.3431 - accuracy: 0.8539 - auc_roc: 0.9305 - val_loss: 0.4330 - val_accuracy: 0.8027 - val_auc_roc: 0.8857
# Epoch 34/50
# 7/7 [==============================] - 1s 114ms/step - loss: 0.3469 - accuracy: 0.8482 - auc_roc: 0.9255 - val_loss: 0.4312 - val_accuracy: 0.8049 - val_auc_roc: 0.8850
# Epoch 35/50
# 7/7 [==============================] - 1s 104ms/step - loss: 0.3240 - accuracy: 0.8555 - auc_roc: 0.9385 - val_loss: 0.4300 - val_accuracy: 0.8117 - val_auc_roc: 0.8862
# Epoch 36/50
# 7/7 [==============================] - 1s 110ms/step - loss: 0.3305 - accuracy: 0.8567 - auc_roc: 0.9346 - val_loss: 0.4289 - val_accuracy: 0.8117 - val_auc_roc: 0.8853
# Epoch 37/50
# 7/7 [==============================] - 1s 105ms/step - loss: 0.3303 - accuracy: 0.8555 - auc_roc: 0.9324 - val_loss: 0.4326 - val_accuracy: 0.8027 - val_auc_roc: 0.8850
# Epoch 38/50
# 7/7 [==============================] - 1s 102ms/step - loss: 0.3131 - accuracy: 0.8539 - auc_roc: 0.9420 - val_loss: 0.4330 - val_accuracy: 0.8072 - val_auc_roc: 0.8845
# Epoch 39/50
# 7/7 [==============================] - 1s 123ms/step - loss: 0.3198 - accuracy: 0.8628 - auc_roc: 0.9403 - val_loss: 0.4326 - val_accuracy: 0.8027 - val_auc_roc: 0.8840
# Epoch 40/50
# 7/7 [==============================] - 1s 106ms/step - loss: 0.3218 - accuracy: 0.8662 - auc_roc: 0.9359 - val_loss: 0.4324 - val_accuracy: 0.8139 - val_auc_roc: 0.8855
# Epoch 41/50
# 7/7 [==============================] - 1s 111ms/step - loss: 0.3027 - accuracy: 0.8668 - auc_roc: 0.9458 - val_loss: 0.4320 - val_accuracy: 0.8117 - val_auc_roc: 0.8841
# Epoch 42/50
# 7/7 [==============================] - 1s 102ms/step - loss: 0.3019 - accuracy: 0.8735 - auc_roc: 0.9455 - val_loss: 0.4335 - val_accuracy: 0.8049 - val_auc_roc: 0.8814
# Epoch 43/50
# 7/7 [==============================] - 1s 102ms/step - loss: 0.3011 - accuracy: 0.8662 - auc_roc: 0.9448 - val_loss: 0.4348 - val_accuracy: 0.8072 - val_auc_roc: 0.8815
# Epoch 44/50
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2958 - accuracy: 0.8746 - auc_roc: 0.9485 - val_loss: 0.4352 - val_accuracy: 0.8049 - val_auc_roc: 0.8807
# Epoch 45/50
# 7/7 [==============================] - 1s 103ms/step - loss: 0.3028 - accuracy: 0.8651 - auc_roc: 0.9444 - val_loss: 0.4341 - val_accuracy: 0.8117 - val_auc_roc: 0.8823
# Epoch 46/50
# 7/7 [==============================] - 1s 108ms/step - loss: 0.2907 - accuracy: 0.8651 - auc_roc: 0.9486 - val_loss: 0.4346 - val_accuracy: 0.8049 - val_auc_roc: 0.8820
# Epoch 47/50
# 7/7 [==============================] - 1s 109ms/step - loss: 0.2834 - accuracy: 0.8803 - auc_roc: 0.9512 - val_loss: 0.4369 - val_accuracy: 0.8027 - val_auc_roc: 0.8823
# Epoch 48/50
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2719 - accuracy: 0.8814 - auc_roc: 0.9552 - val_loss: 0.4345 - val_accuracy: 0.7960 - val_auc_roc: 0.8825
# Epoch 49/50
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2653 - accuracy: 0.8814 - auc_roc: 0.9595 - val_loss: 0.4371 - val_accuracy: 0.7982 - val_auc_roc: 0.8807
# Epoch 50/50
# 7/7 [==============================] - 1s 109ms/step - loss: 0.2686 - accuracy: 0.8881 - auc_roc: 0.9591 - val_loss: 0.4416 - val_accuracy: 0.8027 - val_auc_roc: 0.8804
#  Acc: 0.8026905829596412, MCC: 0.6053732303732303, SN:0.8018018018018018, SP:0.8035714285714286,
#  CM:[[180  44]
#  [ 44 178]]

# %%
loaded_model_A = CNN_model()
loaded_model_A.load_weights("../models/re_train_model_A.h5")
y_pred = loaded_model_A.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
#  Acc: 0.8139013452914798, MCC: 0.6326465519743427, SN:0.8738738738738738, SP:0.7544642857142857,
#  CM:[[169  55]
#  [ 28 194]]

# %%
########### Model B

print("Training Embedding model...")

n_epo_embed = 10
model_B = prot_t5_model()
model_B.compile(optimizer=Adam(learning_rate=1e-3), loss=BinaryCrossentropy(), metrics=metrics)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3, mode='auto')

checkpointer = ModelCheckpoint(filepath="../models/re_train_model_B.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)

history_B = model_B.fit(X_train_full_ST_embedding, train_ST_labels, batch_size=256, epochs=n_epo_embed, verbose=1, 
                        callbacks=[checkpointer], validation_data=(X_test_full_ST_embedding, test_ST_labels))

#model_B.save_weights('../models/re_train_model_B.h5')

y_pred = model_B.predict(X_test_full_ST_embedding).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

plot(history_B)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
print()

loaded_model_B = prot_t5_model()
loaded_model_B.load_weights("../models/re_train_model_B.h5")
y_pred = loaded_model_B.predict(X_test_full_ST_embedding).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
# Training Embedding model...
# Epoch 1/10
# 7/7 [==============================] - 1s 39ms/step - loss: 0.6158 - accuracy: 0.6616 - auc_roc: 0.7616 - val_loss: 0.5120 - val_accuracy: 0.7668 - val_auc_roc: 0.8293
# Epoch 2/10
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5349 - accuracy: 0.7476 - auc_roc: 0.8106 - val_loss: 0.4887 - val_accuracy: 0.7848 - val_auc_roc: 0.8502
# Epoch 3/10
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4943 - accuracy: 0.7684 - auc_roc: 0.8427 - val_loss: 0.4727 - val_accuracy: 0.7937 - val_auc_roc: 0.8627
# Epoch 4/10
# 7/7 [==============================] - 0s 13ms/step - loss: 0.4714 - accuracy: 0.7746 - auc_roc: 0.8591 - val_loss: 0.4557 - val_accuracy: 0.8004 - val_auc_roc: 0.8688
# Epoch 5/10
# 7/7 [==============================] - 0s 13ms/step - loss: 0.4566 - accuracy: 0.7931 - auc_roc: 0.8677 - val_loss: 0.4538 - val_accuracy: 0.8117 - val_auc_roc: 0.8695
# Epoch 6/10
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4284 - accuracy: 0.8072 - auc_roc: 0.8865 - val_loss: 0.4561 - val_accuracy: 0.8072 - val_auc_roc: 0.8683
# Epoch 7/10
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4236 - accuracy: 0.8162 - auc_roc: 0.8884 - val_loss: 0.4560 - val_accuracy: 0.8072 - val_auc_roc: 0.8677
# Epoch 8/10
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3956 - accuracy: 0.8156 - auc_roc: 0.9014 - val_loss: 0.4604 - val_accuracy: 0.8094 - val_auc_roc: 0.8684
# Epoch 9/10
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3866 - accuracy: 0.8325 - auc_roc: 0.9088 - val_loss: 0.4646 - val_accuracy: 0.8027 - val_auc_roc: 0.8641
# Epoch 10/10
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3709 - accuracy: 0.8404 - auc_roc: 0.9157 - val_loss: 0.4692 - val_accuracy: 0.7960 - val_auc_roc: 0.8651
#  Acc: 0.7959641255605381, MCC: 0.5922692755934444, SN:0.8108108108108109, SP:0.78125,
#  CM:[[175  49]
#  [ 42 180]]
#
#
#  Acc: 0.8116591928251121, MCC: 0.6238629018522536, SN:0.7882882882882883, SP:0.8348214285714286,
#  CM:[[187  37]
#  [ 47 175]]

# %%
############# Training Transformer


model_C = transformer_model()
model_C.load_weights('../models/pre_model_C.h5')
model_C.compile(optimizer=Adam(learning_rate=1e-4), loss=BinaryCrossentropy(), metrics=metrics)

model_C.summary()

n_epo_transformer = 40

print("Training Transformer model...")

checkpointer = ModelCheckpoint(filepath="../models/re_train_model_C.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)

#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=7,mode='auto')

history_C = model_C.fit(X_train_CNN, train_ST_labels, batch_size=256, epochs=n_epo_transformer, verbose=1
                        ,callbacks=[checkpointer]
                        , validation_data=(X_test_CNN, test_ST_labels))

# Save model
#model_C.save_weights('../models/re_train_model_C.h5')

y_pred = model_C.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

#save plot
plot(history_C)
print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
print()

loaded_model_C = transformer_model()
loaded_model_C.load_weights("../models/re_train_model_C.h5")
y_pred = loaded_model_C.predict(X_test_CNN).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 33)]              0
#
#  token_and_position_embeddin  (None, 33, 128)          6912
#  g_5 (TokenAndPositionEmbedd
#  ing)
#
#  transformer_block_5 (Transf  ((None, 33, 128),        214912
#  ormerBlock)                  (None, 2, 33, 33))
#
#  global_average_pooling1d_5   (None, 128)              0
#  (GlobalAveragePooling1D)
#
#  dropout_50 (Dropout)        (None, 128)               0
#
#  dense_62 (Dense)            (None, 128)               16512
#
#  dropout_51 (Dropout)        (None, 128)               0
#
#  dense_63 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 238,465
# Trainable params: 238,465
# Non-trainable params: 0
# _________________________________________________________________
# Training Transformer model...
# Epoch 1/40
# 7/7 [==============================] - 3s 273ms/step - loss: 0.5228 - accuracy: 0.7459 - auc_roc: 0.8298 - val_loss: 0.4479 - val_accuracy: 0.8004 - val_auc_roc: 0.8755
# Epoch 2/40
# 7/7 [==============================] - 2s 225ms/step - loss: 0.5136 - accuracy: 0.7572 - auc_roc: 0.8263 - val_loss: 0.4457 - val_accuracy: 0.7937 - val_auc_roc: 0.8781
# Epoch 3/40
# 7/7 [==============================] - 2s 223ms/step - loss: 0.5097 - accuracy: 0.7476 - auc_roc: 0.8287 - val_loss: 0.4441 - val_accuracy: 0.7870 - val_auc_roc: 0.8806
# Epoch 4/40
# 7/7 [==============================] - 2s 221ms/step - loss: 0.5039 - accuracy: 0.7470 - auc_roc: 0.8340 - val_loss: 0.4416 - val_accuracy: 0.7892 - val_auc_roc: 0.8817
# Epoch 5/40
# 7/7 [==============================] - 2s 225ms/step - loss: 0.4955 - accuracy: 0.7611 - auc_roc: 0.8392 - val_loss: 0.4384 - val_accuracy: 0.7937 - val_auc_roc: 0.8826
# Epoch 6/40
# 7/7 [==============================] - 2s 221ms/step - loss: 0.4990 - accuracy: 0.7555 - auc_roc: 0.8372 - val_loss: 0.4361 - val_accuracy: 0.7960 - val_auc_roc: 0.8833
# Epoch 7/40
# 7/7 [==============================] - 2s 232ms/step - loss: 0.4898 - accuracy: 0.7707 - auc_roc: 0.8445 - val_loss: 0.4347 - val_accuracy: 0.7937 - val_auc_roc: 0.8838
# Epoch 8/40
# 7/7 [==============================] - 2s 222ms/step - loss: 0.4876 - accuracy: 0.7684 - auc_roc: 0.8463 - val_loss: 0.4331 - val_accuracy: 0.7982 - val_auc_roc: 0.8846
# Epoch 9/40
# 7/7 [==============================] - 2s 259ms/step - loss: 0.4831 - accuracy: 0.7746 - auc_roc: 0.8485 - val_loss: 0.4320 - val_accuracy: 0.7982 - val_auc_roc: 0.8850
# Epoch 10/40
# 7/7 [==============================] - 2s 286ms/step - loss: 0.4892 - accuracy: 0.7735 - auc_roc: 0.8449 - val_loss: 0.4306 - val_accuracy: 0.7937 - val_auc_roc: 0.8857
# Epoch 11/40
# 7/7 [==============================] - 2s 349ms/step - loss: 0.4839 - accuracy: 0.7690 - auc_roc: 0.8483 - val_loss: 0.4312 - val_accuracy: 0.7915 - val_auc_roc: 0.8856
# Epoch 12/40
# 7/7 [==============================] - 2s 337ms/step - loss: 0.4765 - accuracy: 0.7785 - auc_roc: 0.8529 - val_loss: 0.4304 - val_accuracy: 0.7937 - val_auc_roc: 0.8860
# Epoch 13/40
# 7/7 [==============================] - 2s 352ms/step - loss: 0.4739 - accuracy: 0.7802 - auc_roc: 0.8548 - val_loss: 0.4304 - val_accuracy: 0.7937 - val_auc_roc: 0.8859
# Epoch 14/40
# 7/7 [==============================] - 2s 315ms/step - loss: 0.4752 - accuracy: 0.7813 - auc_roc: 0.8536 - val_loss: 0.4290 - val_accuracy: 0.7892 - val_auc_roc: 0.8866
# Epoch 15/40
# 7/7 [==============================] - 2s 351ms/step - loss: 0.4658 - accuracy: 0.7870 - auc_roc: 0.8592 - val_loss: 0.4279 - val_accuracy: 0.7915 - val_auc_roc: 0.8862
# Epoch 16/40
# 7/7 [==============================] - 3s 369ms/step - loss: 0.4731 - accuracy: 0.7780 - auc_roc: 0.8554 - val_loss: 0.4285 - val_accuracy: 0.7803 - val_auc_roc: 0.8856
# Epoch 17/40
# 7/7 [==============================] - 2s 345ms/step - loss: 0.4681 - accuracy: 0.7903 - auc_roc: 0.8583 - val_loss: 0.4278 - val_accuracy: 0.7848 - val_auc_roc: 0.8862
# Epoch 18/40
# 7/7 [==============================] - 2s 336ms/step - loss: 0.4686 - accuracy: 0.7836 - auc_roc: 0.8585 - val_loss: 0.4274 - val_accuracy: 0.7937 - val_auc_roc: 0.8868
# Epoch 19/40
# 7/7 [==============================] - 2s 341ms/step - loss: 0.4693 - accuracy: 0.7870 - auc_roc: 0.8580 - val_loss: 0.4284 - val_accuracy: 0.7870 - val_auc_roc: 0.8862
# Epoch 20/40
# 7/7 [==============================] - 2s 341ms/step - loss: 0.4613 - accuracy: 0.7920 - auc_roc: 0.8637 - val_loss: 0.4282 - val_accuracy: 0.7892 - val_auc_roc: 0.8860
# Epoch 21/40
# 7/7 [==============================] - 2s 314ms/step - loss: 0.4629 - accuracy: 0.7791 - auc_roc: 0.8621 - val_loss: 0.4271 - val_accuracy: 0.7825 - val_auc_roc: 0.8864
# Epoch 22/40
# 7/7 [==============================] - 2s 315ms/step - loss: 0.4548 - accuracy: 0.7909 - auc_roc: 0.8673 - val_loss: 0.4256 - val_accuracy: 0.7848 - val_auc_roc: 0.8883
# Epoch 23/40
# 7/7 [==============================] - 2s 355ms/step - loss: 0.4596 - accuracy: 0.7920 - auc_roc: 0.8635 - val_loss: 0.4244 - val_accuracy: 0.7848 - val_auc_roc: 0.8892
# Epoch 24/40
# 7/7 [==============================] - 2s 318ms/step - loss: 0.4519 - accuracy: 0.7920 - auc_roc: 0.8692 - val_loss: 0.4257 - val_accuracy: 0.7960 - val_auc_roc: 0.8884
# Epoch 25/40
# 7/7 [==============================] - 2s 316ms/step - loss: 0.4495 - accuracy: 0.7864 - auc_roc: 0.8694 - val_loss: 0.4255 - val_accuracy: 0.7870 - val_auc_roc: 0.8882
# Epoch 26/40
# 7/7 [==============================] - 2s 326ms/step - loss: 0.4513 - accuracy: 0.7954 - auc_roc: 0.8701 - val_loss: 0.4250 - val_accuracy: 0.7758 - val_auc_roc: 0.8879
# Epoch 27/40
# 7/7 [==============================] - 2s 330ms/step - loss: 0.4498 - accuracy: 0.7926 - auc_roc: 0.8715 - val_loss: 0.4256 - val_accuracy: 0.7892 - val_auc_roc: 0.8876
# Epoch 28/40
# 7/7 [==============================] - 2s 343ms/step - loss: 0.4438 - accuracy: 0.8021 - auc_roc: 0.8753 - val_loss: 0.4255 - val_accuracy: 0.7915 - val_auc_roc: 0.8879
# Epoch 29/40
# 7/7 [==============================] - 2s 311ms/step - loss: 0.4444 - accuracy: 0.7965 - auc_roc: 0.8739 - val_loss: 0.4253 - val_accuracy: 0.7892 - val_auc_roc: 0.8878
# Epoch 30/40
# 7/7 [==============================] - 2s 321ms/step - loss: 0.4472 - accuracy: 0.7954 - auc_roc: 0.8721 - val_loss: 0.4257 - val_accuracy: 0.7825 - val_auc_roc: 0.8870
# Epoch 31/40
# 7/7 [==============================] - 2s 313ms/step - loss: 0.4384 - accuracy: 0.8016 - auc_roc: 0.8778 - val_loss: 0.4254 - val_accuracy: 0.7848 - val_auc_roc: 0.8871
# Epoch 32/40
# 7/7 [==============================] - 2s 318ms/step - loss: 0.4401 - accuracy: 0.8021 - auc_roc: 0.8775 - val_loss: 0.4263 - val_accuracy: 0.7937 - val_auc_roc: 0.8870
# Epoch 33/40
# 7/7 [==============================] - 3s 379ms/step - loss: 0.4339 - accuracy: 0.8038 - auc_roc: 0.8807 - val_loss: 0.4258 - val_accuracy: 0.7937 - val_auc_roc: 0.8876
# Epoch 34/40
# 7/7 [==============================] - 2s 348ms/step - loss: 0.4353 - accuracy: 0.8038 - auc_roc: 0.8801 - val_loss: 0.4247 - val_accuracy: 0.7780 - val_auc_roc: 0.8881
# Epoch 35/40
# 7/7 [==============================] - 2s 337ms/step - loss: 0.4310 - accuracy: 0.8004 - auc_roc: 0.8811 - val_loss: 0.4252 - val_accuracy: 0.7892 - val_auc_roc: 0.8879
# Epoch 36/40
# 7/7 [==============================] - 2s 342ms/step - loss: 0.4295 - accuracy: 0.8094 - auc_roc: 0.8824 - val_loss: 0.4240 - val_accuracy: 0.7892 - val_auc_roc: 0.8890
# Epoch 37/40
# 7/7 [==============================] - 2s 359ms/step - loss: 0.4249 - accuracy: 0.8145 - auc_roc: 0.8858 - val_loss: 0.4241 - val_accuracy: 0.7870 - val_auc_roc: 0.8883
# Epoch 38/40
# 7/7 [==============================] - 3s 375ms/step - loss: 0.4255 - accuracy: 0.8117 - auc_roc: 0.8858 - val_loss: 0.4260 - val_accuracy: 0.7915 - val_auc_roc: 0.8874
# Epoch 39/40
# 7/7 [==============================] - 2s 323ms/step - loss: 0.4290 - accuracy: 0.8111 - auc_roc: 0.8833 - val_loss: 0.4268 - val_accuracy: 0.7915 - val_auc_roc: 0.8869
# Epoch 40/40
# 7/7 [==============================] - 2s 338ms/step - loss: 0.4268 - accuracy: 0.8151 - auc_roc: 0.8851 - val_loss: 0.4279 - val_accuracy: 0.7892 - val_auc_roc: 0.8864
#  Acc: 0.7892376681614349, MCC: 0.5809758204967063, SN:0.8333333333333334, SP:0.7455357142857143,
#  CM:[[167  57]
#  [ 37 185]]
#
#
#  Acc: 0.8004484304932735, MCC: 0.6014509272150713, SN:0.8198198198198198, SP:0.78125,
#  CM:[[175  49]
#  [ 40 182]]

# %%
# load models from file
def load_A_models():
    model = CNN_model()
    model.load_weights('../models/re_train_model_A.h5')
    return model


def load_B_models():
    model = prot_t5_model()
    model.load_weights('../models/re_train_model_B.h5')
    return model


def load_C_models():
    model = transformer_model()
    model.load_weights('../models/re_train_model_C.h5')
    return model


# meta learner
def define_stacked_model(members):
    for i in range(len(members)):
        model = members[i]
        for layer in model.layers:
            layer.trainable = False
    ensemble_inputs = [model.input for model in members]
    ensemble_outputs = [model.output for model in members]
    merge = concatenate(ensemble_outputs)
    hidden = Dropout(0.4, name = 'dp_2')(merge)
    hidden = Dense(32, activation='relu', name = 'ds_1')(hidden)
    hidden = Dropout(0.4, name = 'dp_1')(hidden)
    output = Dense(1, activation='sigmoid', name = 'ds_4')(hidden)
    model = Model(inputs=ensemble_inputs, outputs=output)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=metrics)
    return model


# load all models
members = list()
model_A = load_A_models()
model_B = load_B_models()
model_C = load_C_models()

members.append(model_A)
members.append(model_B)
members.append(model_C)

n_epo_stacked = 20


print('Loaded %d models' % len(members))
stacked_model = define_stacked_model(members)


checkpointer = ModelCheckpoint(filepath="../models/pre_re_train_composite_model.h5",
                                monitor = "val_accuracy",
                                verbose=0, 
                                save_weights_only=True,
                                save_best_only=True)


st_history = stacked_model.fit([X_train_CNN, X_train_full_ST_embedding, X_train_CNN], train_ST_labels, 
                               epochs=n_epo_stacked, verbose=1, callbacks = [checkpointer],
                               validation_data=([X_test_CNN, X_test_full_ST_embedding, X_test_CNN], test_ST_labels))
# Out:
# Loaded 3 models
# Epoch 1/20
# 56/56 [==============================] - 2s 24ms/step - loss: 0.6900 - accuracy: 0.4784 - auc_roc: 0.6500 - val_loss: 0.6589 - val_accuracy: 0.5090 - val_auc_roc: 0.8938
# Epoch 2/20
# 56/56 [==============================] - 1s 19ms/step - loss: 0.6531 - accuracy: 0.6020 - auc_roc: 0.7017 - val_loss: 0.6279 - val_accuracy: 0.6637 - val_auc_roc: 0.9001
# Epoch 3/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.6321 - accuracy: 0.6650 - auc_roc: 0.7416 - val_loss: 0.6035 - val_accuracy: 0.7399 - val_auc_roc: 0.8977
# Epoch 4/20
# 56/56 [==============================] - 1s 20ms/step - loss: 0.6054 - accuracy: 0.7066 - auc_roc: 0.7715 - val_loss: 0.5746 - val_accuracy: 0.7982 - val_auc_roc: 0.8985
# Epoch 5/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.5852 - accuracy: 0.7381 - auc_roc: 0.7919 - val_loss: 0.5497 - val_accuracy: 0.8161 - val_auc_roc: 0.9004
# Epoch 6/20
# 56/56 [==============================] - 2s 33ms/step - loss: 0.5724 - accuracy: 0.7369 - auc_roc: 0.7915 - val_loss: 0.5298 - val_accuracy: 0.8274 - val_auc_roc: 0.9013
# Epoch 7/20
# 56/56 [==============================] - 2s 35ms/step - loss: 0.5714 - accuracy: 0.7178 - auc_roc: 0.7834 - val_loss: 0.5242 - val_accuracy: 0.8341 - val_auc_roc: 0.9017
# Epoch 8/20
# 56/56 [==============================] - 2s 32ms/step - loss: 0.5722 - accuracy: 0.7223 - auc_roc: 0.7799 - val_loss: 0.5130 - val_accuracy: 0.8318 - val_auc_roc: 0.9004
# Epoch 9/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.5640 - accuracy: 0.7397 - auc_roc: 0.7877 - val_loss: 0.5121 - val_accuracy: 0.8363 - val_auc_roc: 0.8998
# Epoch 10/20
# 56/56 [==============================] - 2s 33ms/step - loss: 0.5632 - accuracy: 0.7330 - auc_roc: 0.7880 - val_loss: 0.5089 - val_accuracy: 0.8386 - val_auc_roc: 0.9004
# Epoch 11/20
# 56/56 [==============================] - 2s 33ms/step - loss: 0.5339 - accuracy: 0.7532 - auc_roc: 0.8175 - val_loss: 0.4988 - val_accuracy: 0.8341 - val_auc_roc: 0.9006
# Epoch 12/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.5385 - accuracy: 0.7493 - auc_roc: 0.8089 - val_loss: 0.4906 - val_accuracy: 0.8296 - val_auc_roc: 0.9013
# Epoch 13/20
# 56/56 [==============================] - 2s 32ms/step - loss: 0.5636 - accuracy: 0.7313 - auc_roc: 0.7850 - val_loss: 0.4990 - val_accuracy: 0.8341 - val_auc_roc: 0.9019
# Epoch 14/20
# 56/56 [==============================] - 2s 32ms/step - loss: 0.5416 - accuracy: 0.7515 - auc_roc: 0.8039 - val_loss: 0.4999 - val_accuracy: 0.8318 - val_auc_roc: 0.9012
# Epoch 15/20
# 56/56 [==============================] - 2s 32ms/step - loss: 0.5389 - accuracy: 0.7403 - auc_roc: 0.8049 - val_loss: 0.4954 - val_accuracy: 0.8318 - val_auc_roc: 0.9003
# Epoch 16/20
# 56/56 [==============================] - 2s 33ms/step - loss: 0.5426 - accuracy: 0.7420 - auc_roc: 0.8059 - val_loss: 0.5003 - val_accuracy: 0.8274 - val_auc_roc: 0.9004
# Epoch 17/20
# 56/56 [==============================] - 2s 32ms/step - loss: 0.5483 - accuracy: 0.7336 - auc_roc: 0.7949 - val_loss: 0.5032 - val_accuracy: 0.8251 - val_auc_roc: 0.9002
# Epoch 18/20
# 56/56 [==============================] - 2s 33ms/step - loss: 0.5478 - accuracy: 0.7369 - auc_roc: 0.7940 - val_loss: 0.5036 - val_accuracy: 0.8206 - val_auc_roc: 0.9000
# Epoch 19/20
# 56/56 [==============================] - 2s 34ms/step - loss: 0.5416 - accuracy: 0.7386 - auc_roc: 0.8003 - val_loss: 0.5059 - val_accuracy: 0.8206 - val_auc_roc: 0.8997
# Epoch 20/20
# 56/56 [==============================] - 2s 31ms/step - loss: 0.5365 - accuracy: 0.7482 - auc_roc: 0.8081 - val_loss: 0.5078 - val_accuracy: 0.8161 - val_auc_roc: 0.8995

# %%
y_pred = stacked_model.predict([X_test_CNN, X_test_full_ST_embedding, X_test_CNN]).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

plot(st_history)

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
print()

# Predict
re_stacked_model = define_stacked_model(members)
re_stacked_model.load_weights("../models/pre_re_train_composite_model.h5")
y_pred = re_stacked_model.predict([X_test_CNN, X_test_full_ST_embedding, X_test_CNN]).reshape(test_ST_labels.shape[0],)
y_pred = (y_pred > 0.5)
y_pred = [int(i) for i in y_pred]
test_ST_labels = np.array(test_ST_labels)
y_pred = np.array(y_pred)

cm = confusion_matrix(test_ST_labels, y_pred)
mcc = matthews_corrcoef(test_ST_labels, y_pred)
acc = accuracy_score(test_ST_labels, y_pred)

sn = cm[1][1]/(cm[1][1]+cm[1][0])
sp = cm[0][0]/(cm[0][0]+cm[0][1])

print("\n Acc: %s, MCC: %s, SN:%s, SP:%s, \n CM:%s" %(str(acc), str(mcc), str(sn), str(sp), cm))
# Out:
#  Acc: 0.8161434977578476, MCC: 0.6435052298375702, SN:0.7207207207207207, SP:0.9107142857142857,
#  CM:[[204  20]
#  [ 62 160]]
#
#
#  Acc: 0.8385650224215246, MCC: 0.6809266367449776, SN:0.7837837837837838, SP:0.8928571428571429,
#  CM:[[200  24]
#  [ 48 174]]

# %%
# load pretrained model
from tensorflow.keras.models import Sequential, load_model, Model
from sklearn.manifold import TSNE
from matplotlib.pyplot import figure
import pandas as pd
import seaborn as sns
import h5py

#re_stacked_model.summary()

print("Number of layers: ", len(re_stacked_model.layers))

# create truncated model
truncated_ANN_model = Model(inputs=re_stacked_model.input,
                                 outputs=re_stacked_model.get_layer(index=26).output) #20

hidden_features = truncated_ANN_model.predict([X_test_CNN, X_test_full_ST_embedding, X_test_CNN])

print(hidden_features.shape)

df = pd.DataFrame()
df['Target'] = test_ST_labels
# Out:
# Number of layers:  29
# (446, 32)

# %%
m = TSNE(learning_rate = 10, perplexity = 100, random_state = 20) #"auto"
tsne_features = m.fit_transform(hidden_features)
df['Dimension-1'] = tsne_features[:,0]
df['Dimension-2'] = tsne_features[:,1]

figsize = (4, 4)
figure(figsize=figsize, dpi=150)

sns.scatterplot(x="Dimension-1", y="Dimension-2", hue='Target',data=df)
plt.tick_params(top=False,
               bottom=False,
               left=False,
               right=False,
               labelleft=False,
               labelbottom=False)

plt.title("Pretraining: TSNE projection")
plt.legend().set_visible(True)
filename = "TSNE_stacked_no_pretraining.png"
plt.savefig(filename,dpi=150,bbox_inches='tight')
plt.show()
# Out:
# /home/anupkumar/anaconda3/envs/succsite/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
from umap import UMAP
from matplotlib.pyplot import figure

figsize = (4, 4)
figure(figsize=figsize, dpi=150)

n_colors = 10

n_neighbors = 30

min_dist= 0.9

n_components=2

metric='euclidean'

umap_2d = UMAP(n_components=n_components, n_neighbors=n_neighbors, min_dist=min_dist, init='random', random_state=0)

proj_2d = umap_2d.fit_transform(hidden_features)

df_umap = pd.DataFrame()

df_umap["comp-1"] = proj_2d[:,0]
df_umap["comp-2"] = proj_2d[:,1]

sns.scatterplot(x="comp-1", y="comp-2", hue=test_ST_labels, data=df_umap).set(title="UMAP projection")
filename = "UMAP_stacked_no_pretrain.png"
plt.savefig(filename, dpi=150, bbox_inches='tight')
